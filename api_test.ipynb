# %%
url = "https://uniadmission.me"
username = "w"
password = "w"

# %%
import requests
payload = {
    "username": username,
    "password": password
}
response = requests.post(f"{url}/login", json=payload)
print(response.headers)
token = response.headers["set-cookie"].split("jwt=")[-1]
# Out:
# {'Server': 'nginx/1.24.0 (Ubuntu)', 'Date': 'Mon, 06 Oct 2025 08:49:02 GMT', 'Content-Type': 'application/json', 'Content-Length': '65', 'Connection': 'keep-alive', 'set-cookie': 'jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ3Iiwicm9sZSI6InVzZXIiLCJleHAiOjE3NTk3NDQxNDJ9.EMUMaohvDgWqMn_IXwZdd8TD6T1Ao2Bv_PhqKNsQKGg; HttpOnly; Max-Age=3600; Path=/; SameSite=lax'}

# %%
payload = {
  "text": "Điểm chuẩn đại học Công nghệ - Đại học Quốc gia Hà Nội",
  "session_id": None,
  "params": {
    "model_id": "gpt-4o-mini",
    "use_websearch": True,
    "use_localdb": True,
    "max_query": 1,
    "query_score_threshold": 0,
    "engine_type": "google",
    "domain_restrict": False,
    "school_domain": False,
    "time_metric": "m",
    "time_range": 0,
    "llm_rerank": False,
    "page_score_threshold": 0,
    "chunk_score_threshold": 0,
    "k_docs": 5,
    "k_pages": 1,
    "page_rerank": False,
    "chunk_rerank": False,
    "include_pdf": False,
    "include_image": False,
    "merge_table": True,
    "merge_neighbor": False,
    "max_tokens": 2048,
    "temperature": 0.5,
    "top_p": 0.9,
    "top_k": 32,
    "max_history": 0
  }
}
cookie = {
    "jwt": token
}
response = requests.post(f"{url}/chat", json=payload, cookies=cookie)
result_url = response.json().get("result_url", None)

# %%
print(response.json())
# Out:
# {'session_id': 'd6d646a9-ab3b-44a8-8e21-e75488721fe5', 'role': 'bot', 'rag_sources': [{'query': 'UET:diem_chuan', 'url': 'https://hoctap.coccoc.com/tim-truong-dh-cd', 'title': 'Tìm trường ĐH-CĐ - Cốc Cốc (UET)', 'text': 'Điểm chuẩn - Đại học Công nghệ - Đại học Quốc gia Hà Nội:\n\nNGÀNH ĐÀO TẠO VÀ ĐIỂM CHUẨN:\n | **Mã ngành** | **Tên ngành** | **2025** | **2024** | **2023** | **2022** | **2021** | **2020** | \n | -|-|-|-|-|-|-|- | \n| CN18 | Thiết kế công nghiệp và đồ họa | 24.2 | 24.64 | - | - | - | - |\n| CN20 | Khoa học và kỹ thuật dữ liệu | 27.38 | - | - | - | - | - |\n| CN4 | Cơ kỹ thuật | 26.15 | 26.03 | 25.65 | 25.0 | - | - |\n| CN5 | Công nghệ kỹ thuật xây dựng | 22.25 | 23.91 | 23.1 | 22.0 | - | - |\n| CN1 | Công nghệ Thông tin | 28.19 | 27.8 | 27.85 | 29.15 | - | - |\n| CN9 | Công nghệ kỹ thuật điện tử - viễn thông | 26.63 | 26.3 | 25.15 | 23.0 | - | - |\n| CN10 | Công nghệ nông nghiệp* | 22.0 | 22.5 | 22.0 | 22.0 | - | - |\n| CN16 | Công nghệ thông tin định hướng thị trườn
# ...

# %%
print(result_url)
# Out:
# https://uniadmission.me/inference/1410a3af-4bec-4eec-9dbc-e110366e2ef0

# %%
if result_url != None:
    response = requests.post(result_url, stream=True) # post or get both work
    for chunk in response.iter_content(chunk_size=64):
        if chunk:
            print(chunk.decode("utf-8"), end="", flush=False)
# Out:
# ### Điểm chuẩn 2025 — Đại học Công nghệ (Đại học Quốc gia Hà Nội)
# **Tóm tắt:**
# - Điểm chuẩn năm 2025 dao động từ **22.00** đến **28.19**.
# - Ngành có điểm chuẩn cao nhất là **Công nghệ Thông tin** với **28.19** điểm.
# - Ngành có điểm chuẩn thấp nhất là **Công nghệ nông nghiệp** với **22.00** điểm.
#
# | Ngành                                       | Mã ngành | Điểm chuẩn |
# |---------------------------------------------|----------|------------|
# | Công nghệ Thông tin                         | CN1      | 28.19      |
# | Khoa học và kỹ thuật dữ liệu                | CN20     | 27.38      |
# | Trí tuệ nhân tạo                            | CN12     | 27.75      |
# | Kỹ thuật điều khiển và tự động hóa         | CN11     | 27.90      |
# | Máy tính và Robot                           | CN2      | 27.00      |
# | Khoa học máy tính                           | CN8      | 27.86      |
# | Cơ kỹ thuật                                 | CN4      | 26.15      |
# ...
