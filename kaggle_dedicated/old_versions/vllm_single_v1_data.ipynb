# %% [markdown]
# ### Install environment

# %%
import importlib.util
if importlib.util.find_spec("flashrank") is None:
    # !pip install vllm==0.10.0
    # !pip install triton==3.2.0
    # !pip install flashrank langchain langchain-community langchain_google_genai openai faiss-cpu langchain_huggingface crawl4ai unidecode pymupdf4llm google-genai
    # !pip uninstall -y openai
    # !pip install openai==1.90.0
else:
    print("All libs aldready installed")
# Out:
# All libs aldready installed

# %%
# !wget -q -O ngrok.zip https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.zip
# !unzip -o ngrok.zip
# !mv ngrok /usr/local/bin/ngrok
# !chmod +x /usr/local/bin/ngrok
# !ps aux | grep ngrok
# Out:
# Archive:  ngrok.zip
#   inflating: ngrok
# root         255  0.0  0.0      0     0 ?        Z    02:35   0:00 [ngrok] <defunct>
# root         819  0.3  0.0      0     0 ?        Z    02:41   0:01 [ngrok] <defunct>
# root        1005  0.0  0.0   7376  3328 pts/0    Ss+  02:49   0:00 /bin/bash -c ps aux | grep ngrok
# root        1007  0.0  0.0   6484  2304 pts/0    S+   02:49   0:00 grep ngrok

# %%
import os
# Fixed, do not change
os.environ["GLOO_SOCKET_NAME"] = "eth0"
os.environ["NCCL_SOCKET_NAME"] = "eth0"
os.environ["VLLM_HOST_IP"] = "127.0.0.1" # Internal ip for data communicate between VLLM components
os.environ["VLLM_USE_V1"] = "0" # T4 have compute capacity of 7.5, it need at least 8.0 to use V1

# %% [markdown]
# ##### Download package from server

# %%
DOMAIN = "https://6497f61a7736.ngrok-free.app"
BASE_PATH = "/kaggle/working"

# %%
import requests
import io
import tarfile
import shutil
def unpack_folder(data: bytes, path: str):
    if os.path.exists(path): # Remove old code
        shutil.rmtree(path)
    with io.BytesIO(data) as tar_buffer:
        with tarfile.open(fileobj=tar_buffer, mode='r:gz') as tar:
            tar.extractall(path=path)
def unpack_file(data: bytes, path: str):
    if os.path.exists(path):
        os.remove(path)
    with open(path, 'wb') as file:
        file.write(data)
def unpack_list(*names: str):
    for name in names:
        if "." in name:
            url = f"{DOMAIN}/package/{name}"
        else:
            url = f"{DOMAIN}/package/{name}"
        data = requests.get(url).content
        if "." in name:
            unpack_file(data, name)
        else:
            unpack_folder(data, name)
unpack_list(
    "retriever", "server", "static.pkl", "worker.env", "data_collect"
)

# %% [markdown]
# ### Config

# %% [markdown]
# Load environment variable (api keys)

# %%
from dotenv import load_dotenv
load_dotenv(f"{BASE_PATH}/worker.env")
# Out:
# True

# %%
# import shutil, os
# if os.path.exists(f"{BASE_PATH}/data_logs"):
#     shutil.rmtree(f"{BASE_PATH}/data_logs")

# %% [markdown]
# Setup ngrok

# %%
NGROK_PORT = 8002
import subprocess
subprocess.Popen(["ngrok", "config", "add-authtoken", os.getenv("NGROK_TOKEN_1", "")])
subprocess.Popen(["ngrok", "http", str(NGROK_PORT)], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
# Out:
# <Popen: returncode: None args: ['ngrok', 'http', '8002']>
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# Login hugging face

# %%
from huggingface_hub import login
login(os.getenv("HUGGING_FACE_TOKEN"))

# %% [markdown]
# ##### Config

# %%
from retriever import DataRetrieverPage, WebsearchConfig, RagConfig, SplitterConfig, PageRankerConfig, MergeNeighborConfig, MergeTableConfig, CmdLogger, SourceFormat
from server import *
from data_collect import DataCollector
from typing import AsyncGenerator, NotRequired, Protocol
from typing import Callable, AsyncGenerator
from openai import AsyncOpenAI, OpenAI
import os
import pickle
import json
import asyncio
import enum
import traceback

class CallType(enum.Enum):
    ROUTER = "router"
    RERANK = "page_rerank"
    READER = "reader"

class ModelProtocol(Protocol):
    async def __call__(self, call_type: CallType, instruction: str, prefix: str, prompt: str, params: GenerationParams) -> AsyncGenerator[str, None]: ...

# %%
from vllm.lora.request import LoRARequest

# %%
MODEL_ID = "Qwen/Qwen3-4B"
# Retriever config
search_config = WebsearchConfig(
    page_timeout=15,
    file_timeout=15,
    concurrent_page=10,
    concurrent_download=8
)
rag_config = RagConfig(
    embedding_name="intfloat/multilingual-e5-base",
    device="cuda"
)
splitter_config = SplitterConfig(
    tokenizer_name="Qwen/Qwen3-4B",
    chunk_size=512,
    chunk_overlap=0,
    # device="cuda"
)
page_rerank_config = PageRankerConfig(
    use_llm=True,
    call=None
)
table_merge_config = MergeTableConfig(
    k_max_previous=3,
    k_max_next=3
)
neighbor_config = MergeNeighborConfig(
    k_previous_chunks=1,
    k_next_chunks=1
)
# Sampling Params
PAGE_RERANKER_PARAMS = GenerationParams(
    temperature=0.7,
    top_p=0.9,
    max_tokens=4096
)
ROUTER_PARAMS = GenerationParams(
    temperature=0.7,
    top_p=0.9,
    max_tokens=1024
)
READER_LORA = LoRARequest(
    lora_int_id= 1,
    lora_name= "Qwen Reader Lora",
    lora_path= "/kaggle/input/qwen-lora-xxx/transformers/default/1/qwen_lora_adapter"
)
MODELS: list[ModelInfo] = [
    {
        "name": "Qwen 3 4B",
        "id": "Qwen/Qwen3-4B"  
    },
    {
        "name": "Qwen 3 4B LoRA v1",
        "id": "Qwen/Qwen3-4B-LoRA-v1"
    }
]
CLIENT_INFO: WorkerServerInfo = {
    "name": "Test Reader only",
    "domain": "http://127.0.0.1:8002", # Auto change when run with ngrok
    "models": MODELS
}

# %% [markdown]
# ##### Template, instruction, prefix

# %%
PAGE_RERANKER_INSTRUCTION =  "Bạn là hệ thống xếp hạng lại (reranker) kết quả tìm kiếm để trả lời truy vấn của người dùng (Query)."
PAGE_RERANKER_PREFIX = """Hướng dẫn:  
1. Trích xuất các thực thể chính trong truy vấn (tổ chức, khoa, viện, bộ môn, chủ đề, ...).  
2. Với mỗi ứng viên:  
   - Xác định thực thể chính mà nó đề cập.  
   - Gán mức độ ưu tiên: "High", "Medium" hoặc "Low" (xem quy tắc bên dưới).  
   - Viết ngắn gọn lý do.  
3. Gom nhóm các ứng viên theo mức ưu tiên.  
4. Trong mỗi nhóm, so sánh trực tiếp các ứng viên để quyết định thứ tự cuối cùng.  
5. Rà soát: Đảm bảo rằng High > Medium > Low toàn cục. Điều chỉnh nếu cần.  
6. Chỉ trả lời bằng JSON hợp lệ:
  - Suy nghĩ và điền vào "intermediate"
  - Kết luận và đưa ra "output"
7. Không được đưa thêm văn bản ngoài JSON.  

Quy tắc ưu tiên:  
- High: Trang nói rõ về đúng thực thể trong truy vấn.  
- Medium: Trang nói về thực thể liên quan chặt chẽ (cùng trường nhưng khác khoa/bộ môn) đến truy vấn.  
- Low: Trang chung chung về trường đại học hoặc không liên quan đến truy vấn.  

Input format: 
Query:  
"<user query>" 
Candidates:
[
  {"index": 1, "title": <string>, "description": <string>},
  {"index": 2, "title": <string>, "description": <string>},
  ...
]

Output format:
{
  "intermediate": [
    {"index": 1, "title": <string>, "entity_match": <bool>, "priority": "High|Medium|Low", "opinion": <string>},
    {"index": 2, "title": <string>, "entity_match": <bool>, "priority": "High|Medium|Low", "opinion": <string>},
    ...
  ],
  "output": [
    {"index": 2, "rank": 1, "score": <float 0.0–1.0>, "title": <string>, "reason": <string>},
    {"index": 1, "rank": 2, "score": <float 0.0–1.0>, "title": <string>, "reason": <string>},
    ...
  ]
}

Lưu ý: "intermediate" và "output" phải bao gồm tất cả "Candidates" từ "Input", kể cả khi có mức độ ưu tiên thấp. 
"""
PAGE_RERANKER_TEMPLATE = """Query: 
"{query}"
Candidates:
{pages}"""
ROUTER_INSTRUCTION = "Bạn là chuyên gia tạo từ khóa tìm kiếm thông minh. Nhiệm vụ: phân tích câu hỏi và tạo từ khóa giúp tìm được thông tin CĂN BẢN để LLM có thể suy luận ra câu trả lời."
ROUTER_PREFIX = """CHIẾN LƯỢC TÌM KIẾM:

1. **Phân tích ý định câu hỏi**: Xác định thông tin gì cần thiết để trả lời
2. **Xác định nguồn tìm kiếm**: Tìm kiếm từ local vector database hoặc tìm kiếm trên web. Vector DB có chứa thông tin về điểm chuẩn các năm, thông tin chung của trường, học phí và thông tin tuyển sinh. Các câu hỏi ngoài phạm vi của Vector DB sẽ tìm kiếm trên web.
2. **Tìm nguồn thông tin gốc**: Thay vì tìm trực tiếp câu trả lời, tìm dữ liệu để suy luận
3. **Tối ưu từ khóa**: 
   - Dùng thuật ngữ chính thức, tên đầy đủ
   - Xoá từ filler (xin, làm ơn, cho mình) nhưng giữ từ thể hiện ý định.
   - Ưu tiên giữ lại đối tượng (ví dụ như: tổ chức, trường, ngành, ...) → nhưng loại bỏ chi tiết con để tạo phạm vi tìm kiếm bao quát hơn.
   - Nếu input không có năm → thêm `2025`. Nếu có năm → giữ nguyên.
4. **Trả lời đúng định dạng**: Định dạng câu trả lời như sau:
- Nếu sử dụng web search: {"type_search": "web_search", "key_word": ["từ khóa 1", "từ khóa 2", ...]}
- Nếu sử dụng local vector DB: {"type_search": "vector_db", "key_word": [{"school_id": "tên trường 1", "section": "section1"},{"school_id": "tên trường 2", "section": "section2"},...]}. Lưu ý: section là 1 trong 4 mục: "thong_tin_chung", "hoc_phi", "diem_chuan", "tuyen_sinh", trong đó "thong_tin_chung" bao gồm thông tin chung của trường như tên, địa chỉ, liên hệ..., "hoc_phi" bao gồm thông tin học phí của trường, "diem_chuan" bao gồm điểm chuẩn các năm, "tuyen_sinh" bao gồm các ngành đào tạo của trường, thông tin tuyển sinh của truờng.

VÍ DỤ THÔNG MINH:

Câu hỏi: "Số tiến sĩ trong viện trí tuệ nhân tạo UET là bao nhiêu?"
→ Không có trong vector DB nên cần tìm kiếm trên web
→ Cần: Danh sách giảng viên để đếm tiến sĩ
→ Từ khóa: "danh sách giảng viên viện trí tuệ nhân tạo UET"
→ Trả về: {"type_search": "web_search", "key_word": ["danh sách giảng viên viện trí tuệ nhân tạo UET"]}

Câu hỏi: "Điểm chuẩn ngành CNTT Bách Khoa 2025?"
→ Vector DB có thông tin điểm chuẩn các năm nên tìm trong DB
→ Cần: Điểm chuẩn của Đại học Bách Khoa (HUST)
→ Trả về: {"type_search": "vector_db", "key_word": [{"school_id": "HUST", "section": "diem_chuan"}]}

Câu hỏi: "Học phí ngành Luật kinh doanh VNU-LS như thế nào?"
→ Vector DB có thông tin học phí nên tìm trong DB
→ Cần: Học phí của Trường Đại học Luật - Đại học Quốc gia Hà Nội (LS)
→ Trả về: {"type_search": "vector_db", "key_word": [{"school_id": "LS", "section": "hoc_phi"}]}

NGUYÊN TẮC:
- Các câu hỏi ngoài phạm vi vector DB (thông tin chung (gồm tên trường, giới thiệu, mã trường, địa chỉ, thông tin liên hệ như điện thoại, web ...), điểm chuẩn các năm, học phí, thông tin tuyển sinh) thì tìm kiếm trên web
- Nếu câu hỏi cần tìm thông tin mới nhất, ví dụ trong câu hỏi có từ khóa như "mới nhất", "cập nhật",... thì ưu tiên tìm kiếm trên web
- Tìm "danh sách", "bảng", "chương trình" thay vì câu hỏi trực tiếp

Chỉ trả về từ khóa, không giải thích."""
ROUTER_TEMPLATE = """Câu hỏi: {question}"""
READER_INSTRUCTION = """"Bạn là một AI tư vấn tuyển sinh đại học chuyên nghiệp. Hãy trả lời các câu hỏi một cách chính xác, hữu ích và thân thiện. Có thể sử dụng những thông tin được cung cấp để đưa ra câu trả lời hoặc lời khuyên tốt nhất. Nếu được cung cấp link nguồn thì thêm vào phần cuối câu trả lời, nếu không được cung cấp thì không thêm."""
READER_UNTRAINED_INSTRUCTION = """Bạn là một AI tư vấn tuyển sinh đại học chuyên nghiệp. Hãy trả lời các câu hỏi một cách chính xác, hữu ích và thân thiện. Có thể sử dụng những thông tin được cung cấp để đưa ra câu trả lời hoặc lời khuyên tốt nhất. Nếu được cung cấp link nguồn thì thêm vào phần cuối câu trả lời, nếu không được cung cấp thì không thêm.
Nhiệm vụ của bạn: Trả lời câu hỏi theo hướng dẫn sau đây, phải tuân thủ định dạng Markdown chuẩn.
Hiện tại là năm 2025, sử dụng thông tin mới nhất có thể.
Hãy trả lời **chỉ bằng Markdown** theo form chuẩn dưới đây. 
Không thêm giải thích ngoài lề, không in JSON, không in XML.
"""
READER_UNTRAINED_PREFIX = """### FORM TRẢ LỜI (Markdown):

### {TIÊU ĐỀ NGẮN}
**Tóm tắt:**  
- {Ý chính 1}  
- {Ý chính 2}  
- {Ý chính 3 (nếu có)}  

{BẢNG CHÍNH nếu có số liệu, theo đúng intent}  
| Cột 1 | Cột 2 | Cột 3 | (Cột 4 nếu cần) |
|-------|-------|-------|-----------------|
| ...   | ...   | ...   | ...             |

**Nguồn:** [Tên nguồn 1](URL1), [Tên nguồn 2](URL2)  
**Lưu ý:** {ràng buộc hoặc phạm vi áp dụng}  

**Bạn có thể hỏi thêm:** {2–4 gợi ý follow-up câu hỏi liên quan}

---

# Quy tắc bắt buộc
1. **Tiêu đề** luôn bắt đầu bằng `###`, chứa loại thông tin + năm + trường/ngành.  
2. **Tóm tắt** luôn 2–3 bullet, có con số chính yếu (điểm/học phí/số lượng/địa chỉ).  
3. **Bảng chính** chỉ hiển thị nếu có dữ liệu số hoặc danh sách.  
4. **Nguồn**: luôn có ≥1 link; nếu không tìm thấy thì ghi “(chưa tìm thấy nguồn đáng tin)”.  
5. **Lưu ý**: ghi rõ phạm vi (năm, phương thức, chương trình, cơ sở,...).  
6. **Follow-up**: luôn gợi ý 2–4 câu hỏi liên quan.  
7. Nếu dữ liệu thiếu → ghi rõ trong “Lưu ý” hoặc “Nguồn”.  
8. Không bao giờ trả lời ngoài form này.
9. Trong ví dụ câu hỏi điểm chuẩn, tôi chỉ liệt kê 4 ngành ví dụ. Trong câu trả lời thực tế, mỗi trường liệt kê ra cho tôi khoảng 15-20 ngành(phù hợp với trường đó). Tương tự với câu hỏi chỉ tiêu tuyển sinh các ngành.
10. Nếu không tìm thấy đủ dữ liệu đáng tin để xây dựng đầy đủ theo form, chỉ trả lời: "Tôi không tìm thấy thông tin phù hợp.". Sau đó bắt buộc gợi ý người dùng hỏi lại (ví dụ: thêm năm, trường, ngành, phương thức...), hoặc đưa ra 2–4 câu hỏi liên quan.
---

# Ví dụ input → output.

**Ví dụ 1 — Input (câu hỏi):**  
“Điểm chuẩn ngành CNTT UET 2024 là bao nhiêu?”

**Output (Markdown):**
### Điểm chuẩn 2024 — Ngành CNTT (UET, THPT)  
**Tóm tắt:**  
- Điểm chuẩn ngành CNTT UET năm 2024 là **27.80**.  
- Áp dụng cho phương thức xét tuyển THPT.  
- Mã ngành: CN1.  

| Ngành               | Phương thức | Mã ngành | Điểm chuẩn |
|---------------------|-------------|----------|------------|
| Công nghệ thông tin | THPT        | CN1      | 27.80      |

**Nguồn:** [UET Công khai 2024](https://...)  
**Lưu ý:** Điểm chuẩn thay đổi theo phương thức khác (học bạ, ĐGNL).  

**Bạn có thể hỏi thêm:** học phí ngành CNTT, chỉ tiêu 2025, tổ hợp xét tuyển.  

---

**Ví dụ 2 — Input (câu hỏi):**  
“Đội ngũ giảng viên của UET như thế nào?”

**Output (Markdown):**
### Đội ngũ giảng viên — UET (2024)  

**Tóm tắt:**  
- Tổng số giảng viên cơ hữu: ~200.  
- Khoảng **15% là Giáo sư/Phó Giáo sư**.  
- Hơn **80% có bằng Tiến sĩ hoặc Thạc sĩ**.  

| Học hàm / Học vị | Số lượng | Tỉ lệ   |
|------------------|----------|---------|
| GS/PGS           | 30       | 15%     |
| TS/ThS           | 170      | 85%     |
| Khác             | 5        | ~2%     |

**Nguồn:** [UET Công khai đội ngũ 2024](https://...)  
**Lưu ý:** Số liệu mang tính tham khảo, có thể thay đổi theo từng năm học.  

**Bạn có thể hỏi thêm:**  
- Tỉ lệ giảng viên/sinh viên tại UET là bao nhiêu?  
- Các giảng viên tiêu biểu trong ngành CNTT?  
- Nhóm nghiên cứu mạnh nào đang hoạt động tại UET?

---

**Ví dụ 3 — Input (câu hỏi):**
“Điểm chuẩn theo phương thức THPT của Đại học Bách khoa (HUST) năm 2024?”

**Output (Markdown):**
### Điểm chuẩn Đại học Bách khoa (HUST) 2024 — Phương thức THPT  
**Tóm tắt:**  
- Điểm chuẩn Đại học Bách khoa năm 2024 phân bổ từ **24.00** đến **29.50** tùy ngành.
- Ngành có điểm chuẩn cao nhất là **Công nghệ thông tin** với **29.50** điểm.
- Ngành có điểm chuẩn thấp nhất là **Kỹ thuật cơ khí** với **24.00** điểm.

| Ngành               | Phương thức | Mã ngành | Điểm chuẩn |
|---------------------|-------------|----------|------------|
| Công nghệ thông tin | THPT        | IT1      | 29.50      |
| Kỹ thuật cơ khí     | THPT        | ME1      | 24.00      |
| Kỹ thuật điện       | THPT        | EE1      | 26.50      |
| Kỹ thuật xây dựng   | THPT        | CE1      | 25.00      |


**Nguồn:** [Điểm chuẩn HUST 2024](https://...)  
**Lưu ý:** Điểm chuẩn thay đổi theo phương thức khác (học bạ, ĐGNL).  

**Bạn có thể hỏi thêm:** học phí ngành CNTT, chỉ tiêu 2025, tổ hợp xét tuyển.  

--- 
"""
READER_TEMPLATE = """Hiện tại là năm 2025, sử dụng thông tin mới nhất có thể. 
Nếu không tìm thấy đủ dữ liệu đáng tin để xây dựng đầy đủ theo form, chỉ trả lời: "Tôi không tìm thấy thông tin phù hợp.".
Thông tin tham khảo:
{context}
Câu hỏi:
{question}"""

# %% [markdown]
# ### Utility class

# %% [markdown]
# ##### Data Retriever

# %%
class StaticDBSearch:
    """Search in static db"""
    def __init__(self) -> None:
        with open(f"{BASE_PATH}/static.pkl", 'rb') as file:
            self.all_docs = pickle.load(file)
    def _filter_docs(self, school_id: str, section: str) -> list:
        school_docs = [doc for doc in self.all_docs if doc.metadata.get("school_id") == school_id]
        if school_docs:
            filtered_docs = [doc for doc in school_docs if doc.metadata.get("section") == section]
        else:
            filtered_docs = []
        return filtered_docs
    def __call__(self, keywords: list[dict]) -> list[WebSource]:
        results: list[WebSource] = []
        try:
            for kw in keywords:
                school_id = kw.get("school_id")
                section = kw.get("section")
                if school_id and section:
                    docs = self._filter_docs(school_id, section)
                    title = f"Tìm trường ĐH-CĐ - Cốc Cốc ({school_id})"
                    combined_content = "\n\n".join([doc.page_content for doc in docs])
                    description = combined_content[:100] + "..." if len(combined_content) > 100 else combined_content
                    web_source: WebSource = {
                        "title": title,
                        "description": description,
                        "url": "https://hoctap.coccoc.com/tim-truong-dh-cd",
                        "text": combined_content,
                        "files": []
                    }
                    results.append(web_source)
        except:
            traceback.print_exc()
        finally:            
            return results
    def from_websources(self, sources: list[WebSource]) -> list[RagSource]:
        results: list[RagSource] = []
        for source in sources:
            rag_source: RagSource = {
                "title": source["title"],
                "url": source["url"],
                "text": source["text"]
            }
            results.append(rag_source)
        return results

# %%
class WebSearch:
    """Search in web"""
    def __init__(self, llm_call: ModelProtocol) -> None:
        page_rerank_config.call = self._llm_reranker
        self.web_search = DataRetrieverPage(
            search_config=search_config,
            rag_config=rag_config,
            splitter_config=splitter_config,
            page_rerank_config=page_rerank_config,
            merge_neighbor_config=neighbor_config,
            merge_table_config=table_merge_config
        )
        self.llm_call = llm_call
    def _construct_reranker_prompt(self, query: str, data: list[tuple[str, str]]) -> str:
        candidates = [{
            "index": index+1, 
            "title": item[0],
            "description": item[1],
        } for index, item in enumerate(data)]
        candidates = "[" + ",\n".join([json.dumps(item, ensure_ascii=False) for item in candidates]) + "]"
        return PAGE_RERANKER_TEMPLATE.format(query=query, pages=candidates)
    async def start(self):
        """Initialize websearch"""
        await self.web_search.start()
    async def _llm_reranker(self, query: str, data: list[tuple[str, str]]) -> list[float]:
        if len(data) == 0: return []
        text = ""    
        scores = [0.0 for _ in data]
        prompt = self._construct_reranker_prompt(query, data)
        async for chunk in await self.llm_call(
            call_type=CallType.RERANK, 
            instruction=PAGE_RERANKER_INSTRUCTION, 
            prefix=PAGE_RERANKER_PREFIX,
            prompt=prompt, 
            params=PAGE_RERANKER_PARAMS
        ):
            text += chunk
        try:
            result = json.loads(text)
            if "output" in result:
                for item in result["output"]:
                    index = int(item["index"]) - 1
                    scores[index] = float(item["score"])
            else:
                # Fallback if model not provide intermediate step
                for item in result:
                    index = int(item["index"]) - 1
                    scores[index] = float(item["score"])
        except:
            print(text)
            traceback.print_exc()
        return scores
    async def websearch(self, query: str, k_pages: int, domain_restrict: bool, engine: Literal["google", "brave"]):
        return await self.web_search.websearch(query, k_pages, domain_restrict, engine, include_pdf=True, include_image=False)
    async def from_websources(self, web_sources: list[WebSource], rerank_query: str, rag_query: str, params: GenerationParams) -> list[RagSource]:
        k_docs = params.get("k_docs", 0)
        if k_docs == 0:
            return []
        else:
            rag_sources = await self.web_search.rag_retrieve(
                web_sources, rerank_query, rag_query, k_docs,
                rerank_chunk=True, merge_table=True, merge_neighbor=False
            )
            return rag_sources

# %%
class DataRetriverRouter:
    def __init__(self, model: ModelProtocol) -> None:
        self.static = StaticDBSearch()
        self.web = WebSearch(model)
        self.model = model
    async def start(self):
        await self.web.start()
    async def _llm_route(self, question: str):
        prompt = ROUTER_TEMPLATE.format(question=question)
        generator = await self.model(
            call_type=CallType.ROUTER, 
            instruction=ROUTER_INSTRUCTION,
            prefix=ROUTER_PREFIX, 
            prompt=prompt, 
            params=ROUTER_PARAMS
        )
        text = ""
        async for chunk in generator:
            text += chunk
        return text
    async def router(self, question: str):
        """Sử dụng router để quyết định nguồn"""
        try:
            # Sử dụng router để quyết định hướng tìm kiếm
            text = await self._llm_route(question)
            print(text)
            search_strategy: dict = json.loads(text)
            search_type = search_strategy.get("type_search")
            keywords: list[str | dict[str, str]] = search_strategy.get("key_word", [])
            return {"type_search": search_type, "key_words": keywords}
        except Exception as e:
            return {"type_search": "web_search", "key_words": [question]}
    async def __call__(self, question: str, params: GenerationParams) -> tuple[str, list[WebSource], list[RagSource]]:
        """
        Retrive data with user question.\n
        Return web query, list of `WebSource` and list of `RagSource`.
        """
        k_pages = params.get("k_pages", 0)
        k_docs = params.get("k_docs", 0)
        domain_restrict = params.get("domain_restric", False)
        print(f"[WS] k_pages: {k_pages} | k_docs {k_docs} | domain_restrict: {domain_restrict}")
        if k_pages == 0 or k_docs == 0:
            return question, [], []
        else:
            strategy = await self.router(question)
            if strategy["type_search"] == "vector_db":
                web_sources = self.static(strategy["key_words"])
                rag_sources = self.static.from_websources(web_sources)
                web_query = strategy["key_words"]
            if strategy["type_search"] == "vector_db" and (len(web_sources) == 0 or web_sources[0]["text"] == ""):
                # Fallback to web search
                strategy["type_search"] = "web_search"
                strategy["key_words"] = [question]
            if strategy["type_search"] != "vector_db":
                # Multi query is a little bit too complicated
                web_query = ";".join([str(item) for item in strategy["key_words"]])
                web_sources = []
                rag_sources = []
                for query in strategy["key_words"]:
                    web_sources_ = await self.web.websearch(query, k_pages, domain_restrict, params.get("engine_type", "brave"))
                    web_sources.extend(web_sources_)
                    rag_sources.extend(await self.web.from_websources(web_sources_, question, query, params))
        return web_query, web_sources, rag_sources
    async def from_websources(self, query: str, sources: list[WebSource], params: GenerationParams, rag_query: str | None = None) -> list[RagSource]:
        """For multi-turn."""
        dynamic_sources: list[WebSource] = []
        rag_sources: list[RagSource] = []
        for source in sources:
            if source["url"] == "https://hoctap.coccoc.com/tim-truong-dh-cd":
                rag_sources.extend(self.static.from_websources([source]))
            else:
                dynamic_sources.append(source)
        if rag_query is None:
            rag_query = str(params.get("kwargs", {}).get("rag_query", query)) # Try to get rag_query, fallback to query
        rag_queries = rag_query.split(";") if ";" in rag_query else [rag_query] * len(dynamic_sources)
        for source, rag_query_ in zip(dynamic_sources, rag_queries):
            rag_sources.extend(await self.web.from_websources([source], query, rag_query_, params))
        return rag_sources

# %% [markdown]
# ##### vLLM Model

# %%
from vllm import SamplingParams, AsyncLLMEngine, AsyncEngineArgs
from vllm.outputs import RequestOutput
from vllm.utils import random_uuid
from vllm.lora.request import LoRARequest
from typing import AsyncGenerator
from typing import Optional, Any
from vllm.transformers_utils.tokenizers import MistralTokenizer
from openai.types.chat import  ChatCompletionUserMessageParam, ChatCompletionSystemMessageParam
from vllm.entrypoints.chat_utils import (
    ChatTemplateContentFormatOption, 
    resolve_chat_template_content_format, 
    apply_hf_chat_template,
    apply_mistral_chat_template,
    parse_chat_messages
)
from vllm.inputs.data import TokensPrompt

class AsyncLLMEngineWrapper:
    """Not support shutdown"""
    def __init__(self) -> None:
        self.engine = None
        self.reap_wait_time = 5
    def init(self, engine_args: AsyncEngineArgs):
        self.engine = AsyncLLMEngine.from_engine_args(engine_args)
    def generate(self, prompt: str | TokensPrompt, sampling_params: SamplingParams, lora_request: LoRARequest | None) -> AsyncGenerator[RequestOutput, None]:
        if self.engine is None:
            raise Exception("Not initialized")
        return self.engine.generate(
            prompt=prompt,
            sampling_params=sampling_params,
            request_id=random_uuid(),
            lora_request=lora_request
        )
    async def chat(self, instruction: str, prompt: str, sampling_params: SamplingParams, lora_request: LoRARequest | None = None):
        messages = [
            ChatCompletionSystemMessageParam(content=instruction, role="system"),
            ChatCompletionUserMessageParam(content=prompt, role="user")
        ]
        return await self._chat(
            messages=messages,
            sampling_params=sampling_params,
            lora_request=lora_request,
            chat_template_kwargs={
                "enable_thinking": False
            }
        )
    async def _chat(
        self,
        messages: list[ChatCompletionUserMessageParam | ChatCompletionUserMessageParam],
        sampling_params: SamplingParams,
        lora_request: LoRARequest | None,
        chat_template_content_format: ChatTemplateContentFormatOption = "auto",
        chat_template: Optional[str] = None,
        add_generation_prompt: bool = True,
        continue_final_message: bool = False,
        chat_template_kwargs: Optional[dict[str, Any]] = None
    ):
        if self.engine is None: raise Exception("Model not loaded")
        tokenizer = await self.engine.get_tokenizer(lora_request)
        model_config = self.engine.engine.get_model_config()
        resolved_content_format = resolve_chat_template_content_format(
            chat_template,
            None,
            chat_template_content_format,
            tokenizer,
            model_config=model_config,
        )
        _chat_template_kwargs: dict[str, Any] = dict(
            chat_template=chat_template,
            add_generation_prompt=add_generation_prompt,
            continue_final_message=continue_final_message,
            tools=None,
        )
        _chat_template_kwargs.update(chat_template_kwargs or {})
        conversation, _ = parse_chat_messages(
            messages, #type:ignore
            model_config,
            tokenizer,
            content_format=resolved_content_format,
        )

        if isinstance(tokenizer, MistralTokenizer):
            prompt_token_ids = apply_mistral_chat_template(
                tokenizer,
                messages=messages, #type:ignore
                **_chat_template_kwargs,
            )
        else:
            prompt_str = apply_hf_chat_template(
                tokenizer=tokenizer, #type:ignore
                conversation=conversation,
                model_config=model_config,
                **_chat_template_kwargs,
            )
            prompt_token_ids = tokenizer.encode(prompt_str, add_special_tokens=False)
        prompt = TokensPrompt(prompt_token_ids=prompt_token_ids)
        return self.generate(
            prompt,
            sampling_params=sampling_params,
            lora_request=lora_request,
        )
# Out:
# 2025-09-05 02:49:40.313860: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757040580.336590     989 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757040580.343644     989 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO 09-05 02:49:44 [__init__.py:235] Automatically detected platform cuda.

# %% [markdown]
# ##### Client to call model

# %%
import msgspec

class VLLMWrapper:
    def __init__(self) -> None:
        self.use_lora = True
        self._engine = AsyncLLMEngineWrapper()
    def init(self, engine_args: AsyncEngineArgs, models: list[str]):
        self._valid_models = models
        self._engine.init(engine_args)
    async def call(self, call_type: CallType, instruction: str, prefix: str, prompt: str, params: GenerationParams) -> AsyncGenerator[str, None]:
        model = MODEL_ID
        lora_request = None
        if call_type == CallType.READER:
            model = "reader"
            if self.use_lora:
                lora_request = READER_LORA
        elif call_type == CallType.RERANK:
            model = "ranker"
        elif call_type == CallType.ROUTER:
            model = "router"
        if model not in self._valid_models:
            print(f"[VLLM] Invalid model id {model}. List of valid models: {self._valid_models}")
            model = MODEL_ID
        print(f"[VLLM] {call_type} | Instruction length: {len(instruction)} | Prompt length: {len(prompt)} | Prefix length: {len(prefix)} | kwargs: {params.get('kwargs')}")
        sampling_params = msgspec.convert(params, SamplingParams)
        stream = await self._engine.chat(
            instruction=instruction,
            prompt=prefix+prompt,
            sampling_params=sampling_params,
            lora_request=lora_request
        )
        total_text = ""
        last_index = 0
        async for event in stream:
            total_text = event.outputs[0].text
            yield total_text[last_index:]
            last_index = len(total_text)
    async def __call__(self, call_type: CallType, instruction: str, prefix: str, prompt: str, params: GenerationParams) -> AsyncGenerator[str, None]:
        return self.call(call_type, instruction, prefix, prompt, params)

# %% [markdown]
# ##### Pipeline

# %%
class CustomQA:
    def __init__(self, model_protocol: ModelProtocol) -> None:
        self.logger = CmdLogger("QA")
        self.retriever = DataRetriverRouter(model_protocol)
        self.llm_call = model_protocol
    async def start(self):
        await self.retriever.start()
    async def inference(self, prompt: str, request: WorkerChatRequest) -> AsyncGenerator[str, None]:
        text = ""
        async for chunk in await self.llm_call(
            call_type=CallType.READER, 
            instruction=READER_INSTRUCTION, 
            prefix="",
            prompt=prompt, 
            params=request["params"]
        ):
            text += chunk
            yield chunk
    async def pre_inference(
        self,
        question: str,
        stream_id: str,
        params: GenerationParams
    ) -> tuple[str, ModelPreOutput]:
        web_query, web_sources, rag_sources = await self.retriever(
            question, 
            params
        )
        context = SourceFormat()(rag_sources)
        prompt = READER_TEMPLATE.format(context=context, question=question)
        self.logger.start()
        pre_output: ModelPreOutput = {
            "model_id": MODEL_ID,
            "generation_params": params,
            "web_sources": web_sources,
            "rag_sources": rag_sources,
            "extra_data": {
                "web_query": web_query,
            },
            "result_url": stream_id,
            "user_intent": "",
            "user_keywords": [],
            "user_summary": ""
        }
        return prompt, pre_output

# %% [markdown]
# ### Final

# %% [markdown]
# VLLMM Engine

# %%
engine_args = AsyncEngineArgs(
    model=MODEL_ID,
    tensor_parallel_size=2,
    gpu_memory_utilization=0.8,
    max_model_len=32768,
    enable_lora=True,
    max_lora_rank=16,
    max_loras=1
)
vllm = VLLMWrapper()
vllm.init(engine_args, [MODEL_ID, "reader"])
# Out:
# WARNING 09-05 02:50:00 [config.py:3392] Your device 'Tesla T4' (with compute capability 7.5) doesn't support torch.bfloat16. Falling back to torch.float16 for compatibility.
# WARNING 09-05 02:50:00 [config.py:3443] Casting torch.bfloat16 to torch.float16.
# INFO 09-05 02:50:00 [config.py:1604] Using max model len 32768
# INFO 09-05 02:50:00 [llm_engine.py:228] Initializing a V0 LLM engine (v0.10.0) with config: model='Qwen/Qwen3-4B', speculative_config=None, tokenizer='Qwen/Qwen3-4B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=2, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='xgrammar', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=None, served_model_name=Qwen/Qwen3-4B, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=None, chunked_prefill_enabled=False, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":[],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":false,"cudagraph_num_of_warmups":0,"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":256,"local_cache_dir":null}, use_cached_outputs=False,
# WARNING 09-05 02:50:01 [__init__.py:2899] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reason: CUDA is initialized
# WARNING 09-05 02:50:01 [multiproc_worker_utils.py:307] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# INFO 09-05 02:50:02 [cuda.py:346] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 09-05 02:50:02 [cuda.py:395] Using XFormers backend.
# 2025-09-05 02:50:05.768424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757040605.789228    1053 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757040605.795531    1053 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO 09-05 02:50:11 [__init__.py:235] Automatically detected platform cuda.
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:11 [multiproc_worker_utils.py:226] Worker ready; awaiting tasks
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:12 [cuda.py:346] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:12 [cuda.py:395] Using XFormers backend.
# INFO 09-05 02:50:13 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:13 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:13 [pynccl.py:70] vLLM is using nccl==2.26.2
# INFO 09-05 02:50:13 [pynccl.py:70] vLLM is using nccl==2.26.2
# INFO 09-05 02:50:14 [custom_all_reduce_utils.py:246] reading GPU P2P access cache from /root/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:14 [custom_all_reduce_utils.py:246] reading GPU P2P access cache from /root/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# (VllmWorkerProcess pid=1053) WARNING 09-05 02:50:14 [custom_all_reduce.py:147] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 09-05 02:50:14 [custom_all_reduce.py:147] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# INFO 09-05 02:50:14 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1], buffer_handle=(1, 4194304, 6, 'psm_49d5eee1'), local_subscribe_addr='ipc:///tmp/c999990e-e3c5-4df8-8857-c202bdacba2f', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 09-05 02:50:14 [parallel_state.py:1102] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:14 [parallel_state.py:1102] rank 1 in world size 2 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# INFO 09-05 02:50:14 [model_runner.py:1083] Starting to load model Qwen/Qwen3-4B...
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:14 [model_runner.py:1083] Starting to load model Qwen/Qwen3-4B...
# INFO 09-05 02:50:15 [weight_utils.py:296] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/3 [00:00<?, ?it/s]
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:15 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:29 [default_loader.py:262] Loading weights took 13.67 seconds
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:29 [logger.py:65] Using PunicaWrapperGPU.
# INFO 09-05 02:50:29 [default_loader.py:262] Loading weights took 14.18 seconds
# INFO 09-05 02:50:29 [logger.py:65] Using PunicaWrapperGPU.
# INFO 09-05 02:50:30 [model_runner.py:1115] Model loading took 3.8589 GiB and 14.779343 seconds
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:30 [model_runner.py:1115] Model loading took 3.8589 GiB and 14.367283 seconds
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:41 [worker.py:295] Memory profiling takes 11.13 seconds
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:41 [worker.py:295] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.80) = 11.79GiB
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:41 [worker.py:295] model weights take 3.86GiB; non_torch_memory takes 0.11GiB; PyTorch activation peak memory takes 1.68GiB; the rest of the memory reserved for KV Cache is 6.15GiB.
# INFO 09-05 02:50:42 [worker.py:295] Memory profiling takes 11.21 seconds
# INFO 09-05 02:50:42 [worker.py:295] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.80) = 11.79GiB
# INFO 09-05 02:50:42 [worker.py:295] model weights take 3.86GiB; non_torch_memory takes 0.11GiB; PyTorch activation peak memory takes 1.68GiB; the rest of the memory reserved for KV Cache is 6.15GiB.
# INFO 09-05 02:50:42 [executor_base.py:113] # cuda blocks: 5594, # CPU blocks: 3640
# INFO 09-05 02:50:42 [executor_base.py:118] Maximum concurrency for 32768 tokens per request: 2.73x
# (VllmWorkerProcess pid=1053) INFO 09-05 02:50:46 [model_runner.py:1385] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 09-05 02:50:46 [model_runner.py:1385] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/35 [00:00<?, ?it/s]
# (VllmWorkerProcess pid=1053) INFO 09-05 02:51:34 [model_runner.py:1537] Graph capturing finished in 48 secs, took 0.40 GiB
# INFO 09-05 02:51:34 [model_runner.py:1537] Graph capturing finished in 48 secs, took 0.40 GiB
# INFO 09-05 02:51:34 [llm_engine.py:424] init engine (profile, create kv cache, warmup model) took 64.45 seconds

# %% [markdown]
# Websearch pipeline

# %%
ws_pipeline = CustomQA(vllm)
await ws_pipeline.start()
REQUEST_STORAGE: dict[str, tuple[str, WorkerChatRequest, ModelPreOutput]] = {}

async def pre_inference_function(request: WorkerChatRequest) -> ModelPreOutput:
    prompt, pre_output = await ws_pipeline.pre_inference(
        request["text"],
        request["stream_id"],
        request["params"]
    ) 
    vllm.use_lora = request["model_id"] == "Qwen/Qwen3-4B-LoRA-v1"
    REQUEST_STORAGE[request["stream_id"]] = (prompt, request, pre_output)
    DataCollector.pre_output(pre_output)
    return pre_output

async def inference_function(stream_id: str) -> AsyncGenerator[str, None]:
    prompt, request, pre_output = REQUEST_STORAGE.pop(stream_id)
    vllm.use_lora = request["model_id"] == "Qwen/Qwen3-4B-LoRA-v1"
    generator = ws_pipeline.inference(prompt, request)
    total = ""
    try:
        async for chunk in generator:
            total += chunk
            yield chunk
    finally:
    # Store chat data when finish
        model_output: ModelOutput = {
            **pre_output,
            "answer_state": "successfully",
            "bot_summary": total[:50],
            "bot_keywords": [],
            "text": total
        }
        data: WorkerStoreChatData = {
            "forward_kwargs": request["forward_kwargs"],
            "model_output": model_output
        }
        DataCollector.model_output(data)
        DataCollector.backup(f"{BASE_PATH}/data_logs")
        await app.state.store_chat(data)

# %% [markdown]
# Connect to server

# %%
app = construct_app(
    server_domain=DOMAIN,
    info=CLIENT_INFO,
    pre_inference=pre_inference_function,
    inferece=inference_function,
    init_tasks=[],
    shutdown_tasks=[],
    is_local=False
)
# CORS policy
from fastapi.middleware.cors import CORSMiddleware
origins = [
    "http://127.0.0.1:8000",
    DOMAIN
]
app.add_middleware(
    CORSMiddleware,
    allow_origins=origins,
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"]
)
import nest_asyncio
import uvicorn
nest_asyncio.apply()
uvicorn.run(app, port=NGROK_PORT)
# Out:
# INFO:     Started server process [989]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8002 (Press CTRL+C to quit)
# Domain: https://345a43e47044.ngrok-free.app
# [Worker] Failed to update server info
# [Worker] Failed to update server info
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 70 | Prefix length: 2864 | kwargs: None
# INFO 09-05 02:54:51 [chat_utils.py:473] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# INFO 09-05 02:54:51 [async_llm_engine.py:209] Added request fb3e754162ce4c338175e6ffd14f08fd.
# INFO 09-05 02:54:51 [metrics.py:386] Avg prompt throughput: 5.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:54:52 [async_llm_engine.py:177] Finished request fb3e754162ce4c338175e6ffd14f08fd.
# {"type_search": "vector_db", "key_word": [{"school_id": "CNGT", "section": "diem_chuan"}]}
# [Retriever] Websearch: 6.88599s
# ---Original order ---
# Điểm chuẩn Trường Đại Học Công Nghệ – Đại Học Quốc Gia Hà Nội 2025 chính xác
# Điểm chuẩn Trường Đại học Công nghệ, ĐHQG Hà Nội 2023
# Điểm chuẩn Đại Học Công Nghệ - Đại Học Quốc Gia Hà Nội
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 848 | Prefix length: 1689 | kwargs: None
# INFO 09-05 02:54:59 [async_llm_engine.py:209] Added request 0509f09d8ea34ac681cd505dacc5eb45.
# INFO 09-05 02:54:59 [metrics.py:386] Avg prompt throughput: 110.0 tokens/s, Avg generation throughput: 4.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:04 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:09 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:13 [async_llm_engine.py:177] Finished request 0509f09d8ea34ac681cd505dacc5eb45.
# ---Reorder ---
# 1.00000 Điểm chuẩn Trường Đại Học Công Nghệ – Đại Học Quốc Gia Hà Nội 2025 chính xác
# Điểm chuẩn UET năm 2025 theo kết quả thi tốt nghiệp THPT, học bạ, Đánh giá năng lực, Đánh giá tư duy của Trường Đại Học Công Nghệ – Đại Học Quốc Gia Hà Nội chính xác nhất trên Diemthi.tuyensinh247.com
# 0.75000 Điểm chuẩn Trường Đại học Công nghệ, ĐHQG Hà Nội 2023
# Giấy phép số: 19/GP-CBC, cấp ngày 10/5/2024. Trụ sở: 16 Lê Hồng Phong - Ba Đình - Hà Nội.
# 0.50000 Điểm chuẩn Đại Học Công Nghệ - Đại Học Quốc Gia Hà Nội
# Cập nhật điểm chuẩn Đại Học Công Nghệ - Đại Học Quốc Gia Hà Nội mơi và đầy đủ nhất giúp các sỹ từ chuẩn bị hành trang tốt nhất vào trường mà mình mong ước
# [Retriever] Rerank page: 13.64535s
# Split 9668 characters to 9 chunks
# Split 1 pages to 9 chunks
# Split 30204 characters to 36 chunks
# Split 1 pages to 36 chunks
# Split 15147 characters to 14 chunks
# Split 1 pages to 14 chunks
# [Retriever] Split: 0.23400s
# [Retriever] Retrieve: 2.33138s
# [Retriever] Rerank chunk: 4.70940s
# [Retriever] Merge table: 0.00024s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 02:55:20 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 11.0 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/248feaa0-fe62-4ea6-9fd6-da6cd4a1c47f HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 10251 | Prefix length: 0 | kwargs: None
# INFO 09-05 02:55:22 [async_llm_engine.py:209] Added request 322e68ef4e00400c8912391e06a921fb.
# INFO 09-05 02:55:25 [metrics.py:386] Avg prompt throughput: 881.6 tokens/s, Avg generation throughput: 4.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:30 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:35 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:40 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:45 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:55:49 [async_llm_engine.py:177] Finished request 322e68ef4e00400c8912391e06a921fb.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 79 | Prefix length: 2864 | kwargs: None
# INFO 09-05 02:56:25 [async_llm_engine.py:209] Added request 738762e238734670aeaeba86c9a916c2.
# INFO 09-05 02:56:25 [metrics.py:386] Avg prompt throughput: 24.5 tokens/s, Avg generation throughput: 3.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:56:26 [async_llm_engine.py:177] Finished request 738762e238734670aeaeba86c9a916c2.
# {"type_search": "vector_db", "key_word": [{"school_id": "CT", "section": "thong_tin_chung"}]}
# [Page downloader] Timeout: https://uet.vnu.edu.vn/category/sinh-vien/hoc-phi-hoc-bong/
# [Processor] Timeout: File: https://uet.vnu.edu.vn/wp-content/uploads/2024/12/DS-cap-hoc-bong_ĐMKTKT.pdf
# [Retriever] Websearch: 45.53824s
# ---Original order ---
# Chương trình học bổng trao đổi tại Đại học Thanh Hoa, Trung Quốc - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Học phí và học bổng - Trường đại học khoa học và công nghệ Hà Nội
# Chính sách học bổng của USTH - Trường đại học khoa học và công nghệ Hà Nội
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 1167 | Prefix length: 1689 | kwargs: None
# INFO 09-05 02:57:12 [async_llm_engine.py:209] Added request 3c89943e18c0463d8485e7e11d2ff0a3.
# INFO 09-05 02:57:12 [metrics.py:386] Avg prompt throughput: 20.6 tokens/s, Avg generation throughput: 0.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:57:17 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:57:22 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:57:27 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:57:27 [async_llm_engine.py:177] Finished request 3c89943e18c0463d8485e7e11d2ff0a3.
# ---Reorder ---
# 0.95000 Chính sách học bổng của USTH - Trường đại học khoa học và công nghệ Hà Nội
# Hàng năm, USTH giành hàng tỷ đồng để trao Học bổng. Trong đó, nhiều sinh viên xuất sắc đã nhận được học bổng có giá trị lên tới 100% học phí toàn khóa học.
# 0.85000 Chương trình học bổng trao đổi tại Đại học Thanh Hoa, Trung Quốc - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Sinh viên có thể tìm hiểu kỹ các thông tin về chương trình trên, nếu đủ điều kiện và có nguyện vọng tham gia chương trình thì có thể nộp hồ sơ theo quy định tại Phòng Công tác sinh viên (Phòng 104-E3) trước 16h00, thứ Sáu ngày 04/04/2025.
# 0.75000 Học phí và học bổng - Trường đại học khoa học và công nghệ Hà Nội
# Hàng năm trường có học bổng và hỗ trợ tài chính theo chính sách nhà nước và theo quy chế của trường, chi tiết tham khảo tại website: https://usth.edu.vn ... Địa chỉ Tòa nhà A21, Viện Hàn Lâm Khoa học và Công nghệ Việt Nam, 18 Hoàng Quốc Việt, Cầu Giấy, Hà Nội...
# [Retriever] Rerank page: 15.83889s
# Split 10222 characters to 9 chunks
# Split 1 pages to 9 chunks
# Split 16914 characters to 13 chunks
# Split 1 pages to 32 chunks
# Split 7842 characters to 7 chunks
# Split 1 pages to 7 chunks
# [Retriever] Split: 0.42705s
# [Retriever] Retrieve: 1.64784s
# [Retriever] Rerank chunk: 3.45967s
# [Retriever] Merge table: 0.00021s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 02:57:33 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 2.7 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/b28da2f9-683c-4266-8453-d5ba3d9e0088 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 8587 | Prefix length: 0 | kwargs: None
# INFO 09-05 02:57:34 [async_llm_engine.py:209] Added request d820f79091854a91bf2530458ee8a036.
# INFO 09-05 02:57:38 [metrics.py:386] Avg prompt throughput: 656.7 tokens/s, Avg generation throughput: 20.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 3.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:57:43 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:57:47 [async_llm_engine.py:177] Finished request d820f79091854a91bf2530458ee8a036.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 45 | Prefix length: 2864 | kwargs: None
# INFO 09-05 02:58:18 [async_llm_engine.py:209] Added request ad3d71bda42e4d61ab07c41d662b4141.
# INFO 09-05 02:58:18 [metrics.py:386] Avg prompt throughput: 27.8 tokens/s, Avg generation throughput: 3.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:58:19 [async_llm_engine.py:177] Finished request ad3d71bda42e4d61ab07c41d662b4141.
# {"type_search": "vector_db", "key_word": [{"school_id": "NEU", "section": "thong_tin_chung"}]}
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/2fe9791b-b898-421d-9903-24aaa705c468 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 641 | Prefix length: 0 | kwargs: None
# INFO 09-05 02:58:20 [async_llm_engine.py:209] Added request 6b4bbed67e8740ad9efeaf4d403822fe.
# INFO 09-05 02:58:23 [metrics.py:386] Avg prompt throughput: 68.1 tokens/s, Avg generation throughput: 29.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:58:28 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 32.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:58:29 [async_llm_engine.py:177] Finished request 6b4bbed67e8740ad9efeaf4d403822fe.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 60 | Prefix length: 2864 | kwargs: None
# INFO 09-05 02:58:40 [async_llm_engine.py:209] Added request f4f0279dbcd1422f93fb47da38156fbe.
# INFO 09-05 02:58:40 [metrics.py:386] Avg prompt throughput: 81.8 tokens/s, Avg generation throughput: 2.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:58:41 [async_llm_engine.py:177] Finished request f4f0279dbcd1422f93fb47da38156fbe.
# {"type_search": "vector_db", "key_word": [{"school_id": "KINH_TE_QUOC_DAN", "section": "thong_tin_chung"}]}
# [Page download] Error 403
# [Page download] Error 404
# [Page downloader] Timeout: https://dsa.ueh.edu.vn/tin-tuc/kq-dk-kkht-hkd-2024/
# [Retriever] Websearch: 16.25400s
# ---Original order ---
# Học Phí NEU 2024 – 2025 Khóa K66 Và Chính sách Học Bổng
# Thủ khoa đầu ra Trường ĐH Kinh tế Quốc dân và bí quyết đạt 3 học bổng du học
# Trường đại học Kinh tế quốc dân trao học bổng toàn phần cho các sinh viên đạt danh hiệu Thủ khoa năm 2024
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 989 | Prefix length: 1689 | kwargs: None
# INFO 09-05 02:58:58 [async_llm_engine.py:209] Added request 759c7537b4de448da12762500528629a.
# INFO 09-05 02:58:58 [metrics.py:386] Avg prompt throughput: 52.5 tokens/s, Avg generation throughput: 2.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:03 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:08 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:13 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:13 [async_llm_engine.py:177] Finished request 759c7537b4de448da12762500528629a.
# ---Reorder ---
# 0.95000 Trường đại học Kinh tế quốc dân trao học bổng toàn phần cho các sinh viên đạt danh hiệu Thủ khoa năm 2024
# Cũng tại buổi lễ, Hiệu trưởng Trường đại học Kinh tế quốc dân đã quyết định cấp học bổng toàn phần cho 5 tân sinh viên đạt danh hiệu thủ khoa đầu khoá 66. Đồng thời, trao nhiều suất học bổng cho các sinh viên đạt thành ...
# 0.85000 Học Phí NEU 2024 – 2025 Khóa K66 Và Chính sách Học Bổng
# Đại học Kinh tế Quốc dân là một trong những trường đào tạo kinh tế hàng đầu Việt Nam. Vậy học phí NEU 2024 K66 bao nhiêu? Chính sách học bổng ra sao? Xem ngay!
# 0.75000 Thủ khoa đầu ra Trường ĐH Kinh tế Quốc dân và bí quyết đạt 3 học bổng du học
# Vượt qua áp lực do bị từ chối trong lần xin học bổng đầu tiên, Hà Giang vẫn nỗ lực giành liên tiếp học bổng du học tại 3 quốc gia Phần Lan, Ý và Vương quốc Anh.
# [Retriever] Rerank page: 15.68808s
# Split 42722 characters to 47 chunks
# Split 1 pages to 47 chunks
# Split 35954 characters to 30 chunks
# Split 1 pages to 30 chunks
# Split 21747 characters to 18 chunks
# Split 1 pages to 18 chunks
# [Retriever] Split: 0.43498s
# [Retriever] Retrieve: 3.01850s
# [Retriever] Rerank chunk: 3.38993s
# [Retriever] Merge table: 0.00022s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 02:59:20 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 1.3 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/a1d34938-a6ed-4680-ab32-c3bf94058428 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 8217 | Prefix length: 0 | kwargs: None
# INFO 09-05 02:59:21 [async_llm_engine.py:209] Added request 51ffa108bd6544f2b8e5eb5eeb2ee2bb.
# INFO 09-05 02:59:25 [metrics.py:386] Avg prompt throughput: 625.3 tokens/s, Avg generation throughput: 19.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 3.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:30 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 31.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 3.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:35 [async_llm_engine.py:177] Finished request 51ffa108bd6544f2b8e5eb5eeb2ee2bb.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "GET /info HTTP/1.1" 200 OK
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 65 | Prefix length: 2864 | kwargs: None
# INFO 09-05 02:59:43 [async_llm_engine.py:209] Added request e6748bea5ae444779ab64d04e952302a.
# INFO 09-05 02:59:43 [metrics.py:386] Avg prompt throughput: 75.0 tokens/s, Avg generation throughput: 11.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:44 [async_llm_engine.py:177] Finished request e6748bea5ae444779ab64d04e952302a.
# {"type_search": "vector_db", "key_word": [{"school_id": "HUST", "section": "tuyen_sinh"}]}
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/d74c5781-b03f-4039-9a98-c29d90b5f74c HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 8097 | Prefix length: 0 | kwargs: None
# INFO 09-05 02:59:45 [async_llm_engine.py:209] Added request ce7a7d55290041beba4c28b59bd00b6f.
# INFO 09-05 02:59:48 [metrics.py:386] Avg prompt throughput: 704.8 tokens/s, Avg generation throughput: 22.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:53 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 31.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 02:59:58 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:04 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:09 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:14 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.9%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:19 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:22 [async_llm_engine.py:177] Finished request ce7a7d55290041beba4c28b59bd00b6f.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 48 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:00:29 [async_llm_engine.py:209] Added request 0fcd00e03ea04ae2a5f4179eac54e814.
# INFO 09-05 03:00:30 [metrics.py:386] Avg prompt throughput: 89.1 tokens/s, Avg generation throughput: 10.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:30 [async_llm_engine.py:177] Finished request 0fcd00e03ea04ae2a5f4179eac54e814.
# {"type_search": "vector_db", "key_word": [{"school_id": "NEU", "section": "tuyen_sinh"}]}
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/725da622-0f38-4177-9316-8aab5a01d925 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 1520 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:00:31 [async_llm_engine.py:209] Added request 51194f12ae0d4e8f89c7dd4a9b203ee6.
# INFO 09-05 03:00:35 [metrics.py:386] Avg prompt throughput: 117.4 tokens/s, Avg generation throughput: 28.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:39 [async_llm_engine.py:177] Finished request 51194f12ae0d4e8f89c7dd4a9b203ee6.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 82 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:00:51 [async_llm_engine.py:209] Added request e773b2de93b34466ae18ebca58409deb.
# INFO 09-05 03:00:52 [metrics.py:386] Avg prompt throughput: 57.6 tokens/s, Avg generation throughput: 8.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:00:53 [async_llm_engine.py:177] Finished request e773b2de93b34466ae18ebca58409deb.
# {"type_search": "vector_db", "key_word": [{"school_id": "Kinh_te_QD", "section": "tuyen_sinh"}]}
# Không thể tải xuống pdf từ https://neu.edu.vn/Resources/Docs/SubDomain/HomePage/ThongBao/2025/Thang%201/%C4%90%E1%BB%81%20%C3%A1n%20TS%C4%90H%20n%C4%83m%202025.pdf
# [Processor] Timeout: File: https://images.tuyensinh247.com/picture/2025/0527/hktqd-neu_1.pdf
# [Processor] Timeout: File: https://images.tuyensinh247.com/picture/2025/0521/ke-hoach-tuyen-sinh-dai-hoc-kinh-te-quoc-dan-2025.pdf
# [Retriever] Websearch: 25.09865s
# ---Original order ---
# Phương thức, chỉ tiêu tuyển sinh 2025 của Đại học Kinh tế Quốc dân (NEU)
# TUYỂN SINH 2024: Chỉ tiêu, pphương thức xét tuyển của Trường Đại học Kinh tế Quốc dân
# Năm 2025, Trường ĐH Kinh tế Quốc dân giảm chỉ tiêu tuyển sinh bằng kết quả thi tốt nghiệp THPT, chỉ xét 4 tổ hợp
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 1125 | Prefix length: 1689 | kwargs: None
# INFO 09-05 03:01:18 [async_llm_engine.py:209] Added request aed023715e534b3889a75c116c666ea1.
# INFO 09-05 03:01:18 [metrics.py:386] Avg prompt throughput: 37.6 tokens/s, Avg generation throughput: 1.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:01:23 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:01:28 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:01:33 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:01:34 [async_llm_engine.py:177] Finished request aed023715e534b3889a75c116c666ea1.
# ---Reorder ---
# 0.95000 Năm 2025, Trường ĐH Kinh tế Quốc dân giảm chỉ tiêu tuyển sinh bằng kết quả thi tốt nghiệp THPT, chỉ xét 4 tổ hợp
# Năm 2025, Trường Đại học Kinh tế Quốc dân giảm thêm 3% chỉ tiêu xét kết quả thi tốt nghiệp THPT (từ 18% năm 2024 xuống còn 15% năm 2025) và chỉ xét tuyển 4 tổ hợp A00, A01, D01, D07. Phần chỉ tiêu này được đưa vào phương thức xét ...
# 0.85000 Phương thức, chỉ tiêu tuyển sinh 2025 của Đại học Kinh tế Quốc dân (NEU)
# Xét tuyển kết hợp áp dụng với tất cả các mã tuyển sinh năm 2025 và cho các thí sinh như sau:(1) Thí sinh có chứng chỉ quốc tế SAT từ 1200 điểm trở lên hoặc ACT từ 26 điểm trở lên được các tổ chức quốc tế cấp từ ngày 01/6/2023 ...
# 0.75000 TUYỂN SINH 2024: Chỉ tiêu, pphương thức xét tuyển của Trường Đại học Kinh tế Quốc dân
# Trường Đại học Kinh tế Quốc dân công bố Đề án tuyển sinh Đại học chính quy năm 2024 với tổng chỉ tiêu dự kiến gần 7000, trong đó có 6 ngành/chương trình mới mở.
# [Retriever] Rerank page: 16.26888s
# Split 14628 characters to 12 chunks
# Split 1 pages to 12 chunks
# Split 31170 characters to 31 chunks
# Split 1 pages to 31 chunks
# Split 21846 characters to 24 chunks
# Split 1 pages to 24 chunks
# [Retriever] Split: 0.26811s
# [Retriever] Retrieve: 2.26543s
# [Retriever] Rerank chunk: 3.43498s
# [Retriever] Merge table: 0.00020s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 03:01:40 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 4.4 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/89852be2-cc4d-444b-9768-e3e2e35ec894 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 9661 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:01:41 [async_llm_engine.py:209] Added request 3f92d81fe27346e785754f4af2a2c665.
# INFO 09-05 03:01:45 [metrics.py:386] Avg prompt throughput: 841.6 tokens/s, Avg generation throughput: 16.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:01:50 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:01:55 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:01:55 [async_llm_engine.py:177] Finished request 3f92d81fe27346e785754f4af2a2c665.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 58 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:02:03 [async_llm_engine.py:209] Added request 4a6b3a1a06a94355a43ab3c8a5d5df04.
# INFO 09-05 03:02:03 [metrics.py:386] Avg prompt throughput: 120.9 tokens/s, Avg generation throughput: 1.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:02:04 [async_llm_engine.py:177] Finished request 4a6b3a1a06a94355a43ab3c8a5d5df04.
# {"type_search": "vector_db", "key_word": [{"school_id": "DHTN", "section": "thong_tin_chung"}]}
# [Page download] Error 403
# [Page download] Error 403
# [Retriever] Websearch: 41.80301s
# ---Original order ---
# Trường Đại học Ngoại Thương
# Thông tin tuyển sinh trường Đại học Ngoại thương tpHCM
# Review trường Đại học Ngoại thương (FTU) – Lựa chọn hàng đầu cho giấc mơ kinh tế
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 1040 | Prefix length: 1689 | kwargs: None
# INFO 09-05 03:02:46 [async_llm_engine.py:209] Added request 162305ce003e4b77ac28260fa3e77561.
# INFO 09-05 03:02:46 [metrics.py:386] Avg prompt throughput: 21.0 tokens/s, Avg generation throughput: 0.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:02:51 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:02:56 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:02:58 [async_llm_engine.py:177] Finished request 162305ce003e4b77ac28260fa3e77561.
# ---Reorder ---
# 1.00000 Trường Đại học Ngoại Thương
# Trường Đại học Ngoại thương là trường đại học công lập của Việt Nam, trực thuộc Bộ Giáo dục và Đào tạo, trụ sở tại 91 phố Chùa Láng, phường Láng Thượng, quận Đống Đa, thủ đô Hà Nội.
# 0.70000 Thông tin tuyển sinh trường Đại học Ngoại thương tpHCM
# Thông tin tuyển sinh năm 2025 chi tiết của Trường Đại học Ngoại thương (TP.HCM) về ngành nghề đào tạo, chỉ tiêu giúp các thí sinh năm được và chọn trường phù hợp.
# [Retriever] Rerank page: 11.64259s
# Split 68975 characters to 67 chunks
# Split 1 pages to 92 chunks
# Split 14897 characters to 13 chunks
# Split 1 pages to 13 chunks
# [Retriever] Split: 0.50896s
# [Retriever] Retrieve: 3.40884s
# [Retriever] Rerank chunk: 3.87065s
# [Retriever] Merge table: 0.00032s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 03:03:05 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 5.0 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/bff9fd15-981e-4168-b42a-f1c9cee6f9d1 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 10799 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:03:06 [async_llm_engine.py:209] Added request 6fa3d64f29bd4130a18258959b7518f5.
# INFO 09-05 03:03:10 [metrics.py:386] Avg prompt throughput: 869.1 tokens/s, Avg generation throughput: 16.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:03:15 [async_llm_engine.py:177] Finished request 6fa3d64f29bd4130a18258959b7518f5.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 85 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:03:21 [async_llm_engine.py:209] Added request 59fa307f0fac4b609e41ee8fbea21416.
# INFO 09-05 03:03:22 [metrics.py:386] Avg prompt throughput: 88.9 tokens/s, Avg generation throughput: 12.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:03:22 [async_llm_engine.py:177] Finished request 59fa307f0fac4b609e41ee8fbea21416.
# {"type_search": "vector_db", "key_word": [{"school_id": "PTIT", "section": "tuyen_sinh"}]}
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/32b1b761-12f3-4b9e-811f-381dcf38abd8 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 5633 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:03:23 [async_llm_engine.py:209] Added request 8071bfee1ea84e07922943d1442f9091.
# INFO 09-05 03:03:27 [metrics.py:386] Avg prompt throughput: 437.7 tokens/s, Avg generation throughput: 24.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 2.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:03:32 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 31.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 2.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:03:34 [async_llm_engine.py:177] Finished request 8071bfee1ea84e07922943d1442f9091.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 49 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:04:06 [async_llm_engine.py:209] Added request af77458075334636b3710f11668e3240.
# INFO 09-05 03:04:06 [metrics.py:386] Avg prompt throughput: 28.3 tokens/s, Avg generation throughput: 1.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:04:07 [async_llm_engine.py:177] Finished request af77458075334636b3710f11668e3240.
# {"type_search": "vector_db", "key_word": [{"school_id": "DHNH", "section": "thong_tin_chung"}]}
# [Page download] Error 403
# [Page download] Error 403
# [Retriever] Websearch: 11.47960s
# ---Original order ---
# Trường Đại học Ngoại Thương
# Thông tin tuyển sinh trường Đại học Ngoại thương tpHCM
# ĐIỂM CHUẨN Trường Đại học Ngoại thương (FTU) 2024
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 905 | Prefix length: 1689 | kwargs: None
# INFO 09-05 03:04:19 [async_llm_engine.py:209] Added request 5c76242eb9d84b279bc9e64da7da80ae.
# INFO 09-05 03:04:19 [metrics.py:386] Avg prompt throughput: 68.1 tokens/s, Avg generation throughput: 2.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:04:24 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:04:29 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:04:31 [async_llm_engine.py:177] Finished request 5c76242eb9d84b279bc9e64da7da80ae.
# ---Reorder ---
# 1.00000 Trường Đại học Ngoại Thương
# Trường Đại học Ngoại thương là trường đại học công lập của Việt Nam, trực thuộc Bộ Giáo dục và Đào tạo, trụ sở tại 91 phố Chùa Láng, phường Láng Thượng, quận Đống Đa, thủ đô Hà Nội.
# 0.70000 Thông tin tuyển sinh trường Đại học Ngoại thương tpHCM
# Thông tin tuyển sinh năm 2025 chi tiết của Trường Đại học Ngoại thương (TP.HCM) về ngành nghề đào tạo, chỉ tiêu giúp các thí sinh năm được và chọn trường phù hợp.
# [Retriever] Rerank page: 12.08526s
# Split 68975 characters to 67 chunks
# Split 1 pages to 92 chunks
# Split 14897 characters to 13 chunks
# Split 1 pages to 13 chunks
# [Retriever] Split: 0.47808s
# [Retriever] Retrieve: 3.45520s
# [Retriever] Rerank chunk: 4.10910s
# [Retriever] Merge table: 0.00023s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 03:04:39 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 6.2 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/b299a4b8-9c76-4ef1-b3f8-e972e6616153 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 9290 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:04:40 [async_llm_engine.py:209] Added request 7fcbabd2eda64cff9995293a47e3db53.
# INFO 09-05 03:04:44 [metrics.py:386] Avg prompt throughput: 781.2 tokens/s, Avg generation throughput: 18.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:04:49 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:04:50 [async_llm_engine.py:177] Finished request 7fcbabd2eda64cff9995293a47e3db53.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 35 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:04:56 [async_llm_engine.py:209] Added request f79d397e24b842ae82eebf2a3f123019.
# INFO 09-05 03:04:57 [metrics.py:386] Avg prompt throughput: 123.5 tokens/s, Avg generation throughput: 3.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:04:58 [async_llm_engine.py:177] Finished request f79d397e24b842ae82eebf2a3f123019.
# {"type_search": "vector_db", "key_word": [{"school_id": "FTU", "section": "thong_tin_chung"}]}
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/e42d4394-32aa-4de9-9a96-6ac81cbbfd4d HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 579 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:04:58 [async_llm_engine.py:209] Added request 8e124a8108634b91867de6bbae23a0f5.
# INFO 09-05 03:05:02 [metrics.py:386] Avg prompt throughput: 61.3 tokens/s, Avg generation throughput: 29.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:05:07 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 31.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:05:08 [async_llm_engine.py:177] Finished request 8e124a8108634b91867de6bbae23a0f5.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 125 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:06:35 [async_llm_engine.py:209] Added request e7bc1e5d0f704d57b651e747b45bc78c.
# INFO 09-05 03:06:35 [metrics.py:386] Avg prompt throughput: 11.3 tokens/s, Avg generation throughput: 0.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:06:36 [async_llm_engine.py:177] Finished request e7bc1e5d0f704d57b651e747b45bc78c.
# {"type_search": "vector_db", "key_word": [{"school_id": "BCT", "section": "thong_tin_chung"}]}
# [Retriever] Websearch: 34.05136s
# ---Original order ---
# Tìm hiểu về ngành Công nghệ thông tin tại Học viện Công nghệ Bưu chính Viễn thông - Học Viện Công Nghệ Bưu Chính Viễn Thông Cơ sở TP. Hồ Chí Minh
# Chương trình giáo dục đại học cử nhân ngành Công nghệ thông tin
# Ngành Công nghệ Thông tin - Học viện công nghệ bưu chính viễn thông
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 1143 | Prefix length: 1689 | kwargs: None
# INFO 09-05 03:07:10 [async_llm_engine.py:209] Added request f374fde9c1e64522b18d31e764748be3.
# INFO 09-05 03:07:10 [metrics.py:386] Avg prompt throughput: 26.2 tokens/s, Avg generation throughput: 0.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:07:15 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:07:20 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:07:25 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:07:26 [async_llm_engine.py:177] Finished request f374fde9c1e64522b18d31e764748be3.
# ---Reorder ---
# 1.00000 Chương trình giáo dục đại học cử nhân ngành Công nghệ thông tin
# Chương trình giáo dục đại học cử nhân ngành Công nghệ thông tin (định hướng ứng dụng) trình độ đại học hệ chính quy đào tạo tại Học viện.
# 0.80000 Tìm hiểu về ngành Công nghệ thông tin tại Học viện Công nghệ Bưu chính Viễn thông - Học Viện Công Nghệ Bưu Chính Viễn Thông Cơ sở TP. Hồ Chí Minh
# Dựa trên các thành tựu đột phá trong các lĩnh vực công nghệ thông tin, công nghệ sinh học, công nghệ nano, cuộc cách mạng công nghiệp lần thứ tư được cho là đã bắt đầu từ vài năm gần đây, tập trung chủ yếu vào sản xuất thông ...
# 0.60000 Ngành Công nghệ Thông tin - Học viện công nghệ bưu chính viễn thông
# ... Học viện tuyển sinh trên phạm vi cả nước. ... Năm 2023, Học viện Công nghệ Bưu chính Viễn thông sử dụng kết quả kỳ thi THPT 2021, 2022 hoặc kết quả 03 năm học THPT với các môn tương ứng với tổ hợp môn xét tuyển để thực ...
# [Retriever] Rerank page: 15.63387s
# Split 26589 characters to 21 chunks
# Split 1 pages to 24 chunks
# Split 35566 characters to 27 chunks
# Split 1 pages to 27 chunks
# Split 17853 characters to 13 chunks
# Split 1 pages to 13 chunks
# [Retriever] Split: 0.29643s
# [Retriever] Retrieve: 2.11267s
# [Retriever] Rerank chunk: 3.99543s
# [Retriever] Merge table: 0.00020s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 03:07:32 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 1.3 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/2786c658-3d14-4eb9-a689-6f1b4cba23da HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 10537 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:07:33 [async_llm_engine.py:209] Added request 94f078544e61416f99253dc8c3771a0f.
# INFO 09-05 03:07:37 [metrics.py:386] Avg prompt throughput: 741.1 tokens/s, Avg generation throughput: 18.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:07:42 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:07:46 [async_llm_engine.py:177] Finished request 94f078544e61416f99253dc8c3771a0f.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 53 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:07:53 [async_llm_engine.py:209] Added request 33bf4d3825074910a83074fbe7981a0d.
# INFO 09-05 03:07:53 [metrics.py:386] Avg prompt throughput: 87.7 tokens/s, Avg generation throughput: 11.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:07:54 [async_llm_engine.py:177] Finished request 33bf4d3825074910a83074fbe7981a0d.
# {"type_search": "vector_db", "key_word": [{"school_id": "UET", "section": "tuyen_sinh"}]}
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/882a73ad-ebf6-4b20-bc2b-db4f6f1d2c6c HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 4424 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:07:55 [async_llm_engine.py:209] Added request b06654e55a8643e18908ca1286e86c9d.
# INFO 09-05 03:07:58 [metrics.py:386] Avg prompt throughput: 337.9 tokens/s, Avg generation throughput: 26.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 2.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:08:03 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 31.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 2.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:08:04 [async_llm_engine.py:177] Finished request b06654e55a8643e18908ca1286e86c9d.
# [WS] k_pages: 5 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 53 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:08:38 [async_llm_engine.py:209] Added request 3494e40c71674ee9b2bfc354490bacb1.
# INFO 09-05 03:08:39 [metrics.py:386] Avg prompt throughput: 27.8 tokens/s, Avg generation throughput: 0.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:08:40 [async_llm_engine.py:177] Finished request 3494e40c71674ee9b2bfc354490bacb1.
# {"type_search": "vector_db", "key_word": [{"school_id": "UET", "section": "tuyen_sinh"}]}
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/a1a5b5d0-ccfb-44ee-b863-b59696ddc45d HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 4424 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:08:40 [async_llm_engine.py:209] Added request 2d5c8ba31d314310b3b7073719078a07.
# INFO 09-05 03:08:44 [metrics.py:386] Avg prompt throughput: 339.5 tokens/s, Avg generation throughput: 26.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 2.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:08:49 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 31.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 2.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:08:50 [async_llm_engine.py:177] Finished request 2d5c8ba31d314310b3b7073719078a07.
# [WS] k_pages: 3 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 112 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:11:40 [async_llm_engine.py:209] Added request 76a9d74a2a8e4e6ea3d88b4c917e5017.
# INFO 09-05 03:11:40 [metrics.py:386] Avg prompt throughput: 5.8 tokens/s, Avg generation throughput: 0.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:11:41 [async_llm_engine.py:177] Finished request 76a9d74a2a8e4e6ea3d88b4c917e5017.
# {"type_search": "vector_db", "key_word": [{"school_id": "HCTBVP", "section": "tuyen_sinh"}]}
# Lỗi khi xử lý PDF https://portal.ptit.edu.vn/wp-content/uploads/2023/04/Thong-bao-tuyen-sinh-%C4%90HCQ-2023.pdf: File không phải là PDF: /tmp/tmp9tkpcxfa.pdf
# [Retriever] Websearch: 3.81050s
# ---Original order ---
# Thông báo Ngưỡng điểm xét đủ điều kiện trúng tuyển vào đại học hệ chính quy năm 2024 theo Phương thức xét tuyển dựa vào kết quả trong các kỳ thi đánh giá năng lực (ĐGNL), đánh giá tư duy (ĐGTD) và Phương thức xét tuyển kết hợp
# Điểm chuẩn đánh giá năng lực Học viện Công nghệ bưu chính viễn thông cao nhất 20,65 điểm
# PTIT – Tuyển sinh
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 1264 | Prefix length: 1689 | kwargs: None
# INFO 09-05 03:11:45 [async_llm_engine.py:209] Added request 7d4f66ac3ab946d4bb18d7faa9872fdf.
# INFO 09-05 03:11:45 [metrics.py:386] Avg prompt throughput: 199.1 tokens/s, Avg generation throughput: 6.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:11:50 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:11:55 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 34.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:12:00 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 34.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.7%, CPU KV cache usage: 0.0%.
# ...
# INFO 09-05 03:45:10 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:15 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.9%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:15 [async_llm_engine.py:177] Finished request f4438b1d78f4492bad69e93ba45535ca.
# ---Reorder ---
# 0.95000 Danh sách giảng viên cơ hữu tính đến tháng 2/2020 - Thông tin tuyển sinh 2024
# Trường Đại học Công nghệ, ĐHQGHN (VNU-UET)
# 0.85000 Viện trí tuệ nhân tạo - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Giới thiệu Viện Trí tuệ nhân tạo Tổng quan Viện Trí tuệ nhân tạo được thành lập theo quyết định số 162/QĐ-TCCB, ngày 18/03/2022 của Hiệu trưởng Trường Đại học Công nghệ. Tên tiếng Anh: Institute for Artificial Intelligence (IAI).
# 0.75000 Chương trình đào tạo ngành Trí tuệ nhân tạo - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# 1. Tóm tắt yêu cầu chương trình đào tạo Tổng số tín chỉ của chương trình đào tạo (Chưa tính các học phần Giáo dục thể chất, Giáo dục quốc phòng – an ninh, Kỹ năng bổ trợ): 123 tín chỉ – Khối kiến thức chung (Chưa tính các ...
# 0.55000 Danh sách Giảng viên cơ hữu
# CTU English · Danh sách Giảng viên cơ hữu · Gửi Email bài này · GIẢNG VIÊN CƠ HỮU · (Nhấp vào tên để xem lý lịch khoa học) · Đội ngủ cán bộ · Danh sách cán bộ cơ hữu hành chính văn phòng · 28 Tháng 9 2021 · CÁN BỘ VĂN PHÒNG · đọc ...
# [Retriever] Rerank page: 20.53276s
# Split 9830 characters to 10 chunks
# Split 1 pages to 10 chunks
# Split 23073 characters to 17 chunks
# Split 1 pages to 17 chunks
# Split 21232 characters to 17 chunks
# Split 1 pages to 17 chunks
# Split 19861 characters to 20 chunks
# Split 1 pages to 20 chunks
# [Retriever] Split: 0.33736s
# [Retriever] Retrieve: 2.18345s
# [Retriever] Rerank chunk: 3.54338s
# [Retriever] Merge table: 0.00016s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 03:45:21 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.6 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/c8543247-9033-4dd3-952c-676dcf0d817e HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 11917 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:45:22 [async_llm_engine.py:209] Added request c4669ebfb9ee40acb516e409172517c8.
# INFO 09-05 03:45:26 [metrics.py:386] Avg prompt throughput: 1022.2 tokens/s, Avg generation throughput: 13.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:31 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:36 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:41 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:46 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:51 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:45:56 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:01 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 7.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:06 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 7.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:11 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 7.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:16 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 7.5%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:21 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 7.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:26 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 7.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:31 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 8.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:46:32 [async_llm_engine.py:177] Finished request c4669ebfb9ee40acb516e409172517c8.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "GET /info HTTP/1.1" 200 OK
# [WS] k_pages: 4 | k_docs 5 | domain_restrict: False
# [VLLM] Invalid model id router. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.ROUTER | Instruction length: 164 | Prompt length: 97 | Prefix length: 2864 | kwargs: None
# INFO 09-05 03:48:02 [async_llm_engine.py:209] Added request e7d6a3203db8481e98f0dbc74647e292.
# INFO 09-05 03:48:02 [metrics.py:386] Avg prompt throughput: 10.9 tokens/s, Avg generation throughput: 0.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:48:03 [async_llm_engine.py:177] Finished request e7d6a3203db8481e98f0dbc74647e292.
# {"type_search": "web_search", "key_word": ["danh sách giảng viên cơ hữu viện trí tuệ nhân tạo đại học công nghệ"]}
# [Retriever] Websearch: 15.36711s
# ---Original order ---
# Đội ngũ giảng viên - Faculty of Information Technology - VNUHCM-University of Science
# Chương trình Trí tuệ nhân tạo – Phòng Đào tạo Sau đại học
# Giảng viên - Khoa Công Nghệ Thông Tin - Trường Đại học Công Nghệ - Đại Học Quốc Gia Hà Nội -
# Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# [VLLM] Invalid model id ranker. List of valid models: ['Qwen/Qwen3-4B', 'reader']
# [VLLM] CallType.RERANK | Instruction length: 100 | Prompt length: 1581 | Prefix length: 1689 | kwargs: None
# INFO 09-05 03:48:18 [async_llm_engine.py:209] Added request af088598c37b4470bff26707ffed87c9.
# INFO 09-05 03:48:19 [metrics.py:386] Avg prompt throughput: 64.4 tokens/s, Avg generation throughput: 1.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:48:24 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.4%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:48:29 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.6%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:48:34 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 35.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 1.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:48:37 [async_llm_engine.py:177] Finished request af088598c37b4470bff26707ffed87c9.
# ---Reorder ---
# 0.95000 Đội ngũ giảng viên - Faculty of Information Technology - VNUHCM-University of Science
# Lê Trung Nghĩa hiện đang là ... Công Nghệ Tri Thức. Ông tốt nghiệp tiến sĩ ngành khoa học máy tính tại viện National Institute of Informatics (NII), Nhật Bản và có nhiều bài báo khoa học được công bố ở các tạp chí, hội nghị quốc tế có chất lượng cao. ... Lập trình cho trí tuệ nhân tạo ...
# 0.85000 Chương trình Trí tuệ nhân tạo – Phòng Đào tạo Sau đại học
# Đội ngũ giảng viên của chương trình bao gồm 1 GS, 7 PGS và 29 TS. Ngoài ra, chương trình còn hợp tác với các giảng viên đầu ngành trong và ngoài nước như JAIST, NII (Nhật Bản), Lyon 1 (Pháp) và UTA (Hoa Kỳ). Cơ sở vật ...
# 0.75000 Giảng viên - Khoa Công Nghệ Thông Tin - Trường Đại học Công Nghệ - Đại Học Quốc Gia Hà Nội -
# Khoa Công nghệ Thông tin hiện có gần 100 cán bộ giảng dạy và nghiên cứu, bao gồm 1 Giáo sư, 16 Phó Giáo sư và hơn 50% số cán bộ có trình độ tiến sỹ được đào tạo bài bản tại các trường đại học và viện nghiên cứu uy tín từ ...
# 0.65000 Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Trường Đại học Công nghệ hiện có 328 cán bộ trong đó có 258 giảng viên, trợ giảng, nghiên cứu viên và 70 cán bộ hành chính, phục vụ. Nhà trường luôn tự hào có đội ngũ cán bộ, giảng viên, nghiên cứu viên trình độ cao có học ...
# [Retriever] Rerank page: 18.67631s
# Split 37001 characters to 26 chunks
# Split 1 pages to 26 chunks
# Split 24792 characters to 20 chunks
# Split 1 pages to 20 chunks
# Split 13359 characters to 11 chunks
# Split 1 pages to 11 chunks
# Split 25637 characters to 20 chunks
# Split 1 pages to 20 chunks
# [Retriever] Split: 0.42833s
# [Retriever] Retrieve: 2.57303s
# [Retriever] Rerank chunk: 4.45768s
# [Retriever] Merge table: 0.00029s
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO 09-05 03:48:44 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.6 tokens/s, Running: 0 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 0.0%, CPU KV cache usage: 0.0%.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "POST /inference/d41d13f2-e762-4f0a-9572-ddb6730328e4 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 320 | Prompt length: 24964 | Prefix length: 0 | kwargs: None
# INFO 09-05 03:48:46 [async_llm_engine.py:209] Added request cb33bdda51cd4cd4994c3d46e6fa1079.
# INFO 09-05 03:48:50 [metrics.py:386] Avg prompt throughput: 1674.8 tokens/s, Avg generation throughput: 0.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 9.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:48:55 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 9.7%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:00 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 9.8%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:05 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 9.9%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:10 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 9.9%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:15 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 10.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:20 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 11.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 10.0%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:25 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 10.1%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:30 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 10.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 10.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:35 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 11.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 10.2%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:40 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 11.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 10.3%, CPU KV cache usage: 0.0%.
# INFO 09-05 03:49:44 [async_llm_engine.py:177] Finished request cb33bdda51cd4cd4994c3d46e6fa1079.
# INFO:     2a09:bac5:d45a:16dc::247:e0:0 - "GET /info HTTP/1.1" 200 OK
# INFO:     Shutting down
# (VllmWorkerProcess pid=1053) INFO 09-05 04:13:27 [multiproc_worker_utils.py:260] Worker exiting
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_989/591691003.py in <cell line: 0>()
#      24 import uvicorn
#      25 nest_asyncio.apply()
# ---> 26 uvicorn.run(app, port=NGROK_PORT)
#      27
#      28
#
# /usr/local/lib/python3.11/dist-packages/uvicorn/main.py in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     578             Multiprocess(config, target=server.run, sockets=[sock]).run()
#     579         else:
# --> 580             server.run()
#     581     except KeyboardInterrupt:
#     582         pass  # pragma: full coverage
#
# /usr/local/lib/python3.11/dist-packages/uvicorn/server.py in run(self, sockets)
#      64     def run(self, sockets: list[socket.socket] | None = None) -> None:
#      65         self.config.setup_event_loop()
# ---> 66         return asyncio.run(self.serve(sockets=sockets))
#      67
#      68     async def serve(self, sockets: list[socket.socket] | None = None) -> None:
#
# /usr/local/lib/python3.11/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.11/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      94                     break
#      95             if not f.done():
# ---> 96                 raise RuntimeError(
#      97                     'Event loop stopped before Future completed.')
#      98             return f.result()
#
# RuntimeError: Event loop stopped before Future completed.
# ERROR 09-05 04:13:29 [multiproc_worker_utils.py:121] Worker VllmWorkerProcess pid 1053 died, exit code: -15
# INFO 09-05 04:13:29 [multiproc_worker_utils.py:125] Killing local vLLM worker processes

# %% [markdown]
# ###### Note
# If the instruction is too long -> freeze. Seem like vLLM cache instruction, but we still don't know why it only freeze after some requests. (Seem like cache problem, use llm serve would cause it)
