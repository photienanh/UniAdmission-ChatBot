# %%
from web_search import Websearch
import os

# %%
ws = Websearch(
    "intfloat/multilingual-e5-small",
    "Qwen/Qwen3-4B",
    "ms-marco-MultiBERT-L-12",
    "cpu",
    chunk_size=512,
    chunk_overlap=16
)
await ws.start()

# %%
os.environ["BRAVE_SEARCH_API_KEY"] = "BSAbUIq8YC6VrPhwp688ST6Vtz7cyrH"
os.environ["WEB_SEARCH_SSL"] = str(False)

# %%
web_query = "danh sách giảng viên viện trí tuệ nhân tạo uet"
rag_query = web_query.lower()
web_sources, rag_sources = await ws(
    web_query,
    rag_query,
    5,
    5,
    False,
    "brave",
    True,
    False,
    True,
    True,
    0.5,
    neighbor_previous_k=0,
    neighbor_next_k=1,
    table_previous_k=5,
    table_next_k=5,
)
import shutil, json
shutil.rmtree("z_output")
os.makedirs("z_output", exist_ok=True)
total = ""
for index, rag_source in enumerate(rag_sources):
    with open(f"z_output/{index}.json", 'w', encoding='utf-8') as file:
        total += "-"*50 + "\n" + f"{rag_source["text"]}\n"
        file.write(json.dumps(rag_source, ensure_ascii=False))
with open(f"z_output/total.md", 'w', encoding='utf-8') as file:
    file.write(total)
# Out:
# [Web search] Web search: 8.80296s
# ---Original order ---
# Giảng viên - Khoa Công Nghệ Thông Tin - Trường Đại học Công Nghệ - Đại Học Quốc Gia Hà Nội -
# Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Viện trí tuệ nhân tạo - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Bộ môn Khoa học Máy tính - Khoa Công Nghệ Thông Tin - Trường Đại học Công Nghệ - Đại Học Quốc Gia Hà Nội -
# Trường Đại học Công nghệ, ĐHQGHN - VNU- University of Engineering and Technology
# ---Reorder ---
# 0.99952 Viện trí tuệ nhân tạo - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Giới thiệu Viện Trí tuệ nhân tạo Tổng quan Viện Trí tuệ nhân tạo được thành lập theo quyết định số 162/QĐ-TCCB, ngày 18/03/2022 của Hiệu trưởng Trường Đại học Công nghệ. Tên tiếng Anh: Institute for Artificial Intelligence (IAI).
# 0.99869 Giảng viên - Khoa Công Nghệ Thông Tin - Trường Đại học Công Nghệ - Đại Học Quốc Gia Hà Nội -
# Khoa Công nghệ Thông tin hiện có gần 100 cán bộ giảng dạy và nghiên cứu, bao gồm 1 Giáo sư, 16 Phó Giáo sư và hơn 50% số cán bộ có trình độ tiến sỹ được đào tạo bài bản tại các trường đại học và viện nghiên cứu uy tín từ ...
# 0.99804 Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology
# Trường Đại học Công nghệ hiện có 328 cán bộ trong đó có 258 giảng viên, trợ giảng, nghiên cứu viên và 70 cán bộ hành chính, phục vụ. Nhà trường luôn tự hào có đội ngũ cán bộ, giảng viên, nghiên cứu viên trình độ cao có học ...
# 0.99749 Bộ môn Khoa học Máy tính - Khoa Công Nghệ Thông Tin - Trường Đại học Công Nghệ - Đại Học Quốc Gia Hà Nội -
# Thành lập từ năm 1995, đến nay Bộ môn Khoa học máy tính đã phát triển đội ngũ cán bộ dày dạn kinh nghiệm trong giảng dạy cũng như nghiên cứu khoa học và phát triển hệ thống. Bộ môn có 1 giáo sư, 2 phó giáo sư, 6 tiến sĩ, 4 thạc ...
# 0.98699 Trường Đại học Công nghệ, ĐHQGHN - VNU- University of Engineering and Technology
# Trường Đại học Công nghệ, ĐHQGHN (VNU-UET)
# [Web search] Split 28362 characters to 21 chunks
# [Web search] Split 13359 characters to 11 chunks
# [Web search] Split 30977 characters to 24 chunks
# [Web search] Split 8630 characters to 7 chunks
# [Web search] Split 30153 characters to 24 chunks
# Split 5 pages to 87 chunks
# c:\Users\Anh\.conda\envs\ai\Lib\site-packages\torch\nn\modules\module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# INFO:faiss.loader:Loading faiss with AVX2 support.
# INFO:faiss.loader:Successfully loaded faiss with AVX2 support.
# INFO:faiss:Failed to load GPU Faiss: name 'GpuIndexIVFFlat' is not defined. Will not load constructor refs for GPU indexes. This is only an error if you're trying to use GPU Faiss.
# c:\Users\Anh\.conda\envs\ai\Lib\site-packages\torch\nn\modules\module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
text = """6 | TS. Trần Hồng Việt | Giảng viên chính | Xử lý ngôn ngữ tự nhiên |  thviet@vnu.edu.vn"""
print(text.count("|"))
# Out:
# 4
