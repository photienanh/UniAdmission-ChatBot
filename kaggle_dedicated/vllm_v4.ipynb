# %%
DOMAIN = "https://jolie-nonissuable-roxana.ngrok-free.dev"

# %% [markdown]
# ### Install environment

# %%
import importlib.util
import subprocess
import sys


def run_pip(*args):
    subprocess.check_call([sys.executable, "-m", "pip", *args])


def run_cmd(cmd, shell: bool = False):
    subprocess.check_call(cmd, shell=shell)


if importlib.util.find_spec("flashrank") is None:
    run_pip("install", "vllm==0.10.0")
    run_pip("install", "triton==3.2.0")
    run_pip(
        "install",
        "flashrank",
        "langchain",
        "langchain-community",
        "langchain_google_genai",
        "openai",
        "faiss-cpu",
        "langchain_huggingface",
        "crawl4ai",
        "unidecode",
        "pymupdf4llm",
        "google-genai",
        "rapidfuzz",
        "transformers==4.57.0",
    )
    run_pip("uninstall", "-y", "openai")
    run_pip("install", "openai==1.90.0")
    run_cmd([
        "wget",
        "-q",
        "-O",
        "ngrok.zip",
        "https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.zip",
    ])
    run_cmd(["unzip", "-o", "ngrok.zip"])
    run_cmd(["mv", "ngrok", "/usr/local/bin/ngrok"])
    run_cmd(["chmod", "+x", "/usr/local/bin/ngrok"])
    run_cmd("ps aux | grep ngrok", shell=True)
else:
    print("All libs aldready installed")
import os
# Fixed, do not change
os.environ["GLOO_SOCKET_NAME"] = "eth0"
os.environ["NCCL_SOCKET_NAME"] = "eth0"
os.environ["VLLM_HOST_IP"] = "127.0.0.1" # Internal ip for data communicate between VLLM components
os.environ["VLLM_USE_V1"] = "0" # T4 have compute capacity of 7.5, it need at least 8.0 to use V1
# Out:
# All libs aldready installed

# %% [markdown]
# ##### Download package from server

# %%
IS_LOCAL = DOMAIN == "http://127.0.0.1:8000"
BASE_PATH = "" if IS_LOCAL else "/kaggle/working/"

# %%
import requests
import io
import tarfile
import shutil
def unpack_folder(data: bytes, path: str):
    if os.path.exists(path): # Remove old code
        shutil.rmtree(path)
    with io.BytesIO(data) as tar_buffer:
        with tarfile.open(fileobj=tar_buffer, mode='r:gz') as tar:
            tar.extractall(path=path)
def unpack_file(data: bytes, path: str):
    os.makedirs(f"{BASE_PATH}files", exist_ok=True)
    if os.path.exists(path):
        os.remove(path)
    with open(f"{BASE_PATH}files/{path}", 'wb') as file:
        file.write(data)
def unpack_list(*names: str):
    # if DOMAIN == "http://127.0.0.1:8000": return
    for name in names:
        if "." in name:
            url = f"{DOMAIN}/package/{name}"
        else:
            url = f"{DOMAIN}/package/{name}"
        data = requests.get(url).content
        if "." in name:
            unpack_file(data, name)
        else:
            unpack_folder(data, name)
if not os.path.exists(f"{BASE_PATH}/files"):
    """"""
    # This consume a lot of quota. So only download when necessary
    unpack_list(
        "worker.env", "school_name.json", "school_alias.json", "local.pkl",
        "data_retriever", "server", "instruction", "school_mapper", 
        "lora/reader_v2", "lora/qwen_reranker_06b_v1"
    )

# %%
unpack_list("data_retriever")

# %%
# !pip install -U numpy==1.26.4 scipy==1.13.1 scikit-learn==1.5.1 \
# transformers==4.53.3 tokenizers==0.21.1 \
# --force-reinstall --no-cache-dir
# !pip install rapidfuzz

# %% [markdown]
# ### Config

# %% [markdown]
# Load environment variable (api keys)

# %%
from dotenv import load_dotenv
load_dotenv(f"{BASE_PATH}files/worker.env")
# Out:
# True

# %% [markdown]
# Setup ngrok

# %%
NGROK_PORT = 8002
if DOMAIN != "http://127.0.0.1:8000":
    import subprocess
    subprocess.run(["ngrok", "config", "add-authtoken", os.getenv("NGROK_TOKEN_1", "")])
    subprocess.Popen(["ngrok", "http", str(NGROK_PORT)], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# Login hugging face

# %%
cmd = [
    "hf", "auth", "login",
    "--token", os.getenv("HUGGING_FACE_TOKEN")
]
import subprocess
subprocess.run(cmd)
print("")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `Nam Hai Nguyen` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Nam Hai Nguyen`

# %% [markdown]
# ##### Config

# %%
from data_retriever import *
from server import *
from school_mapper import SchoolMapper
from typing import AsyncGenerator, NotRequired, Protocol
from typing import Callable, AsyncGenerator
from openai import AsyncOpenAI, OpenAI
from google import genai
from google.genai import types
import os
import pickle
import json
import asyncio
import enum
import traceback
import copy
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from vllm.lora.request import LoRARequest
# Out:
# Consider using the pymupdf_layout package for a greatly improved page layout analysis.
# [PDFProcessor] Warning: pdfplumber không được cài đặt, sẽ bỏ qua định dạng bảng nâng cao

# %%
from typing import Protocol, AsyncGenerator, TypedDict
class KeywordInfo(TypedDict):
    query: str
    priority: float
    info: str
    school: str
class KeywordModelProtocol(Protocol):
    async def keywords(self, question: str, params: GenerationParams, threshold: float = 0.5) -> list[KeywordInfo]: ...
class RouterModelProtocol(Protocol):
    async def route(self, question: str, params: GenerationParams) -> list[dict]: ...

# %%
MODEL_ID = "Qwen/Qwen3-4B"
# Retriever config
search_config = WebsearchConfig(
    page_timeout=15,
    file_timeout=15,
)
rag_config = RagConfig(
    embedding_name="intfloat/multilingual-e5-small",
    device="cuda"
)
splitter_config = SplitterConfig(
    tokenizer_name=MODEL_ID,
    chunk_size=512,
    chunk_overlap=0,
    # device="cuda"
)
table_merge_config = MergeTableConfig(
    k_max_previous=5,
    k_max_next=5
)
neighbor_config = MergeNeighborConfig(
    k_previous_chunks=1,
    k_next_chunks=1
)
# Sampling Params
PAGE_RERANKER_PARAMS = {
    "temperature": 0.7,
    "top_p": 0.9,
    "max_tokens": 4096
}
KEYWORDS_PARAMS = {
    "temperature": 0.5,
    "top_p": 0.9,
    "max_tokens": 4096
}
ROUTER_PARAMS = {
    "temperature": 0.7,
    "top_p": 0.9,
    "max_tokens": 1024
}
SEP = "$$$"
MODELS: list[ModelInfo] = [
    {
        "name": "Qwen3 4B",
        "id": "Qwen/Qwen3-4B"
    },
    {
        "name": "Qwen3 4B LoRA",
        "id": f"Qwen/Qwen3-4B{SEP}1"
    }
]
CLIENT_INFO: WorkerServerInfo = {
    "name": "Test Qwen4B",
    "domain": "http://127.0.0.1:8002", # Auto change when run with ngrok
    "models": MODELS
}
READER_LORA = LoRARequest(
    lora_int_id= 1,
    lora_name= "Qwen Reader Lora",
    lora_path= f"{BASE_PATH}lora/reader_v2"
)
LORA_MAP = {
    1: READER_LORA
}

# %% [markdown]
# ##### Template, instruction, prefix

# %%
from instruction import *

# %% [markdown]
# ### Utility class

# %% [markdown]
# ##### Data Retriever

# %%
class LocalRetriever:
    """Search in static db"""
    def __init__(self) -> None:
        with open(f"{BASE_PATH}files/local.pkl", 'rb') as file:
            self.all_docs = pickle.load(file)
    def _filter_docs(self, school_id: str, section: str) -> list:
        school_docs = [doc for doc in self.all_docs if doc.metadata.get("school_id") == school_id]
        if school_docs:
            filtered_docs = [doc for doc in school_docs if doc.metadata.get("section") == section]
        else:
            filtered_docs = []
        return filtered_docs
    def retrieve(self, keywords: list[dict]) -> tuple[list[WebSource], list[RagSource]]:
        web_sources: list[WebSource] = []
        rag_sources: list[RagSource] = []
        try:
            for kw in keywords:
                school_id = kw.get("school_id")
                section = kw.get("section")
                if school_id and section:
                    docs = self._filter_docs(school_id, section)
                    title = f"Tìm trường ĐH-CĐ - Cốc Cốc ({school_id})"
                    combined_content = "\n\n".join([doc.page_content for doc in docs])
                    description = combined_content[:100] + "..." if len(combined_content) > 100 else combined_content
                    web_source: WebSource = {
                        "query": f"{school_id}:{section}",
                        "title": title,
                        "description": description,
                        "url": "https://hoctap.coccoc.com/tim-truong-dh-cd",
                        "text": combined_content,
                        "files": [],
                        "score": 1
                    }
                    rag_source: RagSource = {
                        "chunk_index": 0,
                        "query": f"{school_id}:{section}",
                        "title": title,
                        "url": "https://hoctap.coccoc.com/tim-truong-dh-cd",
                        "text": combined_content,
                    }
                    web_sources.append(web_source)
                    rag_sources.append(rag_source)
        except:
            traceback.print_exc()
        finally:            
            return web_sources, rag_sources

# %%
class WebRetriever:
    """Search in web"""
    def __init__(self, llm_ranker: PageRerankModelProtocol, llm_keywords: KeywordModelProtocol) -> None:
        self.pipeline = DataRetrieverPipeline(
            llm_ranker,
            websearch_config=search_config,
            rag_config=rag_config,
            splitter_config=splitter_config,
            neighbor_merge_config=neighbor_config,
            table_merge_config=table_merge_config
        )
        self.llm_keywords = llm_keywords
        self.school_mapper = SchoolMapper(f"{BASE_PATH}files/school_name.json")
    async def start(self):
        """Initialize websearch"""
        await self.pipeline.start()
    async def retrive(self, question: str, params: GenerationParams) -> tuple[list[WebSource], list[RagSource]]:
        data = await self.llm_keywords.keywords(question, params)
        max_query = params.get("max_query", 1)
        queries = []
        school_restrict = params.get("school_domain", False)
        for item in data:
            if not school_restrict:
                queries.append(item["query"])
            else:
                school = item["school"]
                if school.strip() != "":
                    school_domains = self.school_mapper.domains_from_auto(school, 5)[:10]
                    print(f"[DOMAINS]", school_domains)
                    if len(school_domains) > 0:
                        queries.append([item["query"], school_domains])
        return await self.pipeline.retrieve(params, queries[:max_query])

# %%
class RouterRetriever:
    def __init__(self, llm_router: RouterModelProtocol, web_retriever: WebRetriever, local_retriever: LocalRetriever) -> None:
        self.web_retriever = web_retriever
        self.local_retriever = local_retriever
        self.router = llm_router
    async def retrieve(self, question: str, params: GenerationParams) -> tuple[list[WebSource], list[RagSource]]:
        use_websearch = params.get("use_websearch", False) and params.get("max_query", 0) > 0 and params.get("k_docs", 0) > 0 and params.get("k_pages", 0) > 0
        use_localdb = params.get("use_localdb", False)
        if use_websearch and use_localdb:
            local_queries = await self.router.route(question, params)
            if len(local_queries) > 0:
                return self.local_retriever.retrieve(local_queries)
            else:
                return await self.web_retriever.retrive(question, params)
        elif use_localdb:
            local_queries = await self.router.route(question, params)
            if len(local_queries) > 0:
                return self.local_retriever.retrieve(local_queries)
            else:
                return [], []
        elif use_websearch:
            return await self.web_retriever.retrive(question, params)
        else:
            return [], []

# %% [markdown]
# ##### Client to call model

# %%
from vllm import SamplingParams, AsyncLLMEngine, AsyncEngineArgs
from vllm.outputs import RequestOutput
from vllm.utils import random_uuid
from vllm.lora.request import LoRARequest
from typing import AsyncGenerator
from typing import Optional, Any
from vllm.transformers_utils.tokenizers import MistralTokenizer
from openai.types.chat import  ChatCompletionUserMessageParam, ChatCompletionSystemMessageParam
from vllm.entrypoints.chat_utils import (
    ChatTemplateContentFormatOption, 
    resolve_chat_template_content_format, 
    apply_hf_chat_template,
    apply_mistral_chat_template,
    parse_chat_messages
)
from vllm.inputs.data import TokensPrompt

class AsyncLLMEngineWrapper:
    """Not support shutdown"""
    def __init__(self) -> None:
        self.engine = None
        self.reap_wait_time = 5
    def init(self, engine_args: AsyncEngineArgs):
        self.engine = AsyncLLMEngine.from_engine_args(engine_args)
    def generate(self, prompt: str | TokensPrompt, sampling_params: SamplingParams, lora_request: LoRARequest | None) -> AsyncGenerator[RequestOutput, None]:
        if self.engine is None:
            raise Exception("Not initialized")
        return self.engine.generate(
            prompt=prompt,
            sampling_params=sampling_params,
            request_id=random_uuid(),
            lora_request=lora_request
        )
    async def chat(self, instruction: str, prompt: str, sampling_params: SamplingParams, lora_request: LoRARequest | None = None):
        messages = [
            ChatCompletionSystemMessageParam(content=instruction, role="system"),
            ChatCompletionUserMessageParam(content=prompt, role="user")
        ]
        return await self._chat(
            messages=messages,
            sampling_params=sampling_params,
            lora_request=lora_request,
            chat_template_kwargs={
                "enable_thinking": False
            }
        )
    async def _chat(
        self,
        messages: list[ChatCompletionUserMessageParam | ChatCompletionUserMessageParam],
        sampling_params: SamplingParams,
        lora_request: LoRARequest | None,
        chat_template_content_format: ChatTemplateContentFormatOption = "auto",
        chat_template: Optional[str] = None,
        add_generation_prompt: bool = True,
        continue_final_message: bool = False,
        chat_template_kwargs: Optional[dict[str, Any]] = None
    ):
        if self.engine is None: raise Exception("Model not loaded")
        tokenizer = await self.engine.get_tokenizer(lora_request)
        model_config = self.engine.engine.get_model_config()
        resolved_content_format = resolve_chat_template_content_format(
            chat_template,
            None,
            chat_template_content_format,
            tokenizer,
            model_config=model_config,
        )
        _chat_template_kwargs: dict[str, Any] = dict(
            chat_template=chat_template,
            add_generation_prompt=add_generation_prompt,
            continue_final_message=continue_final_message,
            tools=None,
        )
        _chat_template_kwargs.update(chat_template_kwargs or {})
        conversation, _ = parse_chat_messages(
            messages, #type:ignore
            model_config,
            tokenizer,
            content_format=resolved_content_format,
        )

        if isinstance(tokenizer, MistralTokenizer):
            prompt_token_ids = apply_mistral_chat_template(
                tokenizer,
                messages=messages, #type:ignore
                **_chat_template_kwargs,
            )
        else:
            prompt_str = apply_hf_chat_template(
                tokenizer=tokenizer, #type:ignore
                conversation=conversation,
                model_config=model_config,
                **_chat_template_kwargs,
            )
            prompt_token_ids = tokenizer.encode(prompt_str, add_special_tokens=False)
        prompt = TokensPrompt(prompt_token_ids=prompt_token_ids)
        return self.generate(
            prompt,
            sampling_params=sampling_params,
            lora_request=lora_request,
        )
# Out:
# 2025-11-28 06:36:02.197485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764311762.219689    2695 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764311762.226278    2695 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO 11-28 06:36:07 [__init__.py:235] Automatically detected platform cuda.

# %%
import msgspec
import glob

def _find_reranker_checkpoint(base_path: str = None) -> str | None:
    """Tìm LoRA adapter trong package/lora/qwen_reranker_06b_v1"""
    if base_path is None:
        base_path = BASE_PATH
    print(f"[Reranker] Searching for adapter, BASE_PATH={base_path}, cwd={os.getcwd()}")
    
    # Các đường dẫn có thể có (ưu tiên local trước)
    adapter_paths = [
        # Local paths (ưu tiên)
        "app/package/lora/qwen_reranker_06b_v1",
        os.path.join(os.getcwd(), "app", "package", "lora", "qwen_reranker_06b_v1"),
        # Downloaded paths
        f"{base_path}lora/qwen_reranker_06b_v1",
        f"{base_path}package/lora/qwen_reranker_06b_v1",
        "lora/qwen_reranker_06b_v1",
        "package/lora/qwen_reranker_06b_v1",
        # Other possible paths
        os.path.join(os.getcwd(), "package", "lora", "qwen_reranker_06b_v1"),
        os.path.join(os.getcwd(), "lora", "qwen_reranker_06b_v1"),
    ]
    
    for adapter_dir in adapter_paths:
        # Normalize path
        adapter_dir = os.path.normpath(adapter_dir)
        print(f"[Reranker] Checking: {adapter_dir} (exists: {os.path.exists(adapter_dir)})")
        if os.path.exists(adapter_dir) and os.path.isdir(adapter_dir):
            # Kiểm tra có adapter_model.safetensors
            adapter_file = os.path.join(adapter_dir, "adapter_model.safetensors")
            if os.path.exists(adapter_file):
                print(f"[Reranker] ✓ Found adapter at: {adapter_dir}")
                return adapter_dir  # Trả về thư mục chứa adapter
            else:
                print(f"[Reranker] Directory exists but adapter_model.safetensors not found")
                # List files in directory for debugging
                try:
                    files = os.listdir(adapter_dir)
                    print(f"[Reranker] Files in directory ({len(files)} files): {files}")
                except Exception as e:
                    print(f"[Reranker] Error listing directory: {e}")
        else:
            print(f"[Reranker] Path does not exist: {adapter_dir}")
    
    print("[Reranker] ✗ Adapter not found in any of the checked paths")
    return None

class VLLMModelCore:
    def __init__(self) -> None:
        self._engine = AsyncLLMEngineWrapper()
        self.logger = CmdLogger("Model")
        self._reranker_name = os.getenv("PAGE_RERANKER_MODEL", "Qwen/Qwen3-Reranker-0.6B")
        # Tìm checkpoint từ package/lora/qwen_reranker hoặc env variable
        self._reranker_checkpoint = os.getenv("PAGE_RERANKER_CHECKPOINT", None)
        if self._reranker_checkpoint is None:
            self._reranker_checkpoint = _find_reranker_checkpoint()
        if self._reranker_checkpoint:
            print(f"[Reranker] Found adapter at: {self._reranker_checkpoint}")
        else:
            print("[Reranker] No adapter checkpoint found, will use base model only")
        self._reranker_batch_size = int(os.getenv("PAGE_RERANKER_BATCH_SIZE", "8"))
        self._reranker_max_length = int(os.getenv("PAGE_RERANKER_MAX_LENGTH", "1024"))
        self._reranker_device = None
        self._reranker_model = None
        self._reranker_tokenizer = None
    def init(self, engine_args: AsyncEngineArgs):
        self._engine.init(engine_args)
    async def call(self, call_type: CallType, instruction: str, prompt: str, params: GenerationParams) -> AsyncGenerator[str, None]:
        print(f"[VLLM] {call_type} | Instruction length: {len(instruction)} | Prompt length: {len(prompt)} | kwargs: {params.get('kwargs')}")
        model_id = params["model_id"]
        lora_request = None
        if call_type == CallType.READER and SEP in model_id:
            lora_int_id = int(model_id.split(SEP)[-1])
            lora_request = LORA_MAP.get(lora_int_id)
        sampling_params = msgspec.convert(params, SamplingParams)
        if lora_request != None:
            print(f"[VLLm] Using {lora_request.lora_name}")
        stream = await self._engine.chat(
            instruction=instruction,
            prompt=prompt,
            sampling_params=sampling_params,
            lora_request=lora_request
        )
        total_text = ""
        last_index = 0
        async for event in stream:
            total_text = event.outputs[0].text
            yield total_text[last_index:]
            last_index = len(total_text)
    async def __call__(self, call_type: CallType, instruction: str, prompt: str, params: GenerationParams) -> AsyncGenerator[str, None]:
        return self.call(call_type, instruction, prompt, params)

# %%
class VLLMModel(VLLMModelCore):
    async def route(self, question: str, params: GenerationParams) -> list[dict]:
        text = ""
        prompt = ROUTER_TEMPLATE.format(question=question)
        copy_params = copy.deepcopy(params)
        copy_params.update(ROUTER_PARAMS) #type:ignore 
        async for chunk in await self(
            call_type=CallType.ROUTER, 
            instruction=ROUTER_INSTRUCTION, 
            prompt=ROUTER_PREFIX+prompt, 
            params=copy_params
        ):
            text += chunk
        try:
            self.logger.log(text)
            result = json.loads(extract_json(text))
            return result
        except:
            traceback.print_exc()
            return []
    def _ensure_reranker_loaded(self):
        if (
            self._reranker_model is not None
            and self._reranker_tokenizer is not None
            and self._reranker_device is not None
        ):
            return
        device_str = "cuda" if torch.cuda.is_available() else "cpu"
        self._reranker_device = torch.device(device_str)
        self._reranker_tokenizer = AutoTokenizer.from_pretrained(
            self._reranker_name,
            trust_remote_code=True
        )
        # Set padding token if not already set
        if self._reranker_tokenizer.pad_token is None:
            if self._reranker_tokenizer.eos_token is not None:
                self._reranker_tokenizer.pad_token = self._reranker_tokenizer.eos_token
            else:
                # Fallback: add a special pad token
                self._reranker_tokenizer.add_special_tokens({"pad_token": "[PAD]"})
        torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32
        self._reranker_model = AutoModelForSequenceClassification.from_pretrained(
            self._reranker_name,
            trust_remote_code=True,
            torch_dtype=torch_dtype
        )
        # Resize token embeddings if we added a new pad token
        if self._reranker_tokenizer.pad_token_id is not None:
            if self._reranker_model.config.pad_token_id is None:
                self._reranker_model.config.pad_token_id = self._reranker_tokenizer.pad_token_id
            # Resize embeddings if needed (only if we added a new token)
            if len(self._reranker_tokenizer) > self._reranker_model.get_input_embeddings().weight.shape[0]:
                self._reranker_model.resize_token_embeddings(len(self._reranker_tokenizer))
        self._reranker_model.to(self._reranker_device)
        
        # Load trained LoRA adapter or checkpoint if provided
        if self._reranker_checkpoint is not None and os.path.exists(self._reranker_checkpoint):
            try:
                print(f"[Reranker] Loading from {self._reranker_checkpoint}")
                
                # Check if it's a LoRA adapter directory
                if os.path.isdir(self._reranker_checkpoint):
                    adapter_file = os.path.join(self._reranker_checkpoint, "adapter_model.safetensors")
                    if os.path.exists(adapter_file):
                        # Load LoRA adapter using PEFT or direct loading
                        try:
                            from peft import PeftModel, PeftConfig
                            from safetensors.torch import load_file
                            import json
                            
                            # Check adapter config for num_labels BEFORE loading PEFT
                            adapter_config_file = os.path.join(self._reranker_checkpoint, "adapter_config.json")
                            checkpoint_num_labels = None
                            if os.path.exists(adapter_config_file):
                                try:
                                    with open(adapter_config_file, 'r') as f:
                                        adapter_config = json.load(f)
                                        # Check if num_labels is in the config
                                        if 'num_labels' in adapter_config:
                                            checkpoint_num_labels = adapter_config['num_labels']
                                            print(f"[Reranker] Found num_labels in adapter_config: {checkpoint_num_labels}")
                                except Exception as e:
                                    print(f"[Reranker] Could not read adapter_config.json: {e}")
                            
                            import json
                            
                            # Check adapter config for num_labels BEFORE loading PEFT
                            adapter_config_file = os.path.join(self._reranker_checkpoint, "adapter_config.json")
                            checkpoint_num_labels = None
                            if os.path.exists(adapter_config_file):
                                try:
                                    with open(adapter_config_file, 'r') as f:
                                        adapter_config = json.load(f)
                                        # Check if num_labels is in the config
                                        if 'num_labels' in adapter_config:
                                            checkpoint_num_labels = adapter_config['num_labels']
                                            print(f"[Reranker] Found num_labels in adapter_config: {checkpoint_num_labels}")
                                except Exception as e:
                                    print(f"[Reranker] Could not read adapter_config.json: {e}")
                            
                            # Load adapter state dict to check shapes - MUST be done first
                            print("[Reranker] Loading adapter state dict to check shapes...")
                            adapter_state_dict = load_file(adapter_file)
                            
                            # Detect num_labels from score.weight shape if not in config
                            if checkpoint_num_labels is None:
                                for k, v in adapter_state_dict.items():
                                    # Check for modules_to_save keys with score.weight
                                    if "score" in k and "weight" in k and "modules_to_save" in k:
                                        # Shape is [num_labels, hidden_size]
                                        checkpoint_num_labels = v.shape[0]
                                        print(f"[Reranker] Detected num_labels from {k} shape: {checkpoint_num_labels}")
                                        break
                                    elif k.endswith(".score.weight") or k == "score.weight":
                                        checkpoint_num_labels = v.shape[0]
                                        print(f"[Reranker] Detected num_labels from {k} shape: {checkpoint_num_labels}")
                                        break
                            
                            # Resize score layer if num_labels mismatch - MUST be done BEFORE PeftModel.from_pretrained
                            if checkpoint_num_labels is not None and checkpoint_num_labels != self._reranker_model.config.num_labels:
                                print(f"[Reranker] Resizing score layer: {self._reranker_model.config.num_labels} -> {checkpoint_num_labels}")
                                # Get hidden size
                                hidden_size = self._reranker_model.config.hidden_size
                                # Create new score layer with correct num_labels
                                import torch.nn as nn
                                new_score = nn.Linear(hidden_size, checkpoint_num_labels, bias=False)
                                # Copy existing weights if possible (take first num_labels if checkpoint has fewer)
                                if hasattr(self._reranker_model, 'score'):
                                    old_weight = self._reranker_model.score.weight
                                    if old_weight.shape[0] >= checkpoint_num_labels:
                                        new_score.weight.data = old_weight[:checkpoint_num_labels].clone()
                                    else:
                                        # Initialize new weights
                                        new_score.weight.data.normal_(mean=0.0, std=0.02)
                                # Replace score layer
                                self._reranker_model.score = new_score
                                self._reranker_model.config.num_labels = checkpoint_num_labels
                                self._reranker_model.num_labels = checkpoint_num_labels
                                self._reranker_model.to(self._reranker_device)
                                print(f"[Reranker] Score layer resized successfully to {checkpoint_num_labels} labels")
                            
                            adapter_state_dict = load_file(adapter_file)
                            
                            # Detect num_labels from score.weight shape if not in config
                            if checkpoint_num_labels is None:
                                for k, v in adapter_state_dict.items():
                                    # Check for modules_to_save keys with score.weight
                                    if "score" in k and "weight" in k and "modules_to_save" in k:
                                        # Shape is [num_labels, hidden_size]
                                        checkpoint_num_labels = v.shape[0]
                                        print(f"[Reranker] Detected num_labels from {k} shape: {checkpoint_num_labels}")
                                        break
                                    elif k.endswith(".score.weight") or k == "score.weight":
                                        checkpoint_num_labels = v.shape[0]
                                        print(f"[Reranker] Detected num_labels from {k} shape: {checkpoint_num_labels}")
                                        break
                            
                            # Resize score layer if num_labels mismatch - MUST be done BEFORE PeftModel.from_pretrained
                            if checkpoint_num_labels is not None and checkpoint_num_labels != self._reranker_model.config.num_labels:
                                print(f"[Reranker] Resizing score layer: {self._reranker_model.config.num_labels} -> {checkpoint_num_labels}")
                                # Get hidden size
                                hidden_size = self._reranker_model.config.hidden_size
                                # Create new score layer with correct num_labels
                                import torch.nn as nn
                                new_score = nn.Linear(hidden_size, checkpoint_num_labels, bias=False)
                                # Copy existing weights if possible (take first num_labels if checkpoint has fewer)
                                if hasattr(self._reranker_model, 'score'):
                                    old_weight = self._reranker_model.score.weight
                                    if old_weight.shape[0] >= checkpoint_num_labels:
                                        new_score.weight.data = old_weight[:checkpoint_num_labels].clone()
                                    else:
                                        # Initialize new weights
                                        new_score.weight.data.normal_(mean=0.0, std=0.02)
                                # Replace score layer
                                self._reranker_model.score = new_score
                                self._reranker_model.config.num_labels = checkpoint_num_labels
                                self._reranker_model.num_labels = checkpoint_num_labels
                                self._reranker_model.to(self._reranker_device)
                                print(f"[Reranker] Score layer resized successfully to {checkpoint_num_labels} labels")
                            
                            # Now load PEFT adapter - the model should have correct num_labels now
                            
                            # Check adapter config for num_labels BEFORE loading PEFT
                            adapter_config_file = os.path.join(self._reranker_checkpoint, "adapter_config.json")
                            checkpoint_num_labels = None
                            if os.path.exists(adapter_config_file):
                                try:
                                    with open(adapter_config_file, 'r') as f:
                                        adapter_config = json.load(f)
                                        if 'num_labels' in adapter_config:
                                            checkpoint_num_labels = adapter_config['num_labels']
                                            print(f"[Reranker] Found num_labels in adapter_config: {checkpoint_num_labels}")
                                except Exception as e:
                                    print(f"[Reranker] Could not read adapter_config.json: {e}")
                            
                            # Detect num_labels from score.weight shape if not in config
                            if checkpoint_num_labels is None:
                                for k, v in adapter_state_dict.items():
                                    if "score" in k and "weight" in k and "modules_to_save" in k:
                                        checkpoint_num_labels = v.shape[0]
                                        print(f"[Reranker] Detected num_labels from {k} shape: {checkpoint_num_labels}")
                                        break
                                    elif k.endswith(".score.weight") or k == "score.weight":
                                        checkpoint_num_labels = v.shape[0]
                                        print(f"[Reranker] Detected num_labels from {k} shape: {checkpoint_num_labels}")
                                        break
                            
                            # Resize score layer if num_labels mismatch - MUST be done BEFORE PeftModel.from_pretrained
                            if checkpoint_num_labels is not None and checkpoint_num_labels != self._reranker_model.config.num_labels:
                                print(f"[Reranker] Resizing score layer: {self._reranker_model.config.num_labels} -> {checkpoint_num_labels}")
                                hidden_size = self._reranker_model.config.hidden_size
                                import torch.nn as nn
                                new_score = nn.Linear(hidden_size, checkpoint_num_labels, bias=False)
                                if hasattr(self._reranker_model, 'score'):
                                    old_weight = self._reranker_model.score.weight
                                    if old_weight.shape[0] >= checkpoint_num_labels:
                                        new_score.weight.data = old_weight[:checkpoint_num_labels].clone()
                                    else:
                                        new_score.weight.data.normal_(mean=0.0, std=0.02)
                                self._reranker_model.score = new_score
                                self._reranker_model.config.num_labels = checkpoint_num_labels
                                self._reranker_model.num_labels = checkpoint_num_labels
                                self._reranker_model.to(self._reranker_device)
                                print(f"[Reranker] Score layer resized successfully to {checkpoint_num_labels} labels")
                            
                            # Extract modules_to_save weights (score.weight, classifier.weight) for later use
                            modules_to_save_weights = {}
                            model_dict = self._reranker_model.state_dict()
                            
                            for k, v in adapter_state_dict.items():
                                # Look for modules_to_save keys (score, classifier)
                                # They might be: score.weight, base_model.model.score.weight, etc.
                                model_key = None
                                if k == "score.weight" or k.endswith(".score.weight"):
                                    model_key = "score.weight"
                                elif k == "score.bias" or k.endswith(".score.bias"):
                                    model_key = "score.bias"
                                elif k == "classifier.weight" or k.endswith(".classifier.weight"):
                                    model_key = "classifier.weight"
                                elif k == "classifier.bias" or k.endswith(".classifier.bias"):
                                    model_key = "classifier.bias"
                                elif k.startswith("base_model.model.") and ("score" in k or "classifier" in k):
                                    model_key = k.replace("base_model.model.", "")
                                
                                if model_key and model_key in model_dict:
                                    # Handle shape mismatch by resizing if needed
                                    if model_dict[model_key].shape == v.shape:
                                        modules_to_save_weights[model_key] = v.to(self._reranker_device)
                                        print(f"[Reranker] Found modules_to_save: {k} -> {model_key} (shape: {v.shape})")
                            
                            # Load modules_to_save weights into model before PEFT
                            if modules_to_save_weights:
                                print(f"[Reranker] Loading {len(modules_to_save_weights)} modules_to_save weights into model...")
                                missing, unexpected = self._reranker_model.load_state_dict(modules_to_save_weights, strict=False)
                                if missing:
                                    print(f"[Reranker] Missing keys: {missing}")
                                if unexpected:
                                    print(f"[Reranker] Unexpected keys: {unexpected}")
                            
                            print("[Reranker] Loading LoRA adapter using PEFT")
                            self._reranker_model = PeftModel.from_pretrained(
                                self._reranker_model,
                                self._reranker_checkpoint,
                                device=self._reranker_device
                            )
                            
                            # Verify score.weight exists in adapter
                            if hasattr(self._reranker_model, 'peft_config'):
                                print(f"[Reranker] PEFT config loaded: {list(self._reranker_model.peft_config.keys())}")
                            
                            # Check if score.weight is in the model
                            model_state = self._reranker_model.state_dict()
                            score_keys = [k for k in model_state.keys() if 'score' in k]
                            print(f"[Reranker] Keys with 'score' in model: {score_keys}")
                            
                            # Merge LoRA weights into base model for faster inference
                            print("[Reranker] Merging LoRA weights into base model...")
                            self._reranker_model = self._reranker_model.merge_and_unload()
                            # Ensure model is on correct device after merge
                            self._reranker_model.to(self._reranker_device)
                            
                            # Verify score.weight after merge (merge_and_unload() should preserve modules_to_save weights)
                            final_state = self._reranker_model.state_dict()
                            score_weight_ok = False
                            if 'score.weight' in final_state:
                                print(f"[Reranker] ✓ score.weight present after merge (shape: {final_state['score.weight'].shape})")
                                # Check if it's not the default initialized weight
                                if hasattr(self._reranker_model, 'score'):
                                    score_weight = self._reranker_model.score.weight
                                    weight_norm = torch.norm(score_weight).item()
                                    print(f"[Reranker] score.weight norm: {weight_norm:.6f} (should be > 0 if loaded correctly)")
                                    if weight_norm >= 1e-6:
                                        score_weight_ok = True
                                    else:
                                        print(f"[Reranker] ⚠ WARNING: score.weight norm is very small, might be default initialized!")
                            else:
                                print(f"[Reranker] ✗ score.weight NOT found after merge")
                                print(f"[Reranker] Available keys with 'score': {[k for k in final_state.keys() if 'score' in k]}")
                            
                            # Only re-load modules_to_save weights if score.weight is missing or has invalid norm
                            if modules_to_save_weights and not score_weight_ok:
                                print("[Reranker] Re-loading modules_to_save weights after merge (score.weight was not preserved)...")
                                missing, unexpected = self._reranker_model.load_state_dict(modules_to_save_weights, strict=False)
                                # Filter out expected missing keys (base model weights)
                                if missing:
                                    base_model_keys = [k for k in missing if k.startswith('model.')]
                                    if len(base_model_keys) < len(missing):
                                        # Only print if there are unexpected missing keys
                                        unexpected_missing = [k for k in missing if not k.startswith('model.')]
                                        if unexpected_missing:
                                            print(f"[Reranker] Unexpected missing keys when re-loading: {unexpected_missing}")
                                if unexpected:
                                    print(f"[Reranker] Unexpected keys: {unexpected}")
                            elif modules_to_save_weights and score_weight_ok:
                                print("[Reranker] ✓ score.weight preserved after merge, no need to re-load")
                            
                            print(f"[Reranker] Successfully loaded and merged LoRA adapter from {self._reranker_checkpoint}")
                        except ImportError:
                            print("[Reranker] PEFT not available, loading adapter weights directly")
                            # Load directly from safetensors
                            from safetensors.torch import load_file
                            adapter_state_dict = load_file(adapter_file)
                            
                            print(f"[Reranker] Loaded {len(adapter_state_dict)} keys from adapter")
                            print(f"[Reranker] Sample adapter keys: {list(adapter_state_dict.keys())[:10]}")
                            
                            # Map adapter keys to model keys
                            model_dict = self._reranker_model.state_dict()
                            print(f"[Reranker] Model has {len(model_dict)} keys")
                            print(f"[Reranker] Model keys containing 'score': {[k for k in model_dict.keys() if 'score' in k]}")
                            
                            filtered_state_dict = {}
                            
                            for k, v in adapter_state_dict.items():
                                # LoRA adapter có thể có:
                                # 1. LoRA weights (lora_A, lora_B) - bỏ qua vì không có PEFT để merge
                                # 2. modules_to_save weights (score.weight, classifier.weight) - load trực tiếp
                                # 3. Keys với prefix base_model.model. - remove prefix
                                
                                model_key = k
                                if k.startswith("base_model.model."):
                                    model_key = k.replace("base_model.model.", "")
                                elif k.startswith("lora_"):
                                    # Skip LoRA weights khi không có PEFT
                                    continue
                                # Các keys khác (như score.weight, classifier.weight) giữ nguyên
                                
                                if model_key in model_dict:
                                    if model_dict[model_key].shape == v.shape:
                                        filtered_state_dict[model_key] = v.to(self._reranker_device)
                                        print(f"[Reranker] Loading key: {k} -> {model_key} (shape: {v.shape})")
                                    else:
                                        print(f"[Reranker] Shape mismatch for {k} -> {model_key}: adapter {v.shape} vs model {model_dict[model_key].shape}")
                                else:
                                    print(f"[Reranker] Key not in model: {k} -> {model_key}")
                            
                            print(f"[Reranker] Loading {len(filtered_state_dict)} matching keys into model")
                            missing_keys, unexpected_keys = self._reranker_model.load_state_dict(filtered_state_dict, strict=False)
                            
                            if missing_keys:
                                print(f"[Reranker] Missing keys after load: {missing_keys}")
                            if unexpected_keys:
                                print(f"[Reranker] Unexpected keys: {unexpected_keys}")
                            
                            # Verify score.weight was loaded
                            if 'score.weight' in filtered_state_dict:
                                print(f"[Reranker] ✓ score.weight successfully loaded (shape: {filtered_state_dict['score.weight'].shape})")
                            else:
                                print(f"[Reranker] ✗ score.weight NOT found in adapter or not loaded")
                                print(f"[Reranker] Available adapter keys with 'score': {[k for k in adapter_state_dict.keys() if 'score' in k]}")
                            
                            print(f"[Reranker] Successfully loaded adapter weights from {adapter_file}")
                            print(f"[Reranker] Note: LoRA weights not merged (PEFT not available). Only modules_to_save weights loaded.")
                    else:
                        print(f"[Reranker] adapter_model.safetensors not found in {self._reranker_checkpoint}")
                else:
                    # Handle regular checkpoint file
                    print(f"[Reranker] Loading checkpoint file")
                    
                    # Handle safetensors format
                    if self._reranker_checkpoint.endswith('.safetensors'):
                        try:
                            from safetensors.torch import load_file
                            state_dict = load_file(self._reranker_checkpoint)
                        except ImportError:
                            print("[Reranker] safetensors not installed, falling back to torch.load")
                            state_dict = torch.load(self._reranker_checkpoint, map_location=self._reranker_device)
                    else:
                        checkpoint = torch.load(self._reranker_checkpoint, map_location=self._reranker_device)
                        
                        # Handle different checkpoint formats
                        if isinstance(checkpoint, dict):
                            if 'model_state_dict' in checkpoint:
                                state_dict = checkpoint['model_state_dict']
                            elif 'state_dict' in checkpoint:
                                state_dict = checkpoint['state_dict']
                            else:
                                state_dict = checkpoint
                        else:
                            state_dict = checkpoint
                    
                    # Load state dict, handling mismatched keys
                    model_dict = self._reranker_model.state_dict()
                    
                    # Filter out keys that don't match
                    filtered_state_dict = {}
                    for k, v in state_dict.items():
                        if k in model_dict and model_dict[k].shape == v.shape:
                            filtered_state_dict[k] = v
                        else:
                            print(f"[Reranker] Skipping key {k} (shape mismatch or not in model)")
                    
                    # Load the filtered state dict
                    missing_keys, unexpected_keys = self._reranker_model.load_state_dict(filtered_state_dict, strict=False)
                    
                    if missing_keys:
                        print(f"[Reranker] Missing keys: {missing_keys}")
                    if unexpected_keys:
                        print(f"[Reranker] Unexpected keys: {unexpected_keys}")
                    
                    print(f"[Reranker] Successfully loaded checkpoint from {self._reranker_checkpoint}")
            except Exception as e:
                print(f"[Reranker] Failed to load checkpoint: {e}")
                traceback.print_exc()
        
        self._reranker_model.eval()
    def _make_page_text(self, page: SearchResult) -> str:
        parts = [
            page.get("title", ""),
            page.get("description", ""),
            page.get("url", "")
        ]
        return "\n\n".join([part for part in parts if part])
    async def _llm_rerank_page(self, pages: list[SearchResult], query: str, relative_threshold: float, params: GenerationParams) -> list[SearchResult]:
        if len(pages) == 0:
            return []
        try:
            self._ensure_reranker_loaded()
        except Exception as e:
            traceback.print_exc()
            raise RuntimeError(f"Failed to load reranker model: {e}") from e
        if (
            self._reranker_model is None
            or self._reranker_tokenizer is None
            or self._reranker_device is None
        ):
            raise RuntimeError("Reranker model, tokenizer, or device is not initialized")
        page_texts = [self._make_page_text(page) for page in pages]
        
        # DEBUG: Log reranker input
        print(f"\n[Reranker Debug] Query: {query}")
        print(f"[Reranker Debug] Number of pages: {len(pages)}")
        print(f"[Reranker Debug] Sample page texts (first 3):")
        for i, (page, page_text) in enumerate(zip(pages[:3], page_texts[:3]), 1):
            print(f"\n  Page {i}:")
            print(f"    Title: {page.get('title', 'N/A')[:100]}")
            print(f"    Description: {page.get('description', 'N/A')[:100]}")
            print(f"    URL: {page.get('url', 'N/A')}")
            print(f"    Page text (first 200 chars): {page_text[:200]}...")
        
        def _run_reranker() -> list[float]:
            scores: list[float] = []
            self._reranker_model.eval()
            for start in range(0, len(page_texts), self._reranker_batch_size):
                end = start + self._reranker_batch_size
                batch_texts = page_texts[start:end]
                batch_queries = [query for _ in batch_texts]
                
                # DEBUG: Log tokenizer input
                if start == 0:  # Only log first batch
                    print(f"\n[Reranker Debug] First batch:")
                    print(f"  Query: {batch_queries[0]}")
                    print(f"  First page text: {batch_texts[0][:300]}...")
                
                inputs = self._reranker_tokenizer(
                    batch_queries,
                    batch_texts,
                    padding=True,
                    truncation=True,
                    max_length=self._reranker_max_length,
                    return_tensors="pt"
                )
                inputs = {k: v.to(self._reranker_device) for k, v in inputs.items()}
                with torch.no_grad():
                    logits = self._reranker_model(**inputs).logits
                    logits = logits.view(-1)
                    batch_scores = logits.float().cpu().tolist()
                
                # DEBUG: Log raw scores
                if start == 0:  # Only log first batch
                    print(f"\n[Reranker Debug] Raw scores from first batch:")
                    for i, (score, page) in enumerate(zip(batch_scores, pages[start:end]), 1):
                        print(f"  [{i}] Score: {score:.6f} | Title: {page.get('title', 'N/A')[:80]}")
                
                scores.extend(batch_scores)
            return scores
        try:
            scores = await asyncio.to_thread(_run_reranker)
        except Exception as e:
            traceback.print_exc()
            raise RuntimeError(f"Failed to run reranker inference: {e}") from e
        if len(scores) != len(pages):
            raise RuntimeError(f"Reranker returned {len(scores)} scores but expected {len(pages)} scores")
        
        # DEBUG: Log all scores before threshold
        print(f"\n[Reranker Debug] All raw scores (before threshold):")
        score_page_pairs = [(float(score), page) for score, page in zip(scores, pages)]
        score_page_pairs.sort(key=lambda x: x[0], reverse=True)
        for i, (score, page) in enumerate(score_page_pairs, 1):
            print(f"  [{i}] Score: {score:.6f} | Title: {page.get('title', 'N/A')[:80]}")
        
        self.logger.log("-----Original-----")
        if self.logger._enable:
            for page in pages:
                self.logger.log(f'{page["score"]:.3f} + {page["title"]}')
        max_score = float("-inf")
        for score, search_result in zip(scores, pages):
            score = float(score)
            max_score = max(max_score, score)
            search_result["score"] = score
        if max_score == float("-inf"):
            raise RuntimeError("Reranker returned all invalid scores (all -inf)")
        threshold_score = max_score * relative_threshold
        
        # DEBUG: Log threshold info
        print(f"\n[Reranker Debug] Threshold calculation:")
        print(f"  Max score: {max_score:.6f}")
        print(f"  Relative threshold: {relative_threshold}")
        print(f"  Threshold score: {threshold_score:.6f}")
        
        results: list[SearchResult] = []
        for search_result in pages:
            if search_result["score"] >= threshold_score:
                results.append(search_result)
        results = sorted(results, key=lambda r: r["score"], reverse=True)
        
        # DEBUG: Log filtered results
        print(f"\n[Reranker Debug] Filtered results (after threshold, {len(results)}/{len(pages)}):")
        for i, page in enumerate(results, 1):
            print(f"  [{i}] Score: {page['score']:.6f} | Title: {page.get('title', 'N/A')[:80]}")
        
        self.logger.log("-----Reorder-----")
        if self.logger._enable:
            for page in results:
                self.logger.log(f'{page["score"]:.3f} + {page["title"]}')
        return results
    async def keywords(self, question: str, params: GenerationParams, threshold: float = 0.5) -> list[KeywordInfo]:
        num_queries = params.get("max_query", 1)
        copy_params = copy.deepcopy(params)
        copy_params.update(KEYWORDS_PARAMS) #type:ignore
        prompt = KEYWORD_TEMPLATE.format(question=question)
        text = ""
        async for chunk in await self(
            call_type=CallType.KEYWORDS, 
            instruction=KEYWORDS_INTRUCTION, 
            prompt=KEYWORDS_PREFIX.replace("{num}", str(num_queries))+prompt, 
            params=copy_params
        ):
            text += chunk
        try:
            self.logger.log(text)
            result: list[KeywordInfo] = json.loads(extract_json(text))
            for item in result:
                self.logger.log(item)
            return result
        except:
            print(text)
            traceback.print_exc()
            return []
    async def _heristic_rerank_page(self, pages: list[SearchResult], query: str, relative_threshold: float, params: GenerationParams) -> list[SearchResult]:
        """Rerank search results using embedding similarity"""
        self.logger.log("-----Original-----")
        if self.logger._enable:
            for page in pages:
                self.logger.log(f'{page["score"]:.3f} + {page["title"]}')
        import numpy as np
        def normalize_text(text: str) -> str:
            text = text.lower().strip()
            text = re.sub(r"[^a-zA-Z0-9\u00C0-\u1EF9\s\.,;]", " ", text)
            text = re.sub(r"\s+", " ", text).strip()
            return text
        def detect_school(query: str, schools: dict) -> str | None:
            """Detect school from query using predefined keywords"""
            for school, aliases in schools.items():
                if any(alias in query for alias in aliases):
                    return school
            return None
        schools = {
            school: [normalize_text(alias) for alias in aliases]
            for school, aliases in json.load(open(f"{BASE_PATH}files/school_alias.json", "r", encoding="utf-8")).items()
        }
        embedding = ws_pipeline.retriever.web_retriever.pipeline._rag.embedding
        
        # If no embedding model available, return original results
        if not embedding:
            return pages
        
        query_norm = normalize_text(query)
        detected_school = detect_school(query_norm, schools)
        
        try:
            query_emb = embedding.embed_query(query_norm)
            max_score = 0
            for page in pages:
                title = page.get("title", "") or ""
                desc = page.get("description", "") or ""
                url = page.get("url", "") or ""

                # Chuẩn hóa
                title_norm = normalize_text(title)
                desc_norm = normalize_text(desc)
                url_norm = normalize_text(url)

                # Semantic embedding
                title_emb = embedding.embed_query(title_norm) if title_norm else None
                desc_emb = embedding.embed_query(desc_norm) if desc_norm else None
                url_emb = embedding.embed_query(url_norm) if url_norm else None

                # Cosine similarity
                def cos_sim(a, b):
                    norm_a = np.linalg.norm(a)
                    norm_b = np.linalg.norm(b)
                    if norm_a == 0 or norm_b == 0:
                        return 0.0
                    return float(np.dot(a, b) / (norm_a * norm_b))

                score = 0.0
                weights = {"title": 0.5, "desc": 0.3, "url": 0.2}
                if title_emb is not None:
                    score += cos_sim(query_emb, title_emb) * weights["title"]
                if desc_emb is not None:
                    score += cos_sim(query_emb, desc_emb) * weights["desc"]
                if url_emb is not None:
                    score += cos_sim(query_emb, url_emb) * weights["url"]

                # Heuristic ưu tiên trường trong query
                if detected_school:
                    aliases = [normalize_text(a) for a in schools.get(detected_school, [])]
                    if any(a in text for a in aliases for text in [url_norm, title_norm, desc_norm]):
                        score += 0.5
                    else:
                        for school, other_aliases in schools.items():
                            if school != detected_school:
                                other_aliases_norm = [normalize_text(a) for a in other_aliases]
                                if any(a in text for a in other_aliases_norm for text in [url_norm, title_norm, desc_norm]):
                                    score -= 0.5

                # Heuristic boost
                if any(kw in query_norm for kw in ["tuyển sinh", "ngành đào tạo"]):
                    if "tuyensinh247" in url_norm:
                        score += 0.1
                    if url_norm.endswith(".edu") or ".edu.vn" in url_norm:
                        score += 0.2
                page["score"] = score
                max_score = max(score, max_score)
            threshold_score = max_score * relative_threshold
            # Sort theo score giảm dần
            results = []
            for page in pages:
                if page["score"] >= threshold_score:
                    results.append(page)
            results = sorted(results, key=lambda x: x["score"], reverse=True)
            self.logger.log("-----Reorder-----")
            if self.logger._enable:
                for page in results:
                    self.logger.log(f'{page["score"]:.3f} + {page["title"]}')
            return results
            
        except Exception:
            # If any error occurs, return original results
            return pages
    async def rerank_page(self, pages: list[SearchResult], query: str, relative_threshold: float, params: GenerationParams) -> list[SearchResult]:
        use_llm_rerank = params.get("llm_rerank", False)
        if use_llm_rerank:
            return await self._llm_rerank_page(pages, query, relative_threshold, params)
        else:
            return await self._heristic_rerank_page(pages, query, relative_threshold, params)

# %% [markdown]
# ##### Pipeline

# %%
class CombinedProtocol(ModelProtocol, KeywordModelProtocol, PageRerankModelProtocol, RouterModelProtocol):
    pass
class CustomQA:
    def __init__(self, model_protocol: CombinedProtocol) -> None:
        self.logger = CmdLogger("QA")
        web_retriever = WebRetriever(model_protocol, model_protocol)
        local_retriever = LocalRetriever()
        self.retriever = RouterRetriever(
            model_protocol,
            web_retriever,
            local_retriever
        )
        self.llm_call = model_protocol
    async def start(self):
        await self.retriever.web_retriever.start()
    async def inference(self, prompt: str, request: WorkerChatRequest) -> AsyncGenerator[str, None]:
        text = ""
        async for chunk in await self.llm_call(
            call_type=CallType.READER, 
            instruction=READER_INSTRUCTION, 
            prompt=prompt, 
            params=request["params"]
        ):
            text += chunk
            yield chunk
    async def pre_inference(
        self,
        question: str,
        stream_id: str,
        params: GenerationParams
    ) -> tuple[str, ModelPreOutput]:
        web_sources, rag_sources = await self.retriever.retrieve(
            question, 
            params
        )
        print("\n" + "=" * 80)
        print(f"[RAG CHUNKS] Total {len(rag_sources)} chunks selected for reader:")
        for idx, chunk in enumerate(rag_sources, 1):
            title = chunk.get("title", "N/A")
            url = chunk.get("url", "N/A")
            chunk_idx = chunk.get("chunk_index", "N/A")
            text_preview = chunk.get("text", "")[:400]
            print("-" * 80)
            print(f"[Chunk {idx}] title={title} | url={url} | chunk_index={chunk_idx}")
            print("Text preview:\n" + text_preview)
        if not rag_sources:
            print("[RAG CHUNKS] No chunks selected.")
        print("=" * 80)
        context = SourceFormat()(rag_sources)
        prompt = READER_TEMPLATE.format(context=context, question=question)
        print("\n" + "=" * 80)
        print("[RAG CONTEXT] Formatted chunks sent to reader:")
        print("-" * 80)
        print(context if context.strip() else "[Empty context]")
        print("=" * 80)
        print("[FINAL PROMPT] Qwen4B input:")
        print("-" * 80)
        print(prompt)
        print("=" * 80 + "\n")
        self.logger.start()
        pre_output: ModelPreOutput = {
            "generation_params": params,
            "web_sources": web_sources,
            "rag_sources": rag_sources,
            "extra_data": {
            },
            "result_url": stream_id,
        }
        return prompt, pre_output

# %% [markdown]
# ### Final

# %%
engine_args = AsyncEngineArgs(
    model=MODEL_ID,
    tensor_parallel_size=2,
    gpu_memory_utilization=0.7,
    max_model_len=32768,
    enable_lora=True,
    max_lora_rank=16,
    max_loras=1
)
vllm_model = VLLMModel()
vllm_model.init(engine_args)
# Out:
# [Reranker] Searching for adapter, BASE_PATH=/kaggle/working/, cwd=/kaggle/working
# [Reranker] Checking: app/package/lora/qwen_reranker_06b_v1 (exists: False)
# [Reranker] Path does not exist: app/package/lora/qwen_reranker_06b_v1
# [Reranker] Checking: /kaggle/working/app/package/lora/qwen_reranker_06b_v1 (exists: False)
# [Reranker] Path does not exist: /kaggle/working/app/package/lora/qwen_reranker_06b_v1
# [Reranker] Checking: /kaggle/working/lora/qwen_reranker_06b_v1 (exists: True)
# [Reranker] ✓ Found adapter at: /kaggle/working/lora/qwen_reranker_06b_v1
# [Reranker] Found adapter at: /kaggle/working/lora/qwen_reranker_06b_v1
# WARNING 11-28 06:36:25 [config.py:3392] Your device 'Tesla T4' (with compute capability 7.5) doesn't support torch.bfloat16. Falling back to torch.float16 for compatibility.
# WARNING 11-28 06:36:25 [config.py:3443] Casting torch.bfloat16 to torch.float16.
# INFO 11-28 06:36:25 [config.py:1604] Using max model len 32768
# INFO 11-28 06:36:25 [llm_engine.py:228] Initializing a V0 LLM engine (v0.10.0) with config: model='Qwen/Qwen3-4B', speculative_config=None, tokenizer='Qwen/Qwen3-4B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=2, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='xgrammar', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=None, served_model_name=Qwen/Qwen3-4B, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=None, chunked_prefill_enabled=False, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":[],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":false,"cudagraph_num_of_warmups":0,"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":256,"local_cache_dir":null}, use_cached_outputs=False,
# WARNING 11-28 06:36:26 [__init__.py:2899] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reason: CUDA is initialized
# WARNING 11-28 06:36:26 [multiproc_worker_utils.py:307] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# INFO 11-28 06:36:27 [cuda.py:346] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 11-28 06:36:27 [cuda.py:395] Using XFormers backend.
# 2025-11-28 06:36:30.575842: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764311790.595377    2760 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764311790.601377    2760 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO 11-28 06:36:36 [__init__.py:235] Automatically detected platform cuda.
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:37 [multiproc_worker_utils.py:226] Worker ready; awaiting tasks
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:38 [cuda.py:346] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:38 [cuda.py:395] Using XFormers backend.
# INFO 11-28 06:36:39 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:39 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:39 [pynccl.py:70] vLLM is using nccl==2.26.2
# INFO 11-28 06:36:39 [pynccl.py:70] vLLM is using nccl==2.26.2
# INFO 11-28 06:36:39 [custom_all_reduce_utils.py:246] reading GPU P2P access cache from /root/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:39 [custom_all_reduce_utils.py:246] reading GPU P2P access cache from /root/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# (VllmWorkerProcess pid=2760) WARNING 11-28 06:36:39 [custom_all_reduce.py:147] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 11-28 06:36:39 [custom_all_reduce.py:147] Custom allreduce is disabled because your platform lacks GPU P2P capability or P2P test failed. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# INFO 11-28 06:36:39 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1], buffer_handle=(1, 4194304, 6, 'psm_018ad986'), local_subscribe_addr='ipc:///tmp/19560551-041d-44bf-89ec-24cacdc6caaa', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 11-28 06:36:39 [parallel_state.py:1102] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:39 [parallel_state.py:1102] rank 1 in world size 2 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# INFO 11-28 06:36:39 [model_runner.py:1083] Starting to load model Qwen/Qwen3-4B...
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:39 [model_runner.py:1083] Starting to load model Qwen/Qwen3-4B...
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:40 [weight_utils.py:296] Using model weights format ['*.safetensors']
# INFO 11-28 06:36:40 [weight_utils.py:296] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/3 [00:00<?, ?it/s]
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:44 [default_loader.py:262] Loading weights took 3.85 seconds
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:44 [punica_selector.py:19] Using PunicaWrapperGPU.
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:45 [model_runner.py:1115] Model loading took 3.8589 GiB and 4.609806 seconds
# INFO 11-28 06:36:46 [default_loader.py:262] Loading weights took 5.32 seconds
# INFO 11-28 06:36:46 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 11-28 06:36:47 [model_runner.py:1115] Model loading took 3.8589 GiB and 6.140553 seconds
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:59 [worker.py:295] Memory profiling takes 11.69 seconds
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:59 [worker.py:295] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.70) = 10.32GiB
# (VllmWorkerProcess pid=2760) INFO 11-28 06:36:59 [worker.py:295] model weights take 3.86GiB; non_torch_memory takes 0.11GiB; PyTorch activation peak memory takes 1.68GiB; the rest of the memory reserved for KV Cache is 4.67GiB.
# INFO 11-28 06:36:59 [worker.py:295] Memory profiling takes 11.79 seconds
# INFO 11-28 06:36:59 [worker.py:295] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.70) = 10.32GiB
# INFO 11-28 06:36:59 [worker.py:295] model weights take 3.86GiB; non_torch_memory takes 0.11GiB; PyTorch activation peak memory takes 1.68GiB; the rest of the memory reserved for KV Cache is 4.67GiB.
# INFO 11-28 06:37:00 [executor_base.py:113] # cuda blocks: 4252, # CPU blocks: 3640
# INFO 11-28 06:37:00 [executor_base.py:118] Maximum concurrency for 32768 tokens per request: 2.08x
# (VllmWorkerProcess pid=2760) INFO 11-28 06:37:03 [model_runner.py:1385] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 11-28 06:37:03 [model_runner.py:1385] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/35 [00:00<?, ?it/s]
# (VllmWorkerProcess pid=2760) INFO 11-28 06:37:52 [model_runner.py:1537] Graph capturing finished in 49 secs, took 0.40 GiB
# INFO 11-28 06:37:52 [model_runner.py:1537] Graph capturing finished in 49 secs, took 0.40 GiB
# INFO 11-28 06:37:52 [llm_engine.py:424] init engine (profile, create kv cache, warmup model) took 64.86 seconds

# %% [markdown]
# Server wrapper

# %%
ws_pipeline = CustomQA(vllm_model)
await ws_pipeline.start()
import uuid
class ServerModelImplement(ServerModel):  
    def __init__(self) -> None:
        self.request_storage: dict[str, tuple[str, WorkerChatRequest, ModelPreOutput]] = {}
    async def pre_inference(self, request: WorkerChatRequest) -> ModelPreOutput:
        stream_id = str(uuid.uuid4())
        params = request["params"]
        print(params)
        prompt, pre_output = await ws_pipeline.pre_inference(
            request["text"],
            stream_id,
            request["params"]
        ) 
        self.request_storage[stream_id] = (prompt, request, pre_output)
        return pre_output
    async def inference(self, stream_id: str) -> AsyncGenerator[str, None]:
        prompt, request, pre_output = self.request_storage.pop(stream_id)
        generator = ws_pipeline.inference(prompt, request)
        total = ""
        try:
            async for chunk in generator:
                total += chunk
                yield chunk
        finally:
            # Store chat data when finish
            model_output: ModelOutput = {
                **pre_output,
                "text": total
            }
            data: WorkerStoreChatData = {
                "forward_kwargs": request["forward_kwargs"],
                "model_output": model_output
            }
            await self.store(data)

# %% [markdown]
# Connect to server

# %%
server_model = ServerModelImplement()
app = construct_app(
    server_domain=DOMAIN,
    info=CLIENT_INFO,
    server_model=server_model,
    init_tasks=[],
    shutdown_tasks=[],
    is_local=IS_LOCAL
)
# CORS policy
from fastapi.middleware.cors import CORSMiddleware
origins = [
    "http://127.0.0.1:8000", # I don't know why, but this won't work if not add this while in kaggle
    DOMAIN
]
app.add_middleware(
    CORSMiddleware,
    allow_origins=origins,
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"]
)
import uvicorn

uvicorn_config = uvicorn.Config(app, port=NGROK_PORT)
uvicorn_server = uvicorn.Server(uvicorn_config)
await uvicorn_server.serve()
# Out:
# INFO:     Started server process [2695]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8002 (Press CTRL+C to quit)
# Domain: https://venturously-unfendered-seth.ngrok-free.dev
# {'model_id': 'Qwen/Qwen3-4B$$$1', 'use_websearch': True, 'use_localdb': False, 'max_query': 3, 'query_score_threshold': 0.5, 'engine_type': 'google', 'domain_restrict': False, 'school_domain': True, 'llm_rerank': False, 'page_score_threshold': 0.5, 'chunk_score_threshold': 0.5, 'k_docs': 5, 'k_pages': 3, 'page_rerank': False, 'chunk_rerank': False, 'include_pdf': True, 'include_image': False, 'merge_table': False, 'merge_neighbor': False, 'max_tokens': 2048, 'temperature': 0.5, 'top_p': 0.9, 'top_k': 40, 'max_history': 8}
# [VLLM] CallType.KEYWORDS | Instruction length: 168 | Prompt length: 8629 | kwargs: None
# INFO 11-28 06:38:48 [chat_utils.py:473] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# INFO 11-28 06:38:48 [async_llm_engine.py:209] Added request 1576dbdd3c1342a49c9483cfea371feb.
# INFO 11-28 06:38:49 [metrics.py:386] Avg prompt throughput: 51.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.4%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:38:51 [async_llm_engine.py:177] Finished request 1576dbdd3c1342a49c9483cfea371feb.
# [Model] [
#   {
#     "query": "học phí uet 2025-2026",
#     "priority": 1.0,
#     "info": "thông tin học phí năm học 2025-2026",
#     "school": "uet"
#   }
# ]
# [Model] {'query': 'học phí uet 2025-2026', 'priority': 1.0, 'info': 'thông tin học phí năm học 2025-2026', 'school': 'uet'}
# [DOMAINS] ['uet.vnu.edu.vn']
# [Retriever] Manual llm_rerank=OFF (query_count=1)
# [Retriever] Manual chunk_rerank=OFF (query_count=1)
# [Retriever] Websearch: 0.33535s
# [Retriever] Rerank: Skip (llm_rerank=False)
# [Snippet] ✗ Cần crawl:
#   Title: Định mức học phí các chương trình đào tạo năm học 2025-2026 ...
#   URL: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/
#   Snippet: Oct 2, 2025 ... Định mức học phí các chương trình đào tạo năm học 2025-2026. Căn ... Điện thoại: 024.37547.461; Email: uet@vnu.edu.vn. Giới thiệu · Lị...
# [Snippet] ✗ Cần crawl:
#   Title: Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...
#   URL: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/
#   Snippet: – Nhà trường dự kiến thu học phí học kỳ I năm học 2025-2026 và các khoản nợ ... Điện thoại: 024.37547.461; Email: uet@vnu.edu.vn. Giới thiệu · Lịch sử...
# [Snippet] ✗ Cần crawl:
#   Title: Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...
#   URL: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/
#   Snippet: Theo thông báo ngày 17/9/2025: https://uet.vnu.edu.vn/nop-ho-mien-giam-hoc-phi-hoc-ky-nam-hoc-2025-2026/. Hiện nay đã hết thời gian gian nộp hồ sơ MGH...
# [Snippet] ✗ Cần crawl:
#   Title: Quy định định mức học phí đào tạo đại học năm học 2024-2025 ...
#   URL: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-dao-tao-dai-hoc-nam-hoc-2024-2025/
#   Snippet: Oct 3, 2024 ... Kết quả học bổng BIDV năm học 2025-2026 · Đề nghị danh sách sinh viên ... Điện thoại: 024.37547.461; Email: uet@vnu.edu.vn. Giới thiệu...
# [Snippet] ✗ Cần crawl:
#   Title: Miễn giảm học phí và kinh phí được hưởng theo chế độ, trong học ...
#   URL: https://uet.vnu.edu.vn/mien-giam-hoc-phi-va-kinh-phi-duoc-huong-theo-che-trong-hoc-ky-nam-hoc-2024-2025-cua-sinh-vien-dai-hoc-chinh-quy-truong-dai-hoc-cong-nghe/
#   Snippet: Nov 14, 2024 ... Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học 2025-2026 ... Điện thoại: 024.37547.461; Email: uet@vnu.edu.vn. Giới...
# [Snippet] ✗ Cần crawl:
#   Title: Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...
#   URL: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hkii-nam-hoc-2024-2025/
#   Snippet: Triển khai Chương trình Học bổng Toyota năm học 2025 – 2026 · Kết quả Học bổng ... Facebook: https://www.facebook.com/UET.VNUH Điện thoại: 024.37547.4...
# [Snippet] ✗ Cần crawl:
#   Title: Quy định mức học bổng khuyến khích học tập cho sinh viên đại học ...
#   URL: https://uet.vnu.edu.vn/quy-dinh-muc-hoc-bong-khuyen-khich-hoc-tap-cho-sinh-vien-dai-hoc-he-chinh-quy-trong-nam-hoc-2025-2026/
#   Snippet: Oct 27, 2025 ... ... học phí đào tạo đại học năm học 2025-2026;. Căn cứ tờ trình ngày 23 ... Điện thoại: 024.37547.461; Email: uet@vnu.edu.vn. Giới th...
# [Snippet] ✗ Cần crawl:
#   Title: Triển khai thu HP của HVCH/NCS trong HKI năm học 2025-2026 ...
#   URL: https://uet.vnu.edu.vn/trien-khai-thu-hp-cua-hvch-ncs-trong-hki-nam-hoc-2025-2026/
#   Snippet: Ghi chú: Người học sẽ phải hoàn thành tất cả các khoản nợ (nếu có) và học phí của học kỳ I năm học 2025-2026. ... Điện thoại: 024.37547.461; Email: ue...
# [Snippet] ✗ Cần crawl:
#   Title: Quyết định thu học phí của sinh viên Trường Đại học Công nghệ ...
#   URL: https://uet.vnu.edu.vn/thu-hoc-phi-cua-sinh-vien-truong-dai-hoc-cong-nghe-thuoc-doi-tuong-duoc-mien-giam-hoc-phi-trong-hki-nam-hoc-2025-2026/
#   Snippet: Nov 6, 2025 ... Thu học phí HKI năm học 2025-2026 của sinh viên Trường Đại học Công ... Điện thoại: 024.37547.461; Email: uet@vnu.edu.vn. Giới thiệu.
# [Snippet] ✗ Cần crawl:
#   Title: Học bổng Posco, Hàn Quốc năm học 2025-2026 - Trường Đại học ...
#   URL: https://www.uet.vnu.edu.vn/hoc-bong-posco-han-quoc-nam-hoc-2025-2026/
#   Snippet: Sep 3, 2025 ... SINH VIÊN. Thông báo · Học phí, học bổng · Chế độ chính sách · Thông tin ... Điện thoại: 024.37547.461; Email: uet@vnu.edu.vn. Giới th...
# [Retriever] Snippet Check: 0.00060s
# [Download] Bắt đầu crawl 10 URL(s)...
# [Page download] Attempt to download 3 pages from 10 urls (PARALLEL, tối đa 3 request cùng lúc)
# [Page download] ✓ Thành công (premium): https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian...
# [Page download] ✓ Thành công (premium): https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao...
# [Page download] ✓ Thành công (premium): https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-gia...
# [Page download] Tổng requests đã gửi: 3 (bao gồm cả cancelled)
# [Page download] Success download 3 pages
# [Page download] ScrapingBee requests: 3 (regular: 0, premium: 3)
# [Page download] ScrapingBee credits used: 30 (regular: 0x1, premium: 3x10)
# [Download] Snippet đủ: 0, Đã crawl: 3
# [Download] Thời gian crawl: 3.13s (trung bình 0.31s/URL)
#
# [PDF SEARCH] Đang tìm PDF trong: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/
# [PDF SEARCH] Tổng số links tìm thấy: 1
# [PDF SEARCH] PDF links trực tiếp từ links: 1
# [PDF SEARCH]   - đính kèm: https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/Dinh-muc-hoc-phi-nam-hoc-2025-2026.pdf
# [Attachment search] Tổng số links kiểm tra: 8, tìm thấy: 0
# [PDF SEARCH] Attachment links tìm thấy: 0
# [PDF SEARCH] PDF links từ attachment: 0
# [PDF SEARCH] Non-PDF attachment links: 0
# [PDF SEARCH] Tổng số PDF jobs: 1
#
# [PDF SEARCH] Đang tìm PDF trong: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/
# [PDF SEARCH] Tổng số links tìm thấy: 1
# [PDF SEARCH] PDF links trực tiếp từ links: 1
# [PDF SEARCH]   - 5-Đơn-xin-nộp-học-phí- muộn.pdf (vnu.edu.vn ): https://2489013871.e.cdneverest.net/uet.edu.vn/2017/07/5-%C4%90%C6%A1n-xin-n%E1%BB%99p-h%E1%BB%8Dc-ph%C3%AD-mu%E1%BB%99n.pdf
# [Attachment search] Tổng số links kiểm tra: 7, tìm thấy: 0
# [PDF SEARCH] Attachment links tìm thấy: 0
# [PDF SEARCH] PDF links từ attachment: 0
# [PDF SEARCH] Non-PDF attachment links: 0
# [PDF SEARCH] Tổng số PDF jobs: 1
#
# [PDF SEARCH] Đang tìm PDF trong: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/
# [PDF SEARCH] Tổng số links tìm thấy: 2
# [PDF SEARCH] PDF links trực tiếp từ links: 2
# [PDF SEARCH]   - đính kèm: https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/DS-2-TIEP-TUC-DUOC-MGHP.pdf
# [PDF SEARCH]   - đính kèm: https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/DS2_DUOC-XET-DU-HO-SO.pdf
# [Attachment search] Tổng số links kiểm tra: 9, tìm thấy: 0
# [PDF SEARCH] Attachment links tìm thấy: 0
# [PDF SEARCH] PDF links từ attachment: 0
# [PDF SEARCH] Non-PDF attachment links: 0
# [PDF SEARCH] Tổng số PDF jobs: 2
# /kaggle/working/data_retriever/retriever_pipeline.py:354: RuntimeWarning: coroutine 'PageDowloader._download_task' was never awaited
#   return await self._page_downloader.download(search_results, k_pages, include_pdf, include_image)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# [CRAWL PDF] ✓ đính kèm... (3053 chars)
# [PDF SEARCH] PDF đã tải thành công: 1/1
# [PDF SEARCH] Kết quả cuối cùng: 1 PDF links, 1 PDF files đã tải
#
# [CRAWL] https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao... | 2306 chars | 1 PDFs
# [CRAWL PDF] ✓ đính kèm... (3093 chars)
# [CRAWL PDF] ✓ 5-Đơn-xin-nộp-học-phí- muộn.pdf (vnu.edu.vn )... (1179 chars)
# [PDF SEARCH] PDF đã tải thành công: 1/1
# [PDF SEARCH] Kết quả cuối cùng: 1 PDF links, 1 PDF files đã tải
#
# [CRAWL] https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian... | 2093 chars | 1 PDFs
# [CRAWL PDF] ✓ đính kèm... (10366 chars)
# [PDF SEARCH] PDF đã tải thành công: 2/2
# [PDF SEARCH] Kết quả cuối cùng: 2 PDF links, 2 PDF files đã tải
#
# [CRAWL] https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-gia... | 2432 chars | 2 PDFs
# [Retriever] Process: 2.02342s
# Split 3784 characters to 5 chunks
# Split Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ... to 5 chunks
# [Retriever] [Split] Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...: total 5 chunks
# [Retriever] [Split] chunk#0: --- source_url: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Kiểm tra dữ liệu và dự kiến thời ...
# [Retriever] [Split] chunk#1: ### Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong HKI, năm học 2025-2026 Phòng Công tác Sinh viên thông báo Danh sách các sinh viên đã đăng ký môn học và dự kiến thu học phí tr...
# [Retriever] [Split] chunk#2: + Sinh viên thuộc chương trình đào tạo chuẩn thuộc khóa QH-2022 trở về trước và QH-2023, 2024, 2025, TT23 có môn học lại, cải thiện điểm, học tự do sẽ thu học phí tín chỉ: xem sheet HP tín chỉ . + Các...
# [Retriever] [Split] ... (+2 more)
# Split 5767 characters to 9 chunks
# Split Định mức học phí các chương trình đào tạo năm học 2025-2026 ... to 9 chunks
# [Retriever] [Split] Định mức học phí các chương trình đào tạo năm học 2025-2026 ...: total 9 chunks
# [Retriever] [Split] chunk#0: --- source_url: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Định mức học phí các chương trình đào tạo năm học 2025-2026 ... c...
# [Retriever] [Split] chunk#1: ### Định mức học phí các chương trình đào tạo năm học 2025-2026
# [Retriever] [Split] chunk#2: Căn cứ Quyết định số 3568/QĐ-ĐHQGHN ngày 08 tháng 10 năm 2014 của Giám đốc Đại học Quốc gia Hà Nội (ĐHQGHN) quy định về Tổ chức và hoạt động của các đơn vị thành viên và đơn vị trực thuộc ĐHQGHN; Căn ...
# [Retriever] [Split] ... (+6 more)
# Split 16431 characters to 23 chunks
# Split Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ... to 23 chunks
# [Retriever] [Split] Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...: total 23 chunks
# [Retriever] [Split] chunk#0: --- source_url: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học...
# [Retriever] [Split] chunk#1: ### Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học 2025-2026 Theo thông báo ngày 17/9/2025: https://uet.vnu. edu.vn/nop-ho-mien-giam-hoc- phi-hoc-ky-nam-hoc-2025-2026/ Hiện nay đã hế...
# [Retriever] [Split] chunk#2: 1. Danh sách 1: sinh viên được miễn, giảm học phí trong HKII, 2024-2025, tiếp tục được miễn/giảm học phí trong HKI, 2025-2026 (không phải làm lại hồ sơ xin hưởng chế độ) ( đính kèm ) : nếu sinh viên c...
# [Retriever] [Split] ... (+20 more)
# [Retriever] [RAG] Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...: total 2 chunks
# [Retriever] [RAG] chunk#0: --- source_url: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Kiểm tra dữ liệu và dự kiến thời ...
# [Retriever] [RAG] chunk#2: + Sinh viên thuộc chương trình đào tạo chuẩn thuộc khóa QH-2022 trở về trước và QH-2023, 2024, 2025, TT23 có môn học lại, cải thiện điểm, học tự do sẽ thu học phí tín chỉ: xem sheet HP tín chỉ . + Các...
# [Retriever] [Merge] Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...: total 2 chunks
# [Retriever] [Merge] chunk#0: --- source_url: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Kiểm tra dữ liệu và dự kiến thời ...
# [Retriever] [Merge] chunk#2: + Sinh viên thuộc chương trình đào tạo chuẩn thuộc khóa QH-2022 trở về trước và QH-2023, 2024, 2025, TT23 có môn học lại, cải thiện điểm, học tự do sẽ thu học phí tín chỉ: xem sheet HP tín chỉ . + Các...
# [Retriever] [RAG] Định mức học phí các chương trình đào tạo năm học 2025-2026 ...: total 2 chunks
# [Retriever] [RAG] chunk#0: --- source_url: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Định mức học phí các chương trình đào tạo năm học 2025-2026 ... c...
# [Retriever] [RAG] chunk#1: ### Định mức học phí các chương trình đào tạo năm học 2025-2026
# [Retriever] [Merge] Định mức học phí các chương trình đào tạo năm học 2025-2026 ...: total 2 chunks
# [Retriever] [Merge] chunk#0: --- source_url: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Định mức học phí các chương trình đào tạo năm học 2025-2026 ... c...
# [Retriever] [Merge] chunk#1: ### Định mức học phí các chương trình đào tạo năm học 2025-2026
# [Retriever] [Prioritize] Added 1 table chunks before retrieval output
# [Retriever] [RAG] Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...: total 3 chunks
# [Retriever] [RAG] chunk#3: 4. Danh sách 4: sinh viên đã nộp hồ sơ nhưng chưa đăng kí online đề nghị miễn/giảm học phí trong HKI, 2025-2026: đề nghị sinh viên đăng kí online trước 15h ngày 23/10/2025, theo hướng dẫn ở đường link...
# [Retriever] [RAG] chunk#0: --- source_url: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học...
# [Retriever] [RAG] chunk#2: 1. Danh sách 1: sinh viên được miễn, giảm học phí trong HKII, 2024-2025, tiếp tục được miễn/giảm học phí trong HKI, 2025-2026 (không phải làm lại hồ sơ xin hưởng chế độ) ( đính kèm ) : nếu sinh viên c...
# [Retriever] [Merge] Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...: total 3 chunks
# [Retriever] [Merge] chunk#3: 4. Danh sách 4: sinh viên đã nộp hồ sơ nhưng chưa đăng kí online đề nghị miễn/giảm học phí trong HKI, 2025-2026: đề nghị sinh viên đăng kí online trước 15h ngày 23/10/2025, theo hướng dẫn ở đường link...
# [Retriever] [Merge] chunk#0: --- source_url: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/ crawl_date: 2025-11-28 page_title: Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học...
# [Retriever] [Merge] chunk#2: 1. Danh sách 1: sinh viên được miễn, giảm học phí trong HKII, 2024-2025, tiếp tục được miễn/giảm học phí trong HKI, 2025-2026 (không phải làm lại hồ sơ xin hưởng chế độ) ( đính kèm ) : nếu sinh viên c...
# [Retriever] RAG: 0.51957s
# https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/
# https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/
# https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/
#
# ================================================================================
# [RAG CHUNKS] Total 7 chunks selected for reader:
# --------------------------------------------------------------------------------
# [Chunk 1] title=Định mức học phí các chương trình đào tạo năm học 2025-2026 ... | url=https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/ | chunk_index=0
# Text preview:
# ---
# source_url: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Định mức học phí các chương trình đào tạo năm học 2025-2026 ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/Dinh-muc-hoc-phi-nam-hoc-2025-2026.pdf
# ---
# --------------------------------------------------------------------------------
# [Chunk 2] title=Định mức học phí các chương trình đào tạo năm học 2025-2026 ... | url=https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/ | chunk_index=1
# Text preview:
# ### Định mức học phí các chương trình đào tạo năm học 2025-2026
# --------------------------------------------------------------------------------
# [Chunk 3] title=Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ... | url=https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/ | chunk_index=0
# Text preview:
# ---
# source_url: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2017/07/5-%C4%90%C6%A1n-xin-n%E1%BB%99p-h%E1%BB%8Dc-ph%C3%AD-mu%E1
# --------------------------------------------------------------------------------
# [Chunk 4] title=Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ... | url=https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/ | chunk_index=2
# Text preview:
# + Sinh viên thuộc chương trình đào tạo chuẩn thuộc khóa QH-2022 trở về trước và QH-2023, 2024, 2025, TT23 có môn học lại, cải thiện điểm, học tự do sẽ thu học phí tín chỉ: xem sheet HP tín chỉ .
# + Các môn học đăng kí lần đầu của Sinh viên thuộc khóa QH-2023, 2024, 2025 và TT23 sẽ thu học phí niên chế: xem các sheet niên chế tương ứng. + Các sinh viên khác xem ở các sheet tương ứng với đối tượng củ
# --------------------------------------------------------------------------------
# [Chunk 5] title=Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ... | url=https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/ | chunk_index=3
# Text preview:
# 4. Danh sách 4: sinh viên đã nộp hồ sơ nhưng chưa đăng kí online đề nghị miễn/giảm học phí trong HKI, 2025-2026: đề nghị sinh viên đăng kí online trước 15h ngày 23/10/2025, theo hướng dẫn ở đường link trên.
# [BẢNG]
# [BẢNG]
# |1|25023774|Đặng Minh Hiếu|
# |---|---|---|
# |2|24021890|Nguyễn Quang Minh|
# |3|25021614|Đặng Ngọc Anh|
# |4|25021914|Lê Thị Bảo Ngọc|
# |5|25023413|Trần Xuân Triều|
# |6|25022972|Nguyễ
# --------------------------------------------------------------------------------
# [Chunk 6] title=Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ... | url=https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/ | chunk_index=0
# Text preview:
# ---
# source_url: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/DS-2-TIEP-TUC-DUOC-MGHP.pdf
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025
# --------------------------------------------------------------------------------
# [Chunk 7] title=Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ... | url=https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/ | chunk_index=2
# Text preview:
# 1. Danh sách 1: sinh viên được miễn, giảm học phí trong HKII, 2024-2025, tiếp tục được miễn/giảm học phí trong HKI, 2025-2026 (không phải làm lại hồ sơ xin hưởng chế độ) ( đính kèm ) : nếu sinh viên có tên trong danh sách này không có nguyện vọng hưởng chế độ MGHP trong HKI năm học 2025-2026 thì nộp đơn tại phòng CTSV (210-G2), thời hạn cuối để nhận đơn là 15h ngày 23/10/2025.
# 2. Danh sách 2: sinh
# ================================================================================
#
# ================================================================================
# [RAG CONTEXT] Formatted chunks sent to reader:
# --------------------------------------------------------------------------------
# **Nguồn**: [**Định mức học phí các chương trình đào tạo năm học 2025-2026 ...**](https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/)
#
# ---
# source_url: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Định mức học phí các chương trình đào tạo năm học 2025-2026 ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/Dinh-muc-hoc-phi-nam-hoc-2025-2026.pdf
# ---
#
# ### Định mức học phí các chương trình đào tạo năm học 2025-2026
#
# ---
#
# **Nguồn**: [**Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...**](https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/)
#
# ---
# source_url: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2017/07/5-%C4%90%C6%A1n-xin-n%E1%BB%99p-h%E1%BB%8Dc-ph%C3%AD-mu%E1%BB%99n.pdf
# ---
#
# + Sinh viên thuộc chương trình đào tạo chuẩn thuộc khóa QH-2022 trở về trước và QH-2023, 2024, 2025, TT23 có môn học lại, cải thiện điểm, học tự do sẽ thu học phí tín chỉ: xem sheet HP tín chỉ .
# + Các môn học đăng kí lần đầu của Sinh viên thuộc khóa QH-2023, 2024, 2025 và TT23 sẽ thu học phí niên chế: xem các sheet niên chế tương ứng. + Các sinh viên khác xem ở các sheet tương ứng với đối tượng của mình được hưởng. + Sinh viên được miễn/giảm học phí sẽ có thông báo sau. + Sinh viên thuộc nhóm tiếp nhận từ HVKHQS sẽ có DS thu riêng. 2. Lưu ý chung:
# – Sinh viên kiểm tra thông tin, nếu thấy sai sót thì làm đơn gửi Phòng CTSV (P.210-G2) hoặc gửi email về hộp thư hangtt @vnu.edu.vn trước 11h00, ngày 29/10/2025. Nhà trường sẽ không giải quyết các sai sót của sinh viên sau thời hạn nói trên.
# – Nhà trường dự kiến thu học phí học kỳ I năm học 2025-2026 và các khoản nợ (nếu có) của sinh viên trong khoảng thời gian từ ngày 04/11/2025 đến hết ngày 05/12/2025 (sẽ có thông báo cụ thể về thời gian và hình thức nộp tiền, những sinh viên còn dư học phí từ kì trước sẽ được đối trừ trong thông báo thu).
#
# ---
#
# **Nguồn**: [**Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...**](https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/)
#
# 4. Danh sách 4: sinh viên đã nộp hồ sơ nhưng chưa đăng kí online đề nghị miễn/giảm học phí trong HKI, 2025-2026: đề nghị sinh viên đăng kí online trước 15h ngày 23/10/2025, theo hướng dẫn ở đường link trên.
# [BẢNG]
# [BẢNG]
# |1|25023774|Đặng Minh Hiếu|
# |---|---|---|
# |2|24021890|Nguyễn Quang Minh|
# |3|25021614|Đặng Ngọc Anh|
# |4|25021914|Lê Thị Bảo Ngọc|
# |5|25023413|Trần Xuân Triều|
# |6|25022972|Nguyễn Tấn Phát|
# |7|25023522|Đặng Trần Minh Quốc|
# |8|25022808|Nguyễn Hữu Dũng|
# Đề nghị các sinh viên có tên trong các danh sách trên kiểm tra thông tin cá nhân, nếu có sai sót xin vui lòng gửi thắc mắc tới hộp thư hangtt@vnu.edu.vn hoặc làm việc trực tiếp tại phòng CTSV (210-G2).
# Sau ngày 23/10/2025, phòng CTSV sẽ kính trình Ban Giám Hiệu và thực hiện theo trình tự công việc để ban hành Quyết định MGHP, sau khi có phê duyệt của Ban Giám Hiệu.
# Trân trọng thông báo! Bởi Tuyết Nga 22/10/2025 Chế độ chính sách 522 lượt xem
# ---
#
# ---
# source_url: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/DS-2-TIEP-TUC-DUOC-MGHP.pdf
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/DS2_DUOC-XET-DU-HO-SO.pdf
# ---
#
# 1. Danh sách 1: sinh viên được miễn, giảm học phí trong HKII, 2024-2025, tiếp tục được miễn/giảm học phí trong HKI, 2025-2026 (không phải làm lại hồ sơ xin hưởng chế độ) ( đính kèm ) : nếu sinh viên có tên trong danh sách này không có nguyện vọng hưởng chế độ MGHP trong HKI năm học 2025-2026 thì nộp đơn tại phòng CTSV (210-G2), thời hạn cuối để nhận đơn là 15h ngày 23/10/2025.
# 2. Danh sách 2: sinh viên đã nộp hồ sơ + đăng kí online, đủ điều kiện để đề nghị miễn/giảm học phí trong HKI, 2025-2026 ( đính kèm ).
# 3. Danh sách 3: s inh viên đã đăng kí online nhưng chưa nộp hồ sơ đề nghị miễn/giảm học phí trong HKI, 2025-2026: đề nghị sinh viên có tên trong danh sách này nộp hồ sơ tại phòng CTSV (210-G2), thời hạn cuối để nhận đơn là 15h ngày 23/10/2025 (các sinh viên đang học GDQPAN ở Hòa lạc có thể scan hồ sơ và gửi về hộp thư hangtt@vnu.edu.vn , hồ sơ bản gốc nộp sau khi hoàn thành khóa học).
# [BẢNG]
# [BẢNG]
# |1|22029062|Phùng Quốc Việt|
# |---|---|---|
# |2|23020634|Hà Thị Kim Oanh|
# |3|23021385|Bùi Mạnh Dũng|
# |4|23021875|Đinh Đăng Ngọc|
# |5|25021010|Phan Đình Quý|
# |6|25021115|Phạm Anh Vũ|
# |7|24020945|Nguyễn Anh Đức|
# |8|24022292|Lê Minh Đức|
# ================================================================================
# [FINAL PROMPT] Qwen4B input:
# --------------------------------------------------------------------------------
# Hiện tại là năm 2025, sử dụng thông tin mới nhất có thể.
# Nếu không tìm thấy đủ dữ liệu đáng tin để xây dựng đầy đủ theo form, chỉ trả lời: "Tôi không tìm thấy thông tin phù hợp.".
# Thông tin tham khảo:
# **Nguồn**: [**Định mức học phí các chương trình đào tạo năm học 2025-2026 ...**](https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/)
#
# ---
# source_url: https://uet.vnu.edu.vn/dinh-muc-hoc-phi-cac-chuong-trinh-dao-tao-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Định mức học phí các chương trình đào tạo năm học 2025-2026 ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/Dinh-muc-hoc-phi-nam-hoc-2025-2026.pdf
# ---
#
# ### Định mức học phí các chương trình đào tạo năm học 2025-2026
#
# ---
#
# **Nguồn**: [**Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...**](https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/)
#
# ---
# source_url: https://uet.vnu.edu.vn/kiem-tra-du-lieu-va-du-kien-thoi-gian-thu-hoc-phi-cua-sinh-vien-trong-hki-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Kiểm tra dữ liệu và dự kiến thời gian thu học phí của sinh viên trong ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2017/07/5-%C4%90%C6%A1n-xin-n%E1%BB%99p-h%E1%BB%8Dc-ph%C3%AD-mu%E1%BB%99n.pdf
# ---
#
# + Sinh viên thuộc chương trình đào tạo chuẩn thuộc khóa QH-2022 trở về trước và QH-2023, 2024, 2025, TT23 có môn học lại, cải thiện điểm, học tự do sẽ thu học phí tín chỉ: xem sheet HP tín chỉ .
# + Các môn học đăng kí lần đầu của Sinh viên thuộc khóa QH-2023, 2024, 2025 và TT23 sẽ thu học phí niên chế: xem các sheet niên chế tương ứng. + Các sinh viên khác xem ở các sheet tương ứng với đối tượng của mình được hưởng. + Sinh viên được miễn/giảm học phí sẽ có thông báo sau. + Sinh viên thuộc nhóm tiếp nhận từ HVKHQS sẽ có DS thu riêng. 2. Lưu ý chung:
# – Sinh viên kiểm tra thông tin, nếu thấy sai sót thì làm đơn gửi Phòng CTSV (P.210-G2) hoặc gửi email về hộp thư hangtt @vnu.edu.vn trước 11h00, ngày 29/10/2025. Nhà trường sẽ không giải quyết các sai sót của sinh viên sau thời hạn nói trên.
# – Nhà trường dự kiến thu học phí học kỳ I năm học 2025-2026 và các khoản nợ (nếu có) của sinh viên trong khoảng thời gian từ ngày 04/11/2025 đến hết ngày 05/12/2025 (sẽ có thông báo cụ thể về thời gian và hình thức nộp tiền, những sinh viên còn dư học phí từ kì trước sẽ được đối trừ trong thông báo thu).
#
# ---
#
# **Nguồn**: [**Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...**](https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/)
#
# 4. Danh sách 4: sinh viên đã nộp hồ sơ nhưng chưa đăng kí online đề nghị miễn/giảm học phí trong HKI, 2025-2026: đề nghị sinh viên đăng kí online trước 15h ngày 23/10/2025, theo hướng dẫn ở đường link trên.
# [BẢNG]
# [BẢNG]
# |1|25023774|Đặng Minh Hiếu|
# |---|---|---|
# |2|24021890|Nguyễn Quang Minh|
# |3|25021614|Đặng Ngọc Anh|
# |4|25021914|Lê Thị Bảo Ngọc|
# |5|25023413|Trần Xuân Triều|
# |6|25022972|Nguyễn Tấn Phát|
# |7|25023522|Đặng Trần Minh Quốc|
# |8|25022808|Nguyễn Hữu Dũng|
# Đề nghị các sinh viên có tên trong các danh sách trên kiểm tra thông tin cá nhân, nếu có sai sót xin vui lòng gửi thắc mắc tới hộp thư hangtt@vnu.edu.vn hoặc làm việc trực tiếp tại phòng CTSV (210-G2).
# Sau ngày 23/10/2025, phòng CTSV sẽ kính trình Ban Giám Hiệu và thực hiện theo trình tự công việc để ban hành Quyết định MGHP, sau khi có phê duyệt của Ban Giám Hiệu.
# Trân trọng thông báo! Bởi Tuyết Nga 22/10/2025 Chế độ chính sách 522 lượt xem
# ---
#
# ---
# source_url: https://uet.vnu.edu.vn/cap-nhat-danh-sach-nop-ho-so-mien-giam-hoc-phi-hoc-ky-i-nam-hoc-2025-2026/
# crawl_date: 2025-11-28
# page_title: Cập nhật danh sách nộp hồ sơ miễn giảm học phí, học kỳ I năm học ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/DS-2-TIEP-TUC-DUOC-MGHP.pdf
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/10/DS2_DUOC-XET-DU-HO-SO.pdf
# ---
#
# 1. Danh sách 1: sinh viên được miễn, giảm học phí trong HKII, 2024-2025, tiếp tục được miễn/giảm học phí trong HKI, 2025-2026 (không phải làm lại hồ sơ xin hưởng chế độ) ( đính kèm ) : nếu sinh viên có tên trong danh sách này không có nguyện vọng hưởng chế độ MGHP trong HKI năm học 2025-2026 thì nộp đơn tại phòng CTSV (210-G2), thời hạn cuối để nhận đơn là 15h ngày 23/10/2025.
# 2. Danh sách 2: sinh viên đã nộp hồ sơ + đăng kí online, đủ điều kiện để đề nghị miễn/giảm học phí trong HKI, 2025-2026 ( đính kèm ).
# 3. Danh sách 3: s inh viên đã đăng kí online nhưng chưa nộp hồ sơ đề nghị miễn/giảm học phí trong HKI, 2025-2026: đề nghị sinh viên có tên trong danh sách này nộp hồ sơ tại phòng CTSV (210-G2), thời hạn cuối để nhận đơn là 15h ngày 23/10/2025 (các sinh viên đang học GDQPAN ở Hòa lạc có thể scan hồ sơ và gửi về hộp thư hangtt@vnu.edu.vn , hồ sơ bản gốc nộp sau khi hoàn thành khóa học).
# [BẢNG]
# [BẢNG]
# |1|22029062|Phùng Quốc Việt|
# |---|---|---|
# |2|23020634|Hà Thị Kim Oanh|
# |3|23021385|Bùi Mạnh Dũng|
# |4|23021875|Đinh Đăng Ngọc|
# |5|25021010|Phan Đình Quý|
# |6|25021115|Phạm Anh Vũ|
# |7|24020945|Nguyễn Anh Đức|
# |8|24022292|Lê Minh Đức|
# Câu hỏi:
# học phí uet 2025-2026
# ================================================================================
#
# INFO:     2001:ee0:41c1:7d7:6564:d330:7315:67c1:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2001:ee0:41c1:7d7:6564:d330:7315:67c1:0 - "POST /inference/c4d8a642-ac7e-4b76-875f-3b414dca2eeb HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 362 | Prompt length: 5251 | kwargs: None
# [VLLm] Using Qwen Reader Lora
# INFO 11-28 06:38:59 [async_llm_engine.py:209] Added request 28406199a0384bf99539925bcd336b46.
# INFO 11-28 06:39:00 [metrics.py:386] Avg prompt throughput: 214.9 tokens/s, Avg generation throughput: 6.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 3.3%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:05 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.9 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 3.5%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:10 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 3.8%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:15 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.0%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:20 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.1 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.2%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:25 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.3 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.4%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:30 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.5 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.7%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:35 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.9%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:40 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.1%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:39:44 [async_llm_engine.py:177] Finished request 28406199a0384bf99539925bcd336b46.
# {'model_id': 'Qwen/Qwen3-4B$$$1', 'use_websearch': True, 'use_localdb': False, 'max_query': 3, 'query_score_threshold': 0.5, 'engine_type': 'google', 'domain_restrict': False, 'school_domain': True, 'llm_rerank': False, 'page_score_threshold': 0.5, 'chunk_score_threshold': 0.5, 'k_docs': 5, 'k_pages': 3, 'page_rerank': False, 'chunk_rerank': False, 'include_pdf': True, 'include_image': False, 'merge_table': False, 'merge_neighbor': False, 'max_tokens': 2048, 'temperature': 0.5, 'top_p': 0.9, 'top_k': 40, 'max_history': 8}
# [VLLM] CallType.KEYWORDS | Instruction length: 168 | Prompt length: 8624 | kwargs: None
# INFO 11-28 06:41:26 [async_llm_engine.py:209] Added request bcadeee22e9c463fb38616a71e4e526e.
# INFO 11-28 06:41:27 [metrics.py:386] Avg prompt throughput: 27.3 tokens/s, Avg generation throughput: 1.2 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.3%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:41:29 [async_llm_engine.py:177] Finished request bcadeee22e9c463fb38616a71e4e526e.
# [Model] [
#   {
#     "query": "uet là trường đại học nào",
#     "priority": 1.0,
#     "info": "thông tin về trường uet",
#     "school": "uet"
#   }
# ]
# [Model] {'query': 'uet là trường đại học nào', 'priority': 1.0, 'info': 'thông tin về trường uet', 'school': 'uet'}
# [DOMAINS] ['uet.vnu.edu.vn']
# [Retriever] Manual llm_rerank=OFF (query_count=1)
# [Retriever] Manual chunk_rerank=OFF (query_count=1)
# [Retriever] Websearch: 0.43041s
# [Retriever] Rerank: Skip (llm_rerank=False)
# [Snippet] ✗ Cần crawl:
#   Title: Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ...
#   URL: https://uet.vnu.edu.vn/
#   Snippet: Trường Đại học Công nghệ, ĐHQGHN (VNU-UET)
# [Snippet] ✗ Cần crawl:
#   Title: Ngày hội nhập học K70: UET chào đón tân sinh viên bằng những ...
#   URL: https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-don-tan-sinh-vien-bang-nhung-doi-moi-dot-pha/
#   Snippet: Aug 25, 2025 ... Ngày hội nhập học không chỉ là khởi đầu cho K70, mà còn khẳng định cam kết của Trường ĐH Công nghệ trong việc tiên phong đổi mới, tạo...
# [Snippet] ✗ Cần crawl:
#   Title: Hợp tác UET – Yonsei – LG Innotek: Thúc đẩy gắn kết đại học ...
#   URL: https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-day-gan-ket-dai-hoc-doanh-nghiep-trong-dao-tao-nhan-luc-chat-luong-cao/
#   Snippet: Là trường đại học hàng đầu, Đại học Yonsei cũng nổi tiếng vì tính cạnh tranh cao đối với sinh viên Hàn Quốc. (UET-News). Bởi Tuyết Nga | 26/09/2025 .....
# [Snippet] ✗ Cần crawl:
#   Title: Hành trình 20 năm phát triển: Trường Đại học Công nghệ tự hào ...
#   URL: https://uet.vnu.edu.vn/hanh-trinh-20-nam-phat-trien-truong-dai-hoc-cong-nghe-tu-hao-khang-dinh-vi-la-truong-dai-hoc-hang-dau-viet-nam-va-tren-truong-quoc-te/
#   Snippet: May 25, 2024 ... Hành trình 20 năm là chặng đường kiên trì, nỗ lực không ngừng và tự hào là nền tảng vững chắc để UET tiếp tục khẳng định vị thế, vươn...
# [Snippet] ✗ Cần crawl:
#   Title: Sinh viên quốc tế đến nghiên cứu, trao đổi tại Trường Đại học Công ...
#   URL: https://uet.vnu.edu.vn/sinh-vien-quoc-te-den-nghien-cuu-trao-doi-tai-truong-dai-hoc-cong-nghe-dhqghn-thuc-day-moi-truong-hoc-tap-da-van-hoa/
#   Snippet: Aug 14, 2024 ... “Việc trao đổi sinh viên quốc tế cũng là hoạt động đầu tiên giữa TU/e và UET trong lĩnh vực bán dẫn mở ra một chương mới trong quan h...
# [Snippet] ✗ Cần crawl:
#   Title: GIỚI THIỆU - Trường Đại học Công nghệ, ĐHQGHN - VNU-UET
#   URL: https://uet.vnu.edu.vn/truong-dai-hoc-cong-nghe-15-nam-xay-dung-va-truong-thanh/
#   Snippet: Mar 2, 2017 ... Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội được thành lập theo Quyết định số 92/2004/QĐ-TTg ngày 25/05/2004 của Thủ tướng Chính...
# [Snippet] ✗ Cần crawl:
#   Title: Các thủ tục hành chính và mẫu biểu - Trường Đại học Công nghệ ...
#   URL: https://uet.vnu.edu.vn/mot-van-ban-mau-bieu/
#   Snippet: Sinh viên đăng ký qua cổng http://student.uet.vnu.edu.vn/, đính kèm bản mềm minh chứng chứng minh các lý do đã nêu trong yêu cầu là đúng,nộp trước ngà...
# [Snippet] ✗ Cần crawl:
#   Title: 10 sự kiện và thành tựu tiêu biểu của Trường Đại học Công nghệ ...
#   URL: https://uet.vnu.edu.vn/10-su-kien-va-thanh-tuu-tieu-bieu-cua-truong-dai-hoc-cong-nghe-dhqghn-nam-2024-dau-20-nam-kien-tao-doi-moi-va-khang-dinh-vi/
#   Snippet: Năm 2024 đánh dấu mốc son 20 năm xây dựng, phát triển và đổi mới sáng tạo của Trường Đại học Công nghệ – ĐHQGHN (VNU-UET), với những thành tựu xuất sắ...
# [Snippet] ✗ Cần crawl:
#   Title: Gặp gỡ cựu sinh viên Phạm Tuấn Anh: Đồng hành với UET trong ...
#   URL: https://uet.vnu.edu.vn/gap-go-cuu-sinh-vien-pham-tuan-anh-dong-hanh-voi-uet-trong-cong-tac-huong-nghiep-va-tuyen-dung-sinh-vien/
#   Snippet: May 13, 2024 ... Trường Đại học Công nghệ – ĐHQGHN (VNU-UET) không chỉ là nơi nuôi ... Trở về Trường Đại học Công nghệ – ĐHQGHN, những kỷ niệm nào khi...
# [Snippet] ✗ Cần crawl:
#   Title: Những lợi thế khi học ngành Hệ thống thông tin tại UET - Trường ...
#   URL: https://uet.vnu.edu.vn/nhung-loi-khi-hoc-nganh-thong-thong-tin-tai-uet-2/
#   Snippet: Mar 20, 2024 ... ... nào? Ưu điểm vượt trội gì khi theo học ngành này tại Trường Đại học Công nghệ – ĐHQGHN (UET-VNU)? Hãy cùng khám phá ngành Hệ thốn...
# [Retriever] Snippet Check: 0.00061s
# [Download] Bắt đầu crawl 10 URL(s)...
# [Page download] Attempt to download 3 pages from 10 urls (PARALLEL, tối đa 3 request cùng lúc)
# [Page download] ✓ Thành công (premium): https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-da...
# [Page download] ✓ Thành công (premium): https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-do...
# [Page download] ✓ Thành công (premium): https://uet.vnu.edu.vn/...
# [Page download] Tổng requests đã gửi: 3 (bao gồm cả cancelled)
# [Page download] Success download 3 pages
# [Page download] ScrapingBee requests: 3 (regular: 0, premium: 3)
# [Page download] ScrapingBee credits used: 30 (regular: 0x1, premium: 3x10)
# [Download] Snippet đủ: 0, Đã crawl: 3
# [Download] Thời gian crawl: 3.51s (trung bình 0.35s/URL)
#
# [PDF SEARCH] Đang tìm PDF trong: https://uet.vnu.edu.vn/
# [PDF SEARCH] Tổng số links tìm thấy: 0
# [PDF SEARCH] PDF links trực tiếp từ links: 0
# [Attachment search] Tổng số links kiểm tra: 18, tìm thấy: 0
# [PDF SEARCH] Attachment links tìm thấy: 0
# [PDF SEARCH] PDF links từ attachment: 0
# [PDF SEARCH] Non-PDF attachment links: 0
# [PDF SEARCH] Tổng số PDF jobs: 0
# [PDF SEARCH] PDF đã tải thành công: 0/0
# [PDF SEARCH] Keyword links tìm thấy: 0
# [PDF SEARCH] Kết quả cuối cùng: 0 PDF links, 0 PDF files đã tải
#
# [CRAWL] https://uet.vnu.edu.vn/... | 40 chars | 0 PDFs
#
# [PDF SEARCH] Đang tìm PDF trong: https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-don-tan-sinh-vien-bang-nhung-doi-moi-dot-pha/
# [PDF SEARCH] Tổng số links tìm thấy: 0
# [PDF SEARCH] PDF links trực tiếp từ links: 0
# [Attachment search] Tổng số links kiểm tra: 21, tìm thấy: 0
# [PDF SEARCH] Attachment links tìm thấy: 0
# [PDF SEARCH] PDF links từ attachment: 0
# [PDF SEARCH] Non-PDF attachment links: 0
# [PDF SEARCH] Tổng số PDF jobs: 0
# [PDF SEARCH] PDF đã tải thành công: 0/0
# [PDF SEARCH] Keyword links tìm thấy: 0
# [PDF SEARCH] Kết quả cuối cùng: 0 PDF links, 0 PDF files đã tải
#
# [CRAWL] https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-do... | 9487 chars | 0 PDFs
#
# [PDF SEARCH] Đang tìm PDF trong: https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-day-gan-ket-dai-hoc-doanh-nghiep-trong-dao-tao-nhan-luc-chat-luong-cao/
# [PDF SEARCH] Tổng số links tìm thấy: 0
# [PDF SEARCH] PDF links trực tiếp từ links: 0
# [Attachment search] Tổng số links kiểm tra: 15, tìm thấy: 0
# [PDF SEARCH] Attachment links tìm thấy: 0
# [PDF SEARCH] PDF links từ attachment: 0
# [PDF SEARCH] Non-PDF attachment links: 0
# [PDF SEARCH] Tổng số PDF jobs: 0
# [PDF SEARCH] PDF đã tải thành công: 0/0
# [PDF SEARCH] Keyword links tìm thấy: 0
# [PDF SEARCH] Kết quả cuối cùng: 0 PDF links, 0 PDF files đã tải
#
# [CRAWL] https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-da... | 2639 chars | 0 PDFs
# [Retriever] Process: 0.15940s
# Split 211 characters to 1 chunks
# Split Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ... to 1 chunks
# [Retriever] [Split] Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ...: total 1 chunks
# [Retriever] [Split] chunk#0: --- source_url: https://uet.vnu.edu.vn/ crawl_date: 2025-11-28 page_title: Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ... content_type: html has_pdf: False --- Tư vấn tuyển sinh trực tuyến:...
# Split 2922 characters to 4 chunks
# Split Hợp tác UET – Yonsei – LG Innotek: Thúc đẩy gắn kết đại học ... to 4 chunks
# [Retriever] [Split] Hợp tác UET – Yonsei – LG Innotek: Thúc đẩy gắn kết đại học ...: total 4 chunks
# [Retriever] [Split] chunk#0: --- source_url: https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-day-gan-ket-dai-hoc-doanh-nghiep-trong-dao-tao-nhan-luc-chat-luong-cao/ crawl_date: 2025-11-28 page_title: Hợp tác UET – Yonse...
# [Retriever] [Split] chunk#1: ### Hợp tác UET – Yonsei – LG Innotek: Thúc đẩy gắn kết đại học – doanh nghiệp trong đào tạo nhân lực chất lượng cao
# [Retriever] [Split] chunk#2: Ngày 25/9/2025, Trường Đại học Công nghệ – Đại học Quốc gia Hà Nội (VNU-UET) đã đón tiếp và làm việc với đại diện Đại học Yonsei (Hàn Quốc) và Tập đoàn LG Innotek. Đoàn công tác gồm ông Park Seung-Han...
# [Retriever] [Split] ... (+1 more)
# /kaggle/working/data_retriever/retriever_pipeline.py:354: RuntimeWarning: coroutine 'PageDowloader._download_task' was never awaited
#   return await self._page_downloader.download(search_results, k_pages, include_pdf, include_image)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Split 9745 characters to 8 chunks
# Split Ngày hội nhập học K70: UET chào đón tân sinh viên bằng những ... to 8 chunks
# [Retriever] [Split] Ngày hội nhập học K70: UET chào đón tân sinh viên bằng những ...: total 8 chunks
# [Retriever] [Split] chunk#0: --- source_url: https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-don-tan-sinh-vien-bang-nhung-doi-moi-dot-pha/ crawl_date: 2025-11-28 page_title: Ngày hội nhập học K70: UET chào đón tân sinh ...
# [Retriever] [Split] chunk#1: ### Ngày hội nhập học K70: UET chào đón tân sinh viên bằng những đổi mới đột phá
# [Retriever] [Split] chunk#2: Trong không khí tự hào chào mừng 80 năm Quốc khánh nước Cộng hòa Xã hội Chủ nghĩa Việt Nam (2/9/1945 – 2/9/2025), ngày 24/8/2025, Trường Đại học Công nghệ – Đại học Quốc gia Hà Nội (VNU-UET) đã tổ chứ...
# [Retriever] [Split] ... (+5 more)
# [Retriever] [RAG] Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ...: total 1 chunks
# [Retriever] [RAG] chunk#0: --- source_url: https://uet.vnu.edu.vn/ crawl_date: 2025-11-28 page_title: Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ... content_type: html has_pdf: False --- Tư vấn tuyển sinh trực tuyến:...
# [Retriever] [Merge] Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ...: total 1 chunks
# [Retriever] [Merge] chunk#0: --- source_url: https://uet.vnu.edu.vn/ crawl_date: 2025-11-28 page_title: Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ... content_type: html has_pdf: False --- Tư vấn tuyển sinh trực tuyến:...
# [Retriever] [RAG] Hợp tác UET – Yonsei – LG Innotek: Thúc đẩy gắn kết đại học ...: total 2 chunks
# [Retriever] [RAG] chunk#0: --- source_url: https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-day-gan-ket-dai-hoc-doanh-nghiep-trong-dao-tao-nhan-luc-chat-luong-cao/ crawl_date: 2025-11-28 page_title: Hợp tác UET – Yonse...
# [Retriever] [RAG] chunk#3: GS. Park Seung-Han và ông Jeong Junho đã trực tiếp phỏng vấn sinh viên UET Hợp tác với ĐH Yonsei không chỉ giúp sinh viên UET có cơ hội trải nghiệm học thuật và văn hóa tại Seoul – trung tâm kinh tế s...
# [Retriever] [Merge] Hợp tác UET – Yonsei – LG Innotek: Thúc đẩy gắn kết đại học ...: total 2 chunks
# [Retriever] [Merge] chunk#0: --- source_url: https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-day-gan-ket-dai-hoc-doanh-nghiep-trong-dao-tao-nhan-luc-chat-luong-cao/ crawl_date: 2025-11-28 page_title: Hợp tác UET – Yonse...
# [Retriever] [Merge] chunk#3: GS. Park Seung-Han và ông Jeong Junho đã trực tiếp phỏng vấn sinh viên UET Hợp tác với ĐH Yonsei không chỉ giúp sinh viên UET có cơ hội trải nghiệm học thuật và văn hóa tại Seoul – trung tâm kinh tế s...
# [Retriever] [RAG] Ngày hội nhập học K70: UET chào đón tân sinh viên bằng những ...: total 2 chunks
# [Retriever] [RAG] chunk#0: --- source_url: https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-don-tan-sinh-vien-bang-nhung-doi-moi-dot-pha/ crawl_date: 2025-11-28 page_title: Ngày hội nhập học K70: UET chào đón tân sinh ...
# [Retriever] [RAG] chunk#6: Không chỉ sinh viên hào hứng, phụ huynh cũng ấn tượng với công tác tổ chức, cho thấy UET tạo dựng được niềm tin đến cả phụ huynh ngay trong ngày đầu tiên. Anh Hà Minh Hiệp, anh trai của sinh viên Hà M...
# [Retriever] [Merge] Ngày hội nhập học K70: UET chào đón tân sinh viên bằng những ...: total 2 chunks
# [Retriever] [Merge] chunk#0: --- source_url: https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-don-tan-sinh-vien-bang-nhung-doi-moi-dot-pha/ crawl_date: 2025-11-28 page_title: Ngày hội nhập học K70: UET chào đón tân sinh ...
# [Retriever] [Merge] chunk#6: Không chỉ sinh viên hào hứng, phụ huynh cũng ấn tượng với công tác tổ chức, cho thấy UET tạo dựng được niềm tin đến cả phụ huynh ngay trong ngày đầu tiên. Anh Hà Minh Hiệp, anh trai của sinh viên Hà M...
# [Retriever] RAG: 0.24582s
# https://uet.vnu.edu.vn/
# https://www.uet.vnu.edu.vn/ngay-hoi-nhap-hoc-k70-uet-chao-don-tan-sinh-vien-bang-nhung-doi-moi-dot-pha/
# https://uet.vnu.edu.vn/hop-tac-uet-yonsei-lg-innotek-thuc-day-gan-ket-dai-hoc-doanh-nghiep-trong-dao-tao-nhan-luc-chat-luong-cao/
#
# ================================================================================
# [RAG CHUNKS] Total 5 chunks selected for reader:
# --------------------------------------------------------------------------------
# [Chunk 1] title=Trường Đại học Công nghệ, ĐHQGHN - VNU- University of ... | url=https://uet.vnu.edu.vn/ | chunk_index=0
# Text preview:
# ...
# 4. Số sinh viên được nhận học bổng hệ chuẩn dựa trên 8% nguồn thực thu học phí đại học hệ chính quy trong học kỳ II năm học 2023-2024 theo chương trình học, ngành học, khóa học (Nhà trường sẽ cấp HB KKHT cho các sinh viên có đủ điều kiện theo thứ tự từ cao xuống thấp, cho tới khi hết kinh phí chi học bổng KKHT cho sinh viên).
# Đề nghị các sinh viên kiểm tra thông tin trong danh sách ( HBKKHT_TT23+ĐMKTKT ; HBKKHT_CTĐT chuẩn ), nếu có thắc mắc vui lòng đến trực tiếp phòng CTSV (104 – E3), trong giờ hành chính hoặc gửi vào hộp thư hangtt@vnu.edu.vn .
#
# ---
#
# **Nguồn**: [**Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024 ...**](https://uet.vnu.edu.vn/cap-hoc-bong-khuyen-khich-hoc-tap-trong-hoc-ky-nam-hoc-2024-2025-cho-sinh-vien-truong-dai-hoc-cong-nghe/)
#
# Điều 1. Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024-2025 cho các sinh viên đang trong thời hạn đào tạo chuẩn, có tên trong các danh sách ( DS cap hoc bong_chuan ; DS cap hoc bong_ĐMKTKT ; DS cap hoc bong_TT23 ), thỏa mãn đồng thời 4 điều kiện sau đây trong học kỳ II và học kỳ phụ năm học 2023-2024:
# 1. Kết quả học tập và rèn luyện đạt loại Khá trở lên đối với sinh viên chương trình chuẩn; Kết quả học tập đạt loại Giỏi trở lên, rèn luyện loại Tốt trở lên đối với sinh viên chương trình Chất lượng cao và sinh viên thuộc chương trình đào tạo theo định mức kinh tế kỹ thuật.
# 2. Không học phần nào có điểm dưới B.
# 3. Sinh viên hoàn thành ít nhất 14 tín chỉ hoặc đồng thời thỏa mãn 2 điều kiện:sinh viên năm cuối đã học từ 9 tín chỉ và đã đăng kí đủ tối đa số tín chỉ được phép đăng ký theo thời khóa biểu của Nhà trường (có đề xuất xét đặc cách từ Khoa/Viện).
# 4. Số sinh viên được nhận học bổng dựa trên 8% nguồn thực thu học phí đại học, theo chương trình học, ngành học, khóa học, trong học kỳ II và học kỳ phụ năm học 2023-2024.
# Điều 2. Học bổng khuyến khích học tập được cấp theo định mức:
# * Đối với chương trình đào tạo chuẩn
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 3 mức: học bổng loại Khá, học bổng loại Giỏi và học bổng loại Xuất sắc. Chi tiết như sau:
# [BẢNG]
# [BẢNG]
# |Chương trình đào tạo|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |Chuẩn, các khóa từ QH-2021 trở về trước|1.780.000đ|
#
# |Chuẩn, khóa QH-2022 (nhóm 1)|2.970.000đ|
# |Chuẩn, khóa QH-2022 (nhóm 2)|2.480.000đ|
# |Chuẩn, khóa QH-2022 (nhóm 3)|2.010.000đ|
# |Chuẩn, khóa QH-2023, 2024|3.340.000đ|
# * Đối với lớp chất lượng cao thuộc ngành Công nghệ thông tin
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 02 mức: học bổng loại Giỏi và học bổng loại Xuất sắc. Chi tiết như sau:
# [BẢNG]
# [BẢNG]
# |Chương trình đào tạo|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |Các khóa từ QH-2021 trở về trước|2.320.000đ|
# |Khóa QH-2022|3.840.000đ|
# |Khóa QH-2023|4.340.000đ|
# * Đối với chương trình đào tạo chất lượng cao theo thông tư 23/2014/TT-BGDĐT:
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 02 mức: học bổng loại Giỏi và học bổng loại Xuất sắc. Chi tiết như sau:
# [BẢNG]
# [BẢNG]
# |Khóa học|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |QH-2019 đến QH-2022|3.700.000đ|
# * Đối với chương trình đào tạo theo định mức Kinh tế kỹ thuật:
#
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 02 mức: học bổng loại Giỏi và học bổng loại Xuất sắc.
# [BẢNG]
# [BẢNG]
# |Khóa học|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |QH-2023, QH-2024|4.200.000đ|
# Điều 3. Các Trưởng phòng Hành chính – Quản trị, Công tác Sinh viên, Đào tạo, Kế hoạch – Tài chính, Lãnh đạo các Khoa/Viện, các sinh viên có tên ở Điều 1 chịu trách nhiệm thi hành Quyết định này.
# Tiền học bổng sẽ được chuyển vào tài khoản BIDV mà Nhà trường cấp cho sinh viên từ đầu khóa học. Bởi Tuyết Nga 20/12/2024 Học phí, học bổng 14187 lượt xem
# ---
#
# ---
# source_url: https://uet.vnu.edu.vn/cap-hoc-bong-khuyen-khich-hoc-tap-trong-hoc-ky-nam-hoc-2024-2025-cho-sinh-vien-truong-dai-hoc-cong-nghe/
# crawl_date: 2025-11-28
# page_title: Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024 ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2024/12/DS-cap-hoc-bong_chuan.pdf
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2024/12/DS-cap-hoc-bong_ĐMKTKT.pdf
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2024/12/DS-cap-hoc-bong_TT23.pdf
# ---
#
# ### Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024-2025 cho sinh viên Trường Đại học Công nghệ
#
# ---
#
# **Nguồn**: [**Chương trình học bổng Đồng hành Vingroup - ĐHQGHN, năm học ...**](https://www.uet.vnu.edu.vn/chuong-trinh-hoc-bong-dong-hanh-vingroup-dhqghn-nam-hoc-2024-2025/)
#
# ---
# source_url: https://www.uet.vnu.edu.vn/chuong-trinh-hoc-bong-dong-hanh-vingroup-dhqghn-nam-hoc-2024-2025/
# crawl_date: 2025-11-28
# page_title: Chương trình học bổng Đồng hành Vingroup - ĐHQGHN, năm học ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/03/3.-2025.-Mau-Gioi-thieu-ve-SV-nhan-HB.pdf
# ---
#
# ### Chương trình học bổng Đồng hành Vingroup – ĐHQGHN, năm học 2024-2025
# ================================================================================
# [FINAL PROMPT] Qwen4B input:
# --------------------------------------------------------------------------------
# Hiện tại là năm 2025, sử dụng thông tin mới nhất có thể.
# Nếu không tìm thấy đủ dữ liệu đáng tin để xây dựng đầy đủ theo form, chỉ trả lời: "Tôi không tìm thấy thông tin phù hợp.".
# Thông tin tham khảo:
# **Nguồn**: [**Kiểm tra thông tin trong danh sách dự kiến xét học bổng khuyến ...**](https://uet.vnu.edu.vn/kiem-tra-thong-tin-trong-danh-sach-du-kien-xet-hoc-bong-khuyen-khich-hoc-tap-trong-hki-nam-hoc-2024-2025/)
#
# ---
# source_url: https://uet.vnu.edu.vn/kiem-tra-thong-tin-trong-danh-sach-du-kien-xet-hoc-bong-khuyen-khich-hoc-tap-trong-hki-nam-hoc-2024-2025/
# crawl_date: 2025-11-28
# page_title: Kiểm tra thông tin trong danh sách dự kiến xét học bổng khuyến ...
# content_type: html
# has_pdf: False
# ---
#
# Phòng CTSV thông báo danh sách các sinh viên có điểm TBC học tập đạt yêu cầu “không có điểm dưới B”, và ĐRL tương ứng trong HKII năm học 2023-2024 thuộc các đối tượng:
# 1. Đủ điều kiện và dự kiến được cấp học bổng (có ghi số tiền học bổng tương ứng). 2. Đủ điều kiện nhưng dự kiến không được cấp học bổng do đã hết kinh phí theo quy định. 3. Không đủ điều kiện xét (về điểm hoặc số tín chỉ tích lũy hoặc điểm rèn luyện). Điều kiện xét HB cụ thể như sau:
# 1. Kết quả học tập và rèn luyện trong HKII năm học 2023-2024 đạt loại Khá trở lên đối với sinh viên chương trình chuẩn; Kết quả học tập đạt loại Giỏi trở lên, rèn luyện loại Tốt trở lên đối với sinh viên chương trình Chất lượng cao ngành CNTT và CLC TT23/ĐMKTKT.
# 2. Không có học phần nào bị điểm dưới B. 3. Sinh viên hoàn thành ít nhất 14 tín chỉ trong HKII năm học 2023-2024 (Trường hợp đặc biệt phải được Khoa/Viện xét và đề xuất).
# 4. Số sinh viên được nhận học bổng hệ chuẩn dựa trên 8% nguồn thực thu học phí đại học hệ chính quy trong học kỳ II năm học 2023-2024 theo chương trình học, ngành học, khóa học (Nhà trường sẽ cấp HB KKHT cho các sinh viên có đủ điều kiện theo thứ tự từ cao xuống thấp, cho tới khi hết kinh phí chi học bổng KKHT cho sinh viên).
# Đề nghị các sinh viên kiểm tra thông tin trong danh sách ( HBKKHT_TT23+ĐMKTKT ; HBKKHT_CTĐT chuẩn ), nếu có thắc mắc vui lòng đến trực tiếp phòng CTSV (104 – E3), trong giờ hành chính hoặc gửi vào hộp thư hangtt@vnu.edu.vn .
#
# ---
#
# **Nguồn**: [**Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024 ...**](https://uet.vnu.edu.vn/cap-hoc-bong-khuyen-khich-hoc-tap-trong-hoc-ky-nam-hoc-2024-2025-cho-sinh-vien-truong-dai-hoc-cong-nghe/)
#
# Điều 1. Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024-2025 cho các sinh viên đang trong thời hạn đào tạo chuẩn, có tên trong các danh sách ( DS cap hoc bong_chuan ; DS cap hoc bong_ĐMKTKT ; DS cap hoc bong_TT23 ), thỏa mãn đồng thời 4 điều kiện sau đây trong học kỳ II và học kỳ phụ năm học 2023-2024:
# 1. Kết quả học tập và rèn luyện đạt loại Khá trở lên đối với sinh viên chương trình chuẩn; Kết quả học tập đạt loại Giỏi trở lên, rèn luyện loại Tốt trở lên đối với sinh viên chương trình Chất lượng cao và sinh viên thuộc chương trình đào tạo theo định mức kinh tế kỹ thuật.
# 2. Không học phần nào có điểm dưới B.
# 3. Sinh viên hoàn thành ít nhất 14 tín chỉ hoặc đồng thời thỏa mãn 2 điều kiện:sinh viên năm cuối đã học từ 9 tín chỉ và đã đăng kí đủ tối đa số tín chỉ được phép đăng ký theo thời khóa biểu của Nhà trường (có đề xuất xét đặc cách từ Khoa/Viện).
# 4. Số sinh viên được nhận học bổng dựa trên 8% nguồn thực thu học phí đại học, theo chương trình học, ngành học, khóa học, trong học kỳ II và học kỳ phụ năm học 2023-2024.
# Điều 2. Học bổng khuyến khích học tập được cấp theo định mức:
# * Đối với chương trình đào tạo chuẩn
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 3 mức: học bổng loại Khá, học bổng loại Giỏi và học bổng loại Xuất sắc. Chi tiết như sau:
# [BẢNG]
# [BẢNG]
# |Chương trình đào tạo|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |Chuẩn, các khóa từ QH-2021 trở về trước|1.780.000đ|
#
# |Chuẩn, khóa QH-2022 (nhóm 1)|2.970.000đ|
# |Chuẩn, khóa QH-2022 (nhóm 2)|2.480.000đ|
# |Chuẩn, khóa QH-2022 (nhóm 3)|2.010.000đ|
# |Chuẩn, khóa QH-2023, 2024|3.340.000đ|
# * Đối với lớp chất lượng cao thuộc ngành Công nghệ thông tin
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 02 mức: học bổng loại Giỏi và học bổng loại Xuất sắc. Chi tiết như sau:
# [BẢNG]
# [BẢNG]
# |Chương trình đào tạo|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |Các khóa từ QH-2021 trở về trước|2.320.000đ|
# |Khóa QH-2022|3.840.000đ|
# |Khóa QH-2023|4.340.000đ|
# * Đối với chương trình đào tạo chất lượng cao theo thông tư 23/2014/TT-BGDĐT:
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 02 mức: học bổng loại Giỏi và học bổng loại Xuất sắc. Chi tiết như sau:
# [BẢNG]
# [BẢNG]
# |Khóa học|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |QH-2019 đến QH-2022|3.700.000đ|
# * Đối với chương trình đào tạo theo định mức Kinh tế kỹ thuật:
#
# Học bổng được cấp cho sinh viên trong thời hạn đào tạo chuẩn, với 02 mức: học bổng loại Giỏi và học bổng loại Xuất sắc.
# [BẢNG]
# [BẢNG]
# |Khóa học|Mức học bổng/sinh viên/tháng|
# |---|---|
# |Loại Xuất sắc|Loại Giỏi|
# |QH-2023, QH-2024|4.200.000đ|
# Điều 3. Các Trưởng phòng Hành chính – Quản trị, Công tác Sinh viên, Đào tạo, Kế hoạch – Tài chính, Lãnh đạo các Khoa/Viện, các sinh viên có tên ở Điều 1 chịu trách nhiệm thi hành Quyết định này.
# Tiền học bổng sẽ được chuyển vào tài khoản BIDV mà Nhà trường cấp cho sinh viên từ đầu khóa học. Bởi Tuyết Nga 20/12/2024 Học phí, học bổng 14187 lượt xem
# ---
#
# ---
# source_url: https://uet.vnu.edu.vn/cap-hoc-bong-khuyen-khich-hoc-tap-trong-hoc-ky-nam-hoc-2024-2025-cho-sinh-vien-truong-dai-hoc-cong-nghe/
# crawl_date: 2025-11-28
# page_title: Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024 ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2024/12/DS-cap-hoc-bong_chuan.pdf
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2024/12/DS-cap-hoc-bong_ĐMKTKT.pdf
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2024/12/DS-cap-hoc-bong_TT23.pdf
# ---
#
# ### Cấp học bổng khuyến khích học tập trong học kỳ I năm học 2024-2025 cho sinh viên Trường Đại học Công nghệ
#
# ---
#
# **Nguồn**: [**Chương trình học bổng Đồng hành Vingroup - ĐHQGHN, năm học ...**](https://www.uet.vnu.edu.vn/chuong-trinh-hoc-bong-dong-hanh-vingroup-dhqghn-nam-hoc-2024-2025/)
#
# ---
# source_url: https://www.uet.vnu.edu.vn/chuong-trinh-hoc-bong-dong-hanh-vingroup-dhqghn-nam-hoc-2024-2025/
# crawl_date: 2025-11-28
# page_title: Chương trình học bổng Đồng hành Vingroup - ĐHQGHN, năm học ...
# content_type: html
# has_pdf: True
# pdf_links:
# - https://2489013871.e.cdneverest.net/uet.edu.vn/2025/03/3.-2025.-Mau-Gioi-thieu-ve-SV-nhan-HB.pdf
# ---
#
# ### Chương trình học bổng Đồng hành Vingroup – ĐHQGHN, năm học 2024-2025
# Câu hỏi:
# học bổng uet 2025
# ================================================================================
#
# INFO:     2001:ee0:41c1:7d7:6564:d330:7315:67c1:0 - "POST /pre_inference HTTP/1.1" 200 OK
# INFO:     2001:ee0:41c1:7d7:6564:d330:7315:67c1:0 - "POST /inference/d1beb739-1ddd-40f6-86be-888b05d90512 HTTP/1.1" 200 OK
# [VLLM] CallType.READER | Instruction length: 362 | Prompt length: 6708 | kwargs: None
# [VLLm] Using Qwen Reader Lora
# INFO 11-28 06:41:59 [async_llm_engine.py:209] Added request ab7ca689899a45e196e376d873f29b13.
# INFO 11-28 06:42:00 [metrics.py:386] Avg prompt throughput: 192.8 tokens/s, Avg generation throughput: 4.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 3.9%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:05 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.8 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.1%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:10 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.3%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:15 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.5%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:20 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 4.8%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:25 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.4 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.0%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:30 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.2%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:35 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.4%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:40 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.7%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:45 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 5.9%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:50 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.7 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.1%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:42:55 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.3%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:43:00 [metrics.py:386] Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 30.6 tokens/s, Running: 1 reqs, Swapped: 0 reqs, Pending: 0 reqs, GPU KV cache usage: 6.6%, CPU KV cache usage: 0.0%.
# INFO 11-28 06:43:01 [async_llm_engine.py:177] Finished request ab7ca689899a45e196e376d873f29b13.
# INFO:     Shutting down
# (VllmWorkerProcess pid=2760) INFO 11-28 06:43:20 [multiproc_worker_utils.py:260] Worker exiting
# ERROR 11-28 06:43:21 [multiproc_worker_utils.py:121] Worker VllmWorkerProcess pid 2760 died, exit code: -15
# INFO 11-28 06:43:21 [multiproc_worker_utils.py:125] Killing local vLLM worker processes
# ERROR:asyncio:Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7d36940464d0>

# %%
DOMAIN

# %% [markdown]
# ## Test WebSearch - Debug Tool
#
# Test để xem:
# 1. Queries được extract từ câu hỏi
# 2. Web search results (sau reranker 0.6B)
# 3. Text content đọc từ các web

# %%
async def test_websearch_debug(question: str, params: GenerationParams):
    """
    Test websearch: hiển thị queries, search results, và text content
    """
    print("=" * 80)
    print("WEBSEARCH DEBUG TEST")
    print("=" * 80)
    
    # Step 1: Extract keywords/queries
    print("\n📝 STEP 1: KEYWORD EXTRACTION")
    print("-" * 80)
    print(f"Question: {question}\n")
    
    keywords_data = await vllm_model.keywords(question, params)
    print(f"Extracted {len(keywords_data)} keywords/queries:")
    for i, item in enumerate(keywords_data, 1):
        print(f"\n  [{i}]")
        print(f"    Query: {item.get('query', 'N/A')}")
        print(f"    Priority: {item.get('priority', 'N/A')}")
        print(f"    Info: {item.get('info', 'N/A')}")
        print(f"    School: {item.get('school', 'N/A')}")
    
    # Step 2: Build queries list
    print("\n🔍 STEP 2: QUERY CONSTRUCTION")
    print("-" * 80)
    max_query = params.get("max_query", 1)
    queries = []
    school_restrict = params.get("school_domain", False)
    web_retriever = ws_pipeline.retriever.web_retriever
    
    for item in keywords_data:
        if not school_restrict:
            queries.append(item["query"])
        else:
            school = item["school"]
            if school.strip() != "":
                school_domains = web_retriever.school_mapper.domains_from_auto(school, 5)[:10]
                print(f"  School: {school} -> Domains: {school_domains}")
                if len(school_domains) > 0:
                    queries.append([item["query"], school_domains])
    
    queries = queries[:max_query]
    print(f"\nFinal queries (max_query={max_query}):")
    for i, query in enumerate(queries, 1):
        if isinstance(query, str):
            print(f"  [{i}] {query}")
        else:
            print(f"  [{i}] Query: {query[0]}")
            print(f"      Domains: {query[1]}")
    
    # Step 3: Search and retrieve
    print("\n🌐 STEP 3: WEB SEARCH & RETRIEVAL")
    print("-" * 80)
    web_sources, rag_sources = await web_retriever.retrive(question, params)
    
    print(f"\n✅ Web Sources: {len(web_sources)} (3 page đầu tiên từ search, KHÔNG qua reranker)")
    for i, ws in enumerate(web_sources, 1):
        print(f"\n  [{i}] {ws.get('title', 'N/A')}")
        print(f"      URL: {ws.get('url', 'N/A')}")
        print(f"      Score: {ws.get('score', 'N/A')}")
        print(f"      Description: {ws.get('description', 'N/A')[:200]}...")
        text = ws.get('text', '')
        print(f"      Text length: {len(text)} characters")
        preview = text[:500] + "..." if len(text) > 500 else text
        print(f"      Text preview (first 500 chars):\n      {preview}")
    
    print(f"\n✅ RAG Sources (chunks): {len(rag_sources)}")
    for i, rs in enumerate(rag_sources[:10], 1):  # Show first 10
        print(f"\n  [{i}] Chunk {rs.get('chunk_index', 'N/A')}")
        print(f"      URL: {rs.get('url', 'N/A')}")
        print(f"      Title: {rs.get('title', 'N/A')}")
        text = rs.get('text', '')
        preview = text[:400] + "..." if len(text) > 400 else text
        print(f"      Text (first 400 chars):\n      {preview}")
    
    if len(rag_sources) > 10:
        print(f"\n  ... and {len(rag_sources) - 10} more chunks")
    
    # Step 4: Show FULL TEXT of RAG chunks
    print("\n📚 STEP 4: FULL TEXT FROM RAG CHUNKS")
    print("-" * 80)
    for i, rs in enumerate(rag_sources, 1):
        print(f"\n{'='*80}")
        print(f"RAG CHUNK {i}/{len(rag_sources)}")
        print(f"{'='*80}")
        print(f"Chunk Index: {rs.get('chunk_index', 'N/A')}")
        print(f"URL: {rs.get('url', 'N/A')}")
        print(f"Title: {rs.get('title', 'N/A')}")
        text = rs.get('text', '')
        print(f"\nFull Text ({len(text)} characters):")
        print("-" * 80)
        print(text)
        print("-" * 80)
    
    # Step 5: Evaluate RAG chunks quality
    print("\n🔍 STEP 5: EVALUATE RAG CHUNKS QUALITY")
    print("-" * 80)
    # Extract keywords from question
    question_lower = question.lower()
    question_words = set(question_lower.split())
    # Also check for key phrases
    key_phrases = []
    for item in keywords_data:
        query = item.get('query', '').lower()
        key_phrases.extend(query.split())
    key_phrases = set(key_phrases)
    
    print(f"Question: {question}")
    print(f"Key words/phrases to check: {key_phrases}")
    print()
    
    relevant_chunks = []
    for i, rs in enumerate(rag_sources, 1):
        text = rs.get('text', '').lower()
        title = rs.get('title', '').lower()
        full_text = title + " " + text
        
        # Count matches
        matches = []
        for phrase in key_phrases:
            if phrase in full_text:
                matches.append(phrase)
        
        match_ratio = len(matches) / len(key_phrases) if len(key_phrases) > 0 else 0
        is_relevant = match_ratio >= 0.3  # At least 30% of keywords match
        
        status = "✅ RELEVANT" if is_relevant else "❌ NOT RELEVANT"
        print(f"[{i}] Chunk {rs.get('chunk_index', 'N/A')} - {status}")
        print(f"    Title: {rs.get('title', 'N/A')[:80]}")
        print(f"    Matched keywords: {matches} ({len(matches)}/{len(key_phrases)})")
        print(f"    Match ratio: {match_ratio:.2%}")
        
        if is_relevant:
            relevant_chunks.append(i)
    
    print(f"\n📊 Summary:")
    print(f"  Total chunks: {len(rag_sources)}")
    print(f"  Relevant chunks: {len(relevant_chunks)} ({len(relevant_chunks)/len(rag_sources)*100:.1f}%)")
    print(f"  Relevant chunk indices: {relevant_chunks}")
    
    # Step 6: Show full text from web sources
    print("\n📄 STEP 6: FULL TEXT FROM WEB SOURCES")
    print("-" * 80)
    for i, ws in enumerate(web_sources, 1):
        print(f"\n{'='*80}")
        print(f"WEB SOURCE {i}/{len(web_sources)}")
        print(f"{'='*80}")
        print(f"Title: {ws.get('title', 'N/A')}")
        print(f"URL: {ws.get('url', 'N/A')}")
        print(f"Score: {ws.get('score', 'N/A')}")
        print(f"\nFull Text ({len(ws.get('text', ''))} characters):")
        print("-" * 80)
        print(ws.get('text', 'N/A'))
        print("-" * 80)
    
    print("\n" + "=" * 80)
    print("✅ TEST COMPLETED")
    print("=" * 80)
    
    return {
        "keywords": keywords_data,
        "queries": queries,
        "web_sources": web_sources,
        "rag_sources": rag_sources
    }

# %% [markdown]
# ### Run Test
#
# Nhập câu hỏi và chạy test:

# %%
# Test question
question = "Thủ khoa ngành trí tuệ nhân tạo UET 2025 là ai"

# Generation params - TẮT reranker, tải 3 page đầu tiên
params: GenerationParams = {
    "model_id": f"{MODEL_ID}{SEP}1",  # Use LoRA model
    "use_websearch": True,
    "use_localdb": False,  # Chỉ test websearch
    "max_query": 2,
    "k_docs": 5,
    "k_pages": 3,  # Tải 3 page đầu tiên
    "engine_type": "goggle",  # or "google"
    "domain_restrict": False,
    "school_domain": False,
    "llm_rerank": False,  # TẮT reranker - lấy 3 page đầu tiên từ search
    "page_score_threshold": 0.5,
    "chunk_score_threshold": 0.5,
    "max_tokens": 2048,
    "temperature": 0.5,
    "top_p": 0.9,
}

print(f"Question: {question}")
print(f"Params: {params}")
print(f"\n⚠️ Reranker: TẮT - Sẽ tải 3 page đầu tiên từ search results")

# %%
# Run test
result = await test_websearch_debug(question, params)

# %%
# ================================================================================
# CHATBOT HOÀN CHỈNH: HỎI → WEBSEARCH → TRẢ LỜI
# ================================================================================

# Nhập câu hỏi của bạn
user_question = "Thủ khoa ngành trí tuệ nhân tạo UET 2025"

# Cấu hình generation params
generation_params: GenerationParams = {
    "model_id": f"{MODEL_ID}{SEP}1",  # Qwen 4B LoRA
    "use_websearch": True,
    "use_localdb": False,
    "max_query": 2,
    "k_docs": 5,
    "use_snippet_optimization": True,
    "k_pages": 5,
    "engine_type": "google",
    "domain_restrict": False,
    "school_domain": False,
    "llm_rerank": False,
    "page_score_threshold": 0.0,
    "chunk_score_threshold": 0.5,
    "max_tokens": 2048,
    "temperature": 0.5,
    "top_p": 0.9,
}

print("=" * 80)
print("💬 CHATBOT VỚI WEBSEARCH")
print("=" * 80)
print(f"\n❓ Câu hỏi: {user_question}\n")

# Bước 1: Websearch và lấy context
print("🔍 Đang tìm kiếm thông tin trên web...")
web_retriever = ws_pipeline.retriever.web_retriever
web_sources, rag_sources = await web_retriever.retrive(user_question, generation_params)

print(f"✅ Tìm thấy {len(web_sources)} nguồn web và {len(rag_sources)} chunks")

# Bước 2: Format context
from data_retriever import SourceFormat
from instruction import READER_TEMPLATE, READER_INSTRUCTION

context = SourceFormat()(rag_sources)
prompt = READER_TEMPLATE.format(context=context, question=user_question)

# Bước 3: Gọi LLM để trả lời
print(f"\n🤖 Đang tạo câu trả lời với Qwen 4B LoRA...")
print("-" * 80)
print("\n📝 Câu trả lời:\n")

answer = ""
async for chunk in await vllm_model(
    call_type=CallType.READER,
    instruction=READER_INSTRUCTION,
    prompt=prompt,
    params=generation_params
):
    answer += chunk
    print(chunk, end="", flush=True)

print("\n\n" + "=" * 80)
print("✅ HOÀN THÀNH")
print("=" * 80)

# Lưu kết quả để xem lại
final_result = {
    "question": user_question,
    "answer": answer,
    "web_sources": web_sources,
    "rag_sources": rag_sources
}

# %% [markdown]
# ###### Note
# If the instruction is too long -> freeze. Seem like vLLM cache instruction, but we still don't know why it only freeze after some requests. (Seem like cache problem, use llm serve would cause it)
