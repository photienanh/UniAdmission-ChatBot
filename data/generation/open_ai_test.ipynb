# %%
OPEN_AI_API_KEY = "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"
import os
os.environ["OPEN_AI_API_KEY"] = OPEN_AI_API_KEY

# %%
INSTRUCTION = '''Bạn là một AI tư vấn chuyên nghiệp. Hãy trả lời các câu hỏi một cách chính xác, hữu ích và thân thiện. Nếu thông tin được cung cấp có nguồn thì thêm nguồn vào thông tin tìm được và câu trả lời.
Đầu tiên hãy dựa trên thông tin được cung cấp lựa chọn ra thông tin cần tham khảo.
Sau đó trả lời câu hỏi dưới dạng "Thông tin tham khảo:\n$${reference_information}$$\nCâu trả lời:\n$${answer}$$"'''
PROMPT_TEMPLATE = """Thông tin được cung cấp:\n{context}\n
Câu hỏi:\n{question}\n
Thông tin tham khảo:\n"""

# %%
from openai import OpenAI
from search_engines_caching import Websearch

message = "Số giảng viên trường đại học công nghệ - Đại học quốc gia Hà Nội"

# Initialize client
client = OpenAI(api_key=OPEN_AI_API_KEY)
ws = Websearch("intfloat/multilingual-e5-small", 1024, 128)
web_query, _, docs = await ws(message, 10, 10, False, "brave", True, False)
context = ""
for index, doc in enumerate(docs):
    context += f"[**{doc.metadata['title']}**]({doc.metadata['url']}):\n{doc.page_content}\n"
# Out:
# [Web search] Web search: 0.02253s
# c:\Users\Anh\.conda\envs\ai\Lib\site-packages\torch\nn\modules\module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# [Web search] Page length: [2389, 7924, 2276, 9344, 6093, 11866, 19925, 4438, 0]
# [Web search] Splitted 9 docs to 60 chunks
# [HYDE] Tính đến thời điểm tháng 10 năm 2023, số giảng viên của Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội không được công bố cụ thể. Tuy nhiên, ví dụ, một trường đại học công nghệ có thể có khoảng 100-200 giảng viên tùy theo quy mô và chương trình đào tạo.
# c:\Users\Anh\.conda\envs\ai\Lib\site-packages\torch\nn\modules\module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
print(INSTRUCTION)
# Out:
# Bạn là một AI tư vấn chuyên nghiệp. Hãy trả lời các câu hỏi một cách chính xác, hữu ích và thân thiện. Nếu thông tin được cung cấp có nguồn thì thêm nguồn vào thông tin tìm được và câu trả lời.
# Đầu tiên hãy dựa trên thông tin được cung cấp lựa chọn ra thông tin cần tham khảo.
# Sau đó trả lời câu hỏi dưới dạng "Thông tin tham khảo:
# $${reference_information}$$
# Câu trả lời:
# $${answer}$$"

# %%
prompt = PROMPT_TEMPLATE.format(context=context, question=message)
print(prompt)
# Out:
# Thông tin được cung cấp:
# [**Trường Đại học Công nghệ, ĐHQGHN - VNU- University of Engineering and Technology**](https://uet.vnu.edu.vn/):
# Menu __
# Với khát vọng đóng góp cho lĩnh vực y sinh hiện đại, nhóm sinh viên khóa QH-2021, QH-2022 Trường Đại học Công nghệ – Đại học Quốc gia Hà Nội gồm Nguyễn Kiên, Phạm Tuấn Phong, Hoàng Nhật Minh và Dương Nhật Minh, dưới sự hướng dẫn của GS.TS Chử Đức Trình và ThS. Phan
# Bộ Giáo dục và Đào tạo (GD&ĐT) vừa thông tin về kết quả chính thức của Đội tuyển quốc gia Việt Nam dự thi Olympic Trí tuệ nhân tạo quốc tế (IOAI) năm 2025 do Trung Quốc đăng cai tổ chức từ ngày 2/8 đến ngày 8/8/2025. Theo đó, 08 học sinh Việt Nam giành được 3 Huy
# Thời gian gần đây, Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội ghi nhận một số trường hợp thí sinh và phụ huynh nhận được các giấy báo, thông báo giả mạo mạo danh Nhà trường, liên quan đến các chương trình du học ngắn hạn, giao lưu quốc tế, … với
# Từ ngày 14/7- 27/7/2025, đoàn giảng viên và sinh viên Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội (VNU-UET) đã có những trải nghiệm thú vị và bài học quý báu khi tham gia chương trình trao đổi quốc tế “Intelligent Robots 2025” được tổ chức tại Trường Đại học Sư
# Việc hình thành và phát triển các nhóm nghiên cứu mạnh tại các cơ sở giáo dục đại học không chỉ là yêu cầu nội t�
# [**Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology**](https://uet.vnu.edu.vn/doi-ngu-can-bo/):
# Menu __
# ## Đội ngũ cán bộ
# Trường Đại học Công nghệ hiện có 372 cán bộ bao gồm 335 cán bộ cơ hữu, trong đó: 269 giảng viên, trợ giảng, nghiên cứu viên và 61 cán bộ hành chính, kỹ thuật (cán bộ chuyên môn dùng chung) và 37 cán bộ thỉnh giảng. Nhà trường luôn tự hào có đội ngũ cán bộ, giảng viên, nghiên cứu viên trình độ cao có học vị tiến sĩ trở lên chiếm tỷ lệ 74,54%, trong đó tỉ lệ giáo sư và phó giáo sư đạt 19,44%. Bên cạnh đó, Nhà trường còn có đội ngũ giáo sư kiêm nhiệm đến từ các trường đại học và viện tiên tiến trên thế giới. Dưới đây là danh sách cán bộ, giảng viên của trường có học vị tiến sĩ trở lên.
# **I. Danh sách Giáo sư**
# **Stt** | **Họ và tên** | **Đơn vị công tác**
# ---|---|---
# 1 | GS.TS. Nguyễn Hữu Đức | Chủ tịch Hội đồng Khoa học và Đào tạo
# 2 |  | Khoa Công nghệ Xây dựng – Giao thông
# 3 | GS.TS Lê Huy Hàm | Khoa Công nghệ nông nghiệp - Chuyên gia
# 4 |  | Khoa Vật lý kỹ thuật và Công nghệ nano
# 5 | GS.TS Lê Trung Thành | Khoa Điện tử viễn thông
# 6 | GS.TS Chử Đức Trình | Khoa Điện tử viễn thông
# 7 |  | Khoa Công nghệ thông tin
# 8 |  | Khoa Công nghệ thông tin
# **II. Danh sách Phó Giáo sư**
# **Stt** | **Họ và tên** | **Đơn vị công tác**
# ---|---|---
# 1 |  | Viện Công nghệ hàng không - vũ trụ
# 2 |  | Khoa Công nghệ thông tin
# 3 |  | Khoa Cơ học kỹ thuật và Tự �
# [**Điểm chuẩn Trường Đại Học Công Nghệ – Đại Học Quốc Gia Hà Nội 2025 chính xác**](https://diemthi.tuyensinh247.com/diem-chuan/dai-hoc-cong-nghe-dai-hoc-quoc-gia-ha-noi-QHI.html):
# * Xem thêmkeyboard_arrow_down
# Tìm kiếm trường
# Nhập tên trường/mã trường _
# # Điểm chuẩn Trường Đại Học Công Nghệ – Đại Học Quốc Gia Hà Nội 2025 chính xác
# **Điểm chuẩn trường  UET - Đại Học Cong nghệ - ĐHQG Ha Nội năm 2025**
# Năm 2025, trường Đại học Cong nghệ - ĐHQGHN tuyển sinh năm 2025 la 4.020 chỉ tieu cho 21 nganh đao tạo với 4 phương thức. Trường mở them 4 nganh mới gồm: Cong nghệ sinh học (chương trinh cong nghệ kỹ thuật sinh học); cong nghệ kỹ thuật điện tử viễn thong định hướng thiết kế vi mạch; cong nghệ vật liệu (chương trinh cong nghệ vật liệu va vi mạch điện tử); khoa học dữ liệu (chương trinh khoa học va kỹ thuật dữ liệu).
# ** **dựa theo thi tốt nghiệp THPT, điểm thi SAT, A-LEVEL, ACT, điểm thi HSA sẽ được cong bố đến tất cả thi sinh trước 17h00 ngay 22/08.
# **Chú ý:** Điểm chuẩn dưới đây là tổng điểm các môn xét tuyển + điểm ưu tiên nếu có
# Click vào phương thức để xem nhanh điểm chuẩn của phương thức đó
# ###  **Điểm chuẩn theo phương thức Điểm thi THPT năm 2024 **
# Tên ngành| Tổ hợp môn| Điểm chuẩn| Ghi chú
# ---|---|---|---
# Công nghệ thông tin| A00; A01; D01| 27.8|
# Công nghệ nông nghiệp| A00; A01; B00| 22.5|
# Kỹ thuật điều khiển và tự động hoá| A00; A01; D01| 27.05|
# Trí tuệ nhân tạo| A00; A01; D01|
# [**Trường Đại học Công nghệ - ĐHQG Hà Nội - Thông tin tuyển sinh**](https://www.thongtintuyensinh.vn/Truong-Dai-hoc-Cong-nghe-DHQG-Ha-Noi_C50_D671.htm):
# ## ĐẠI HỌC » TP.Hà Nội
# # Trường Đại học Công nghệ - ĐHQG Hà Nội
# **TH ÔNG TIN TUYỂN SINH ĐẠI HỌC CHÍNH QUY NĂM 2025
# *********
# **I. TH ÔNG TIN CHUNG **
# **1. T en cơ sở đao tạo: Trường Đại học Cong nghệ, Đại học Quốc gia Ha Nội **
# **2. M a cơ sở đao tạo trong tuyển sinh: QHI **
# **3. Địa chỉ c ac trụ sở: **
# - Trụ sở chinh: Nha E3, 144 Xuan Thủy, Cầu Giấy, Ha Nội
# **4. Địa chỉ trang th ong tin điện tử: **
# - Trang thong tin chung: https://uet.vnu.edu.vn
# - Trang thong tin tuyển sinh: https://tuyensinh.uet.vnu.edu.vn
# - Địa chỉ trang mạng xa hội: https://www.facebook.com/UET.VNUH
# **5. Số điện thoại li en hệ tuyển sinh: 024 37 547 865*
# **6. Địa chỉ c ong khai quy chế tuyển sinh: **
# https://tuyensinh.uet.vnu.edu.vn/tin-tuyen-sinh/
# **7. Địa chỉ c ong khai cac thong tin về hoạt động của cơ sở đao tạo: **
# https://uet.vnu.edu.vn
# **II. TUYỂN SINH Đ ÀO TẠO ĐẠI HỌC **
# **1. Đối tượng, điều kiện dự tuyển**
# - Người đa được cong nhận tốt nghiệp trung học phổ thong của Việt Nam hoặc co bằng tốt nghiệp của nước ngoai được cong nhận trinh độ tương đương;
# - Đạt ngưỡng đầu vao theo quy định của Trường Đại học Cong nghệ;
# - Co đủ sức khoẻ để học tập theo quy định hiện hanh;
# - Co đủ thong tin ca nhan, hồ sơ dự tuyển theo quy định.
# - Đối với thi sinh khuyết tật bị suy giảm kh
# [**Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội**](https://vi.wikipedia.org/wiki/Trường_Đại_học_Công_nghệ,_Đại_học_Quốc_gia_Hà_Nội):
#  Giáo dục Thể chất & Thể thao
# * Nano & Năng lượng
# * Nghiên cứu Biển & đảo
# * Nghiên cứu về Phụ nữ
# * Nghiên cứu Tài nguyên & Môi trường
# * Nghiên cứu Đô thị
# * Quốc tế nghiên cứu biến đổi toàn cầu
# * Đào tạo, Bồi dưỡng giảng viên lý luận chính trị
# Trường phổ thông|
# Tuyển sinh|
# Lấy từ “”
# Thể loại ẩn:
# * Trang này được sửa đổi lần cuối vào ngày 4 tháng 6 năm 2025, 14:19.
# * Văn bản được phát hành theo ; có thể áp dụng điều khoản bổ sung. Với việc sử dụng trang web này, bạn chấp nhận  và . Wikipedia® là thương hiệu đã đăng ký của , một tổ chức phi lợi nhuận.
# Tìm kiếm
# Tìm kiếm
# Đóng mở mục lục
# Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội
# 2 ngôn ngữ
# *[x]: Xem bản mẫu này
# *[t]: Thảo luận bản mẫu này
# *[s]: Sửa bản mẫu này
# [**Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội**](https://vi.wikipedia.org/wiki/Trường_Đại_học_Công_nghệ,_Đại_học_Quốc_gia_Hà_Nội):
# nh viên của , được thành lập vào năm 2004, địa chỉ tại 144 Xuân Thủy, quận Cầu Giấy, Hà Nội, trong khuôn viên  khu vực Cầu Giấy cùng với các trường thành viên như , , , ,...
# ## Lịch sử
# ### Hình thành
# Trường Đại học Công nghệ phát triển từ các khoa truyền thống và danh tiếng của Trường Đại học Tổng hợp Hà Nội:
# * Ngày 11 tháng 2 năm 1995, thành lập Khoa Công nghệ Thông tin trực thuộc  (nay là ).
# * Ngày 3 tháng 1 năm 1996, Khoa Công nghệ Điện tử - Viễn thông được thành lập.
# * Ngày 18 tháng 10 năm 1999, Giám đốc ĐHQG Hà Nội đã ký quyết định số 1348/TCCB thành lập Khoa Công nghệ trên cơ sở sắp xếp, tổ chức lại Khoa Công nghệ Thông tin và Khoa Công nghệ Điện tử - Viễn thông thuộc  thành hai ngành thuộc Khoa Công nghệ. Cùng với sự ra đời của Khoa Công nghệ, ĐHQGHN đã thành lập Trung tâm Hợp tác Đào tạo và Bồi dưỡng cơ học trực thuộc ĐHQGHN.
# * Ngày 25 tháng 5 năm 2004,  đã ký Quyết định số 92/2004/QĐ-TTg thành lập Trường Đại học Công nghệ trên cơ sở Khoa Công nghệ và Trung tâm Hợp tác Đào tạo và Bồi dưỡng Cơ học thuộc .
# ### Quá trình phát triển
# * Sau khi hình thành, Trường Đại học Công nghệ nhanh chóng ổn định tổ chức, bộ máy với việc tái thành lập Khoa Công nghệ Thông tin và Khoa Điện tử viễn thông.
# * Ngà
# [**Trường Đại học Công nghệ, ĐHQGHN - VNU- University of Engineering and Technology**](https://uet.vnu.edu.vn/):
#  Trường Đại học Sư
# Việc hình thành và phát triển các nhóm nghiên cứu mạnh tại các cơ sở giáo dục đại học không chỉ là yêu cầu nội tại để nâng cao chất lượng đào tạo, mà còn là điểm tựa thúc đẩy khoa học công nghệ quốc gia phát triển bền vững, hiệu quả. TS. Nguyễn Văn
# Ngày 29/7/2025, Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội (VNU-UET) đã ký kết hợp tác với Trường Đại học Ngoại ngữ - Đại học Quốc gia Hà Nội trong lĩnh vực đào tạo, chuyển đổi số và phát triển nguồn nhân lực chất lượng cao. Lễ ký kết đánh dấu
# Xuất phát từ khát vọng đưa công nghệ vào giải quyết các vấn đề thực tiễn trong nông nghiệp, nhóm sinh viên phòng thí nghiệm Nông nghiệp số, Khoa Công nghệ nông nghiệp (Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội) đã cùng nhau thực hiện đề tài: “Nghiên cứu cải tiến
# Ngày 25/07/2025, Hội Sinh viên Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội tổ chức Lễ ra mắt Câu lạc bộ Trí tuệ nhân tạo, Câu lạc bộ Thiết kế và sáng tạo. Sự kiện đánh dấu bước phát triển mới trong việc xây dựng môi trường học thuật và sáng
# ## **SỰ KIỆN NỔI BẬT**
# ## Hợp Tác - Phát
# [**Điểm chuẩn Trường Đại học Công nghệ, ĐHQG Hà Nội 2023**](https://xaydungchinhsach.chinhphu.vn/diem-chuan-truong-dai-hoc-cong-nghe-dhqg-hn-119230822182441776.htm):
#  Đại học Công nghệ – ĐHQGHN năm 2023
# Thí sinh trúng tuyển vào Trường Đại học Công nghệ – ĐHQGHN năm 2023 thực hiện nhập học như sau:
# #### 1. Xác nhận nhập học
# Thí sinh phải xác nhận nhập học trực tuyến trên Hệ thống theo hướng dẫn của Bộ Giáo dục và Đào tạo, thời gian từ ngày 24/8 đến trước 17h ngày 8/9/2023.
# Địa chỉ:
# #### 2. Nhận giấy triệu tập
# Thí sinh tra cứu và xem bản scan online từ 9h00 ngày 24/08/2023 tại địa chỉ:
# Thí sinh sẽ nhận trực tiếp giấy triệu tập tại bàn đón tiếp ngày nhập học Chủ nhật, ngày 27/08/2023. Địa điểm nhập học Nhà G2, Trường Đại học Công nghệ, ĐHQGHN số 144 Xuân Thủy, Cầu Giấy, Hà Nội
# #### 3. Thời gian, địa điểm nhập học
# Ca nhập học| Ngành
# ---|---
# Ca 1: 07h00 đến 08h30| CN8: Khoa học máy tính
# CN14: Hệ thống thông tin
# Ca 2: 08h30 đến 10h00| CN1: Công nghệ thông tin
# CN16: Công nghệ thông tin định hướng thị trường Nhật Bản
# CN15: Mạng máy tính và truyền thông dữ liệu
# Ca 3: 10h00 đến 12h00| CN12: Trí tuệ nhân tạo
# CN5: Công nghệ kỹ thuật xây dựng
# CN 10: Công nghệ nông nghiệp
# Ca 4: 13h00 đến 14h30| CN2: Kỹ thuật máy tính
# CN9: Công nghệ kỹ thuật điện tử viễn thông
# CN17: Kỹ thuật Robot
# Ca 5: 14h30 đến 16h00| CN6: Công nghệ kỹ thuật Cơ điện tử
# CN4: Cơ kỹ th
# [**Thông tin tuyển sinh trường Đại học Công nghệ - Đại Học Quốc Gia Hà Nội**](https://tuyensinhso.vn/school/dai-hoc-cong-nghe-dai-hoc-quoc-gia-ha-noi.html):
# **CỔNG THÔNG TIN TUYỂN SINH ĐẠI HỌC, CAO ĐẲNG LỚN NHẤT VIỆT NAM**
# # Đại học Công nghệ - Đại học Quốc gia Hà Nội
# _Cập nhật: 16/01/2025_
# ## **A. GIỚI THIỆU**
# * Ten trường: Đại học Cong nghệ - Đại học Quốc gia Ha Nội
# * Ten tiếng Anh: University of Engineering and Technology (UET)
# * Ma trường: QHI
# * Loại trường: Cong lập
# * Hệ đao tạo: Đại học - Sau đại học - Lien kết quốc tế
# * Địa chỉ: Nha E3, 144 Xuan Thủy, Cầu Giấy, Ha Nội
# * Điện thoại: 024.37547.461
# * Email:
# * Website: <https://uet.vnu.edu.vn/>
# * Facebook:
# ## **B. TH ÔNG TIN TUYỂN SINH NĂM 2025 (Dự kiến)**
# ### **I. Th ong tin chung**
# **1. Thời gian và h ò sơ xet tuyển**
# * Trướng sẽ thong bao thời gian xet tuyển tren website.
# **2. Đối tượng tuyển sinh**
# * Người đa tốt nghiệp chương trinh THPT của Việt Nam (theo hinh thức giao dục chinh quy hoặc giao dục thường xuyen) hoặc đa tốt nghiệp trinh độ trung cấp (trong đo, người tốt nghiệp trinh độ trung cấp nhưng chưa co bằng tốt nghiệp THPT phải học va thi đạt yeu cầu đủ khối kiến thức văn hoa THPT theo quy định hiện hanh). Người đa tốt nghiệp chương trinh THPT của nước ngoai (đa được nước sở tại cho phep thực hiện, đạt trinh độ tương đương trinh độ THPT của Việt Nam) ở nước ngoai hoặc ở Việt Nam.
# * Co đủ sức khoẻ để học tập tại ĐHQGHN theo
# [**Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology**](https://uet.vnu.edu.vn/doi-ngu-can-bo/):
# �**
# 1 | PGS.TS. Bùi Đình Trí | Khoa Cơ học kỹ thuật và tự động hóa
# 2 | PGS.TS. Đào Như Mai | Khoa Cơ học kỹ thuật và tự động hóa
# 3 | PGS.TS. Đinh Văn Mạnh | Khoa Cơ học kỹ thuật và tự động hóa
# 4 | PGS.TS. Lã Đức Việt | Khoa Cơ học kỹ thuật và tự động hóa
# 5 | PGS.TS. Nguyễn Đình Kiên | Khoa Cơ học kỹ thuật và tự động hóa
# 6 | PGS.TS. Nguyễn Thế Đức | Khoa Cơ học kỹ thuật và tự động hóa
# 7 | PGS.TS. Trần Thu Hà | Khoa Cơ học kỹ thuật và tự động hóa
# 8 | PGS.TS. Hà Quang Thụy | Khoa Công nghệ thông tin
# 9 | PGS.TS. Nguyễn Hoàng Hải | Khoa Điện tử viễn thông
# 10 | PGS.TS. Lê Anh Cường | Viện Trí tuệ nhân tạo
# **Danh sách Tiến sĩ**
# 1 | TS. Chử Đức Hoàng | Khoa Điện tử viễn thông
# 2 | TS. Đỗ Trần Thắng | Khoa Cơ học kỹ thuật và tự động hóa
# 3 | TS. Hoàng Thanh Tùng | Viện Trí tuệ Nhân tạo
# 4 | TS. Lê Phê Đô | Khoa Công nghệ thông tin
# 5 | TS. Lê Xuân Huy | Khoa Cơ học kỹ thuật và tự động hóa
# 6 | TS. Nguyễn Đức Vân | Khoa Công nghệ Xây dựng - Giao thông
# 7 | TS. Nguyễn Tiến Dũng | Khoa Công nghệ Xây dựng - Giao thông
# 8 | TS. Nguyễn Trường Giang | Khoa Công nghệ Xây dựng - Giao thông
# 9 | TS. Nguyễn Văn Quang | Khoa Cơ học kỹ thuật và tự động hóa
# 10 | TS. Nguyễn Việt Cường | Viện Trí tuệ Nhân tạo
# 11 | TS. Phạm Hồng Công | Khoa Công nghệ Xây dựng - Giao thông
# 12 | TS. Phạm Việ
#
#
# Câu hỏi:
# Số giảng viên trường đại học công nghệ - Đại học quốc gia Hà Nội
#
# Thông tin tham khảo:

# %%
# Make a request
response = client.chat.completions.create(
    model="gpt-4o-mini", 
    messages=[
        {"role": "system", "content": INSTRUCTION},
        {"role": "user", "content": prompt}
    ],
    max_tokens=4096,
    temperature=0.7,
    top_p=0.95
)

# Print the model's reply
print(response.choices[0].message.content)
# Out:
# Thông tin tham khảo:
# $$Trường Đại học Công nghệ hiện có 372 cán bộ bao gồm 335 cán bộ cơ hữu, trong đó: 269 giảng viên, trợ giảng, nghiên cứu viên và 61 cán bộ hành chính, kỹ thuật (cán bộ chuyên môn dùng chung) và 37 cán bộ thỉnh giảng.$$
#
# Câu trả lời:
# $$Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội hiện có 269 giảng viên, trợ giảng, và nghiên cứu viên.$$

# %%
print(len(response.choices[0].message.content))
# Out:
# 363

# %%
print(context)
# Out:
# [**Trường Đại học Công nghệ, ĐHQGHN - VNU- University of Engineering and Technology**](https://uet.vnu.edu.vn/):
# Menu __
# Với khát vọng đóng góp cho lĩnh vực y sinh hiện đại, nhóm sinh viên khóa QH-2021, QH-2022 Trường Đại học Công nghệ – Đại học Quốc gia Hà Nội gồm Nguyễn Kiên, Phạm Tuấn Phong, Hoàng Nhật Minh và Dương Nhật Minh, dưới sự hướng dẫn của GS.TS Chử Đức Trình và ThS. Phan
# Bộ Giáo dục và Đào tạo (GD&ĐT) vừa thông tin về kết quả chính thức của Đội tuyển quốc gia Việt Nam dự thi Olympic Trí tuệ nhân tạo quốc tế (IOAI) năm 2025 do Trung Quốc đăng cai tổ chức từ ngày 2/8 đến ngày 8/8/2025. Theo đó, 08 học sinh Việt Nam giành được 3 Huy
# Thời gian gần đây, Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội ghi nhận một số trường hợp thí sinh và phụ huynh nhận được các giấy báo, thông báo giả mạo mạo danh Nhà trường, liên quan đến các chương trình du học ngắn hạn, giao lưu quốc tế, … với
# Từ ngày 14/7- 27/7/2025, đoàn giảng viên và sinh viên Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội (VNU-UET) đã có những trải nghiệm thú vị và bài học quý báu khi tham gia chương trình trao đổi quốc tế “Intelligent Robots 2025” được tổ chức tại Trường Đại học Sư
# Việc hình thành và phát triển các nhóm nghiên cứu mạnh tại các cơ sở giáo dục đại học không chỉ là yêu cầu nội t�
# [**Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology**](https://uet.vnu.edu.vn/doi-ngu-can-bo/):
# Menu __
# ## Đội ngũ cán bộ
# Trường Đại học Công nghệ hiện có 372 cán bộ bao gồm 335 cán bộ cơ hữu, trong đó: 269 giảng viên, trợ giảng, nghiên cứu viên và 61 cán bộ hành chính, kỹ thuật (cán bộ chuyên môn dùng chung) và 37 cán bộ thỉnh giảng. Nhà trường luôn tự hào có đội ngũ cán bộ, giảng viên, nghiên cứu viên trình độ cao có học vị tiến sĩ trở lên chiếm tỷ lệ 74,54%, trong đó tỉ lệ giáo sư và phó giáo sư đạt 19,44%. Bên cạnh đó, Nhà trường còn có đội ngũ giáo sư kiêm nhiệm đến từ các trường đại học và viện tiên tiến trên thế giới. Dưới đây là danh sách cán bộ, giảng viên của trường có học vị tiến sĩ trở lên.
# **I. Danh sách Giáo sư**
# **Stt** | **Họ và tên** | **Đơn vị công tác**
# ---|---|---
# 1 | GS.TS. Nguyễn Hữu Đức | Chủ tịch Hội đồng Khoa học và Đào tạo
# 2 |  | Khoa Công nghệ Xây dựng – Giao thông
# 3 | GS.TS Lê Huy Hàm | Khoa Công nghệ nông nghiệp - Chuyên gia
# 4 |  | Khoa Vật lý kỹ thuật và Công nghệ nano
# 5 | GS.TS Lê Trung Thành | Khoa Điện tử viễn thông
# 6 | GS.TS Chử Đức Trình | Khoa Điện tử viễn thông
# 7 |  | Khoa Công nghệ thông tin
# 8 |  | Khoa Công nghệ thông tin
# **II. Danh sách Phó Giáo sư**
# **Stt** | **Họ và tên** | **Đơn vị công tác**
# ---|---|---
# 1 |  | Viện Công nghệ hàng không - vũ trụ
# 2 |  | Khoa Công nghệ thông tin
# 3 |  | Khoa Cơ học kỹ thuật và Tự �
# [**Điểm chuẩn Trường Đại Học Công Nghệ – Đại Học Quốc Gia Hà Nội 2025 chính xác**](https://diemthi.tuyensinh247.com/diem-chuan/dai-hoc-cong-nghe-dai-hoc-quoc-gia-ha-noi-QHI.html):
# * Xem thêmkeyboard_arrow_down
# Tìm kiếm trường
# Nhập tên trường/mã trường _
# # Điểm chuẩn Trường Đại Học Công Nghệ – Đại Học Quốc Gia Hà Nội 2025 chính xác
# **Điểm chuẩn trường  UET - Đại Học Cong nghệ - ĐHQG Ha Nội năm 2025**
# Năm 2025, trường Đại học Cong nghệ - ĐHQGHN tuyển sinh năm 2025 la 4.020 chỉ tieu cho 21 nganh đao tạo với 4 phương thức. Trường mở them 4 nganh mới gồm: Cong nghệ sinh học (chương trinh cong nghệ kỹ thuật sinh học); cong nghệ kỹ thuật điện tử viễn thong định hướng thiết kế vi mạch; cong nghệ vật liệu (chương trinh cong nghệ vật liệu va vi mạch điện tử); khoa học dữ liệu (chương trinh khoa học va kỹ thuật dữ liệu).
# ** **dựa theo thi tốt nghiệp THPT, điểm thi SAT, A-LEVEL, ACT, điểm thi HSA sẽ được cong bố đến tất cả thi sinh trước 17h00 ngay 22/08.
# **Chú ý:** Điểm chuẩn dưới đây là tổng điểm các môn xét tuyển + điểm ưu tiên nếu có
# Click vào phương thức để xem nhanh điểm chuẩn của phương thức đó
# ###  **Điểm chuẩn theo phương thức Điểm thi THPT năm 2024 **
# Tên ngành| Tổ hợp môn| Điểm chuẩn| Ghi chú
# ---|---|---|---
# Công nghệ thông tin| A00; A01; D01| 27.8|
# Công nghệ nông nghiệp| A00; A01; B00| 22.5|
# Kỹ thuật điều khiển và tự động hoá| A00; A01; D01| 27.05|
# Trí tuệ nhân tạo| A00; A01; D01|
# [**Trường Đại học Công nghệ - ĐHQG Hà Nội - Thông tin tuyển sinh**](https://www.thongtintuyensinh.vn/Truong-Dai-hoc-Cong-nghe-DHQG-Ha-Noi_C50_D671.htm):
# ## ĐẠI HỌC » TP.Hà Nội
# # Trường Đại học Công nghệ - ĐHQG Hà Nội
# **TH ÔNG TIN TUYỂN SINH ĐẠI HỌC CHÍNH QUY NĂM 2025
# *********
# **I. TH ÔNG TIN CHUNG **
# **1. T en cơ sở đao tạo: Trường Đại học Cong nghệ, Đại học Quốc gia Ha Nội **
# **2. M a cơ sở đao tạo trong tuyển sinh: QHI **
# **3. Địa chỉ c ac trụ sở: **
# - Trụ sở chinh: Nha E3, 144 Xuan Thủy, Cầu Giấy, Ha Nội
# **4. Địa chỉ trang th ong tin điện tử: **
# - Trang thong tin chung: https://uet.vnu.edu.vn
# - Trang thong tin tuyển sinh: https://tuyensinh.uet.vnu.edu.vn
# - Địa chỉ trang mạng xa hội: https://www.facebook.com/UET.VNUH
# **5. Số điện thoại li en hệ tuyển sinh: 024 37 547 865*
# **6. Địa chỉ c ong khai quy chế tuyển sinh: **
# https://tuyensinh.uet.vnu.edu.vn/tin-tuyen-sinh/
# **7. Địa chỉ c ong khai cac thong tin về hoạt động của cơ sở đao tạo: **
# https://uet.vnu.edu.vn
# **II. TUYỂN SINH Đ ÀO TẠO ĐẠI HỌC **
# **1. Đối tượng, điều kiện dự tuyển**
# - Người đa được cong nhận tốt nghiệp trung học phổ thong của Việt Nam hoặc co bằng tốt nghiệp của nước ngoai được cong nhận trinh độ tương đương;
# - Đạt ngưỡng đầu vao theo quy định của Trường Đại học Cong nghệ;
# - Co đủ sức khoẻ để học tập theo quy định hiện hanh;
# - Co đủ thong tin ca nhan, hồ sơ dự tuyển theo quy định.
# - Đối với thi sinh khuyết tật bị suy giảm kh
# [**Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội**](https://vi.wikipedia.org/wiki/Trường_Đại_học_Công_nghệ,_Đại_học_Quốc_gia_Hà_Nội):
#  Giáo dục Thể chất & Thể thao
# * Nano & Năng lượng
# * Nghiên cứu Biển & đảo
# * Nghiên cứu về Phụ nữ
# * Nghiên cứu Tài nguyên & Môi trường
# * Nghiên cứu Đô thị
# * Quốc tế nghiên cứu biến đổi toàn cầu
# * Đào tạo, Bồi dưỡng giảng viên lý luận chính trị
# Trường phổ thông|
# Tuyển sinh|
# Lấy từ “”
# Thể loại ẩn:
# * Trang này được sửa đổi lần cuối vào ngày 4 tháng 6 năm 2025, 14:19.
# * Văn bản được phát hành theo ; có thể áp dụng điều khoản bổ sung. Với việc sử dụng trang web này, bạn chấp nhận  và . Wikipedia® là thương hiệu đã đăng ký của , một tổ chức phi lợi nhuận.
# Tìm kiếm
# Tìm kiếm
# Đóng mở mục lục
# Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội
# 2 ngôn ngữ
# *[x]: Xem bản mẫu này
# *[t]: Thảo luận bản mẫu này
# *[s]: Sửa bản mẫu này
# [**Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội**](https://vi.wikipedia.org/wiki/Trường_Đại_học_Công_nghệ,_Đại_học_Quốc_gia_Hà_Nội):
# nh viên của , được thành lập vào năm 2004, địa chỉ tại 144 Xuân Thủy, quận Cầu Giấy, Hà Nội, trong khuôn viên  khu vực Cầu Giấy cùng với các trường thành viên như , , , ,...
# ## Lịch sử
# ### Hình thành
# Trường Đại học Công nghệ phát triển từ các khoa truyền thống và danh tiếng của Trường Đại học Tổng hợp Hà Nội:
# * Ngày 11 tháng 2 năm 1995, thành lập Khoa Công nghệ Thông tin trực thuộc  (nay là ).
# * Ngày 3 tháng 1 năm 1996, Khoa Công nghệ Điện tử - Viễn thông được thành lập.
# * Ngày 18 tháng 10 năm 1999, Giám đốc ĐHQG Hà Nội đã ký quyết định số 1348/TCCB thành lập Khoa Công nghệ trên cơ sở sắp xếp, tổ chức lại Khoa Công nghệ Thông tin và Khoa Công nghệ Điện tử - Viễn thông thuộc  thành hai ngành thuộc Khoa Công nghệ. Cùng với sự ra đời của Khoa Công nghệ, ĐHQGHN đã thành lập Trung tâm Hợp tác Đào tạo và Bồi dưỡng cơ học trực thuộc ĐHQGHN.
# * Ngày 25 tháng 5 năm 2004,  đã ký Quyết định số 92/2004/QĐ-TTg thành lập Trường Đại học Công nghệ trên cơ sở Khoa Công nghệ và Trung tâm Hợp tác Đào tạo và Bồi dưỡng Cơ học thuộc .
# ### Quá trình phát triển
# * Sau khi hình thành, Trường Đại học Công nghệ nhanh chóng ổn định tổ chức, bộ máy với việc tái thành lập Khoa Công nghệ Thông tin và Khoa Điện tử viễn thông.
# * Ngà
# [**Trường Đại học Công nghệ, ĐHQGHN - VNU- University of Engineering and Technology**](https://uet.vnu.edu.vn/):
#  Trường Đại học Sư
# Việc hình thành và phát triển các nhóm nghiên cứu mạnh tại các cơ sở giáo dục đại học không chỉ là yêu cầu nội tại để nâng cao chất lượng đào tạo, mà còn là điểm tựa thúc đẩy khoa học công nghệ quốc gia phát triển bền vững, hiệu quả. TS. Nguyễn Văn
# Ngày 29/7/2025, Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội (VNU-UET) đã ký kết hợp tác với Trường Đại học Ngoại ngữ - Đại học Quốc gia Hà Nội trong lĩnh vực đào tạo, chuyển đổi số và phát triển nguồn nhân lực chất lượng cao. Lễ ký kết đánh dấu
# Xuất phát từ khát vọng đưa công nghệ vào giải quyết các vấn đề thực tiễn trong nông nghiệp, nhóm sinh viên phòng thí nghiệm Nông nghiệp số, Khoa Công nghệ nông nghiệp (Trường Đại học Công nghệ, Đại học Quốc gia Hà Nội) đã cùng nhau thực hiện đề tài: “Nghiên cứu cải tiến
# Ngày 25/07/2025, Hội Sinh viên Trường Đại học Công nghệ - Đại học Quốc gia Hà Nội tổ chức Lễ ra mắt Câu lạc bộ Trí tuệ nhân tạo, Câu lạc bộ Thiết kế và sáng tạo. Sự kiện đánh dấu bước phát triển mới trong việc xây dựng môi trường học thuật và sáng
# ## **SỰ KIỆN NỔI BẬT**
# ## Hợp Tác - Phát
# [**Điểm chuẩn Trường Đại học Công nghệ, ĐHQG Hà Nội 2023**](https://xaydungchinhsach.chinhphu.vn/diem-chuan-truong-dai-hoc-cong-nghe-dhqg-hn-119230822182441776.htm):
#  Đại học Công nghệ – ĐHQGHN năm 2023
# Thí sinh trúng tuyển vào Trường Đại học Công nghệ – ĐHQGHN năm 2023 thực hiện nhập học như sau:
# #### 1. Xác nhận nhập học
# Thí sinh phải xác nhận nhập học trực tuyến trên Hệ thống theo hướng dẫn của Bộ Giáo dục và Đào tạo, thời gian từ ngày 24/8 đến trước 17h ngày 8/9/2023.
# Địa chỉ:
# #### 2. Nhận giấy triệu tập
# Thí sinh tra cứu và xem bản scan online từ 9h00 ngày 24/08/2023 tại địa chỉ:
# Thí sinh sẽ nhận trực tiếp giấy triệu tập tại bàn đón tiếp ngày nhập học Chủ nhật, ngày 27/08/2023. Địa điểm nhập học Nhà G2, Trường Đại học Công nghệ, ĐHQGHN số 144 Xuân Thủy, Cầu Giấy, Hà Nội
# #### 3. Thời gian, địa điểm nhập học
# Ca nhập học| Ngành
# ---|---
# Ca 1: 07h00 đến 08h30| CN8: Khoa học máy tính
# CN14: Hệ thống thông tin
# Ca 2: 08h30 đến 10h00| CN1: Công nghệ thông tin
# CN16: Công nghệ thông tin định hướng thị trường Nhật Bản
# CN15: Mạng máy tính và truyền thông dữ liệu
# Ca 3: 10h00 đến 12h00| CN12: Trí tuệ nhân tạo
# CN5: Công nghệ kỹ thuật xây dựng
# CN 10: Công nghệ nông nghiệp
# Ca 4: 13h00 đến 14h30| CN2: Kỹ thuật máy tính
# CN9: Công nghệ kỹ thuật điện tử viễn thông
# CN17: Kỹ thuật Robot
# Ca 5: 14h30 đến 16h00| CN6: Công nghệ kỹ thuật Cơ điện tử
# CN4: Cơ kỹ th
# [**Thông tin tuyển sinh trường Đại học Công nghệ - Đại Học Quốc Gia Hà Nội**](https://tuyensinhso.vn/school/dai-hoc-cong-nghe-dai-hoc-quoc-gia-ha-noi.html):
# **CỔNG THÔNG TIN TUYỂN SINH ĐẠI HỌC, CAO ĐẲNG LỚN NHẤT VIỆT NAM**
# # Đại học Công nghệ - Đại học Quốc gia Hà Nội
# _Cập nhật: 16/01/2025_
# ## **A. GIỚI THIỆU**
# * Ten trường: Đại học Cong nghệ - Đại học Quốc gia Ha Nội
# * Ten tiếng Anh: University of Engineering and Technology (UET)
# * Ma trường: QHI
# * Loại trường: Cong lập
# * Hệ đao tạo: Đại học - Sau đại học - Lien kết quốc tế
# * Địa chỉ: Nha E3, 144 Xuan Thủy, Cầu Giấy, Ha Nội
# * Điện thoại: 024.37547.461
# * Email:
# * Website: <https://uet.vnu.edu.vn/>
# * Facebook:
# ## **B. TH ÔNG TIN TUYỂN SINH NĂM 2025 (Dự kiến)**
# ### **I. Th ong tin chung**
# **1. Thời gian và h ò sơ xet tuyển**
# * Trướng sẽ thong bao thời gian xet tuyển tren website.
# **2. Đối tượng tuyển sinh**
# * Người đa tốt nghiệp chương trinh THPT của Việt Nam (theo hinh thức giao dục chinh quy hoặc giao dục thường xuyen) hoặc đa tốt nghiệp trinh độ trung cấp (trong đo, người tốt nghiệp trinh độ trung cấp nhưng chưa co bằng tốt nghiệp THPT phải học va thi đạt yeu cầu đủ khối kiến thức văn hoa THPT theo quy định hiện hanh). Người đa tốt nghiệp chương trinh THPT của nước ngoai (đa được nước sở tại cho phep thực hiện, đạt trinh độ tương đương trinh độ THPT của Việt Nam) ở nước ngoai hoặc ở Việt Nam.
# * Co đủ sức khoẻ để học tập tại ĐHQGHN theo
# [**Đội ngũ cán bộ - Trường Đại học Công nghệ, ĐHQGHN - Univeristy of Engineering and Technology**](https://uet.vnu.edu.vn/doi-ngu-can-bo/):
# �**
# 1 | PGS.TS. Bùi Đình Trí | Khoa Cơ học kỹ thuật và tự động hóa
# 2 | PGS.TS. Đào Như Mai | Khoa Cơ học kỹ thuật và tự động hóa
# 3 | PGS.TS. Đinh Văn Mạnh | Khoa Cơ học kỹ thuật và tự động hóa
# 4 | PGS.TS. Lã Đức Việt | Khoa Cơ học kỹ thuật và tự động hóa
# 5 | PGS.TS. Nguyễn Đình Kiên | Khoa Cơ học kỹ thuật và tự động hóa
# 6 | PGS.TS. Nguyễn Thế Đức | Khoa Cơ học kỹ thuật và tự động hóa
# 7 | PGS.TS. Trần Thu Hà | Khoa Cơ học kỹ thuật và tự động hóa
# 8 | PGS.TS. Hà Quang Thụy | Khoa Công nghệ thông tin
# 9 | PGS.TS. Nguyễn Hoàng Hải | Khoa Điện tử viễn thông
# 10 | PGS.TS. Lê Anh Cường | Viện Trí tuệ nhân tạo
# **Danh sách Tiến sĩ**
# 1 | TS. Chử Đức Hoàng | Khoa Điện tử viễn thông
# 2 | TS. Đỗ Trần Thắng | Khoa Cơ học kỹ thuật và tự động hóa
# 3 | TS. Hoàng Thanh Tùng | Viện Trí tuệ Nhân tạo
# 4 | TS. Lê Phê Đô | Khoa Công nghệ thông tin
# 5 | TS. Lê Xuân Huy | Khoa Cơ học kỹ thuật và tự động hóa
# 6 | TS. Nguyễn Đức Vân | Khoa Công nghệ Xây dựng - Giao thông
# 7 | TS. Nguyễn Tiến Dũng | Khoa Công nghệ Xây dựng - Giao thông
# 8 | TS. Nguyễn Trường Giang | Khoa Công nghệ Xây dựng - Giao thông
# 9 | TS. Nguyễn Văn Quang | Khoa Cơ học kỹ thuật và tự động hóa
# 10 | TS. Nguyễn Việt Cường | Viện Trí tuệ Nhân tạo
# 11 | TS. Phạm Hồng Công | Khoa Công nghệ Xây dựng - Giao thông
# 12 | TS. Phạm Việ

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pri
#
# NameError: name 'pri' is not defined
