# %%
import json
from typing import Any
DOMAIN = "https://27d0cf91238e.ngrok-free.app"

# %%
import requests
data = {
    "question": "Tuyển sinh đại học công nghệ 2025",
    "use_web_search": True
}
response = requests.post(f"{DOMAIN}/consume/slm_1", data=json.dumps(data), timeout=60)
print(response.text)
data:dict[str, Any] = json.loads(response.text)

# %%
print(data)
