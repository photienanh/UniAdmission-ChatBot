# %%
DOMAIN = "http://127.0.0.1:8000"

import requests
def login(username: str, password: str) -> str:
    url = f"{DOMAIN}/login"
    payload = {
        "username": username,
        "password": password
    }
    response = requests.post(url, json=payload)
    token = response.headers.get("set-cookie")
    token = str(token).split("jwt=")[-1].split(";")[0]
    return token
def chat(token: str, model_id: str, message: str) -> dict:
    payload = {
        "text": message,
        "model_id": model_id,
        "session_id": None,
        "params": {
            "engine_type": "brave",
            "domain_restrict": False,
            "k_docs": 16,
            "k_pages": 10,
            "max_tokens": 4096,
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 16,
            "max_history": 0
        }
    }
    url = f"{DOMAIN}/chat"
    headers = {
        "jwt": token
    }
    response = requests.post(url, json=payload, cookies=headers)
    return response.json()
def get_result(url: str) -> str:
    response = requests.post(url)
    return response.text

# %%
model_id = "gpt-4o-miniCustom"

# %%
import traceback
with open("question_final.md", 'r', encoding='utf-8') as file:
    lines = file.readlines()
questions = []
for line in lines:
    line = line.strip()
    if len(line) > 0:
        questions.append(line.split(": ")[-1].strip())
for index in range(len(questions)):
    try:
        question = questions[index]
        print("-"*10 + "Question" + "-"*10)
        print(question)
        token = login("generate", "generate")
        data = chat(token, model_id, question)
        result_url = data["result_url"]
        result = get_result(result_url)
        # print("-"*10 + "Result" + "-"*10)
        # print(result)
    except:
        traceback.print_exc()
# Out:
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy ngành Ngôn ngữ Pháp trường Đại học Ngoại thương
# ----------Question----------
# Số các phòng chức năng khác trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Thời gian đào tạo ngành Truyền thông Marketing trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT ngành Ngành Kỹ thuật điều khiển & Tự động hóa trường PTIT
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT ngành Kinh doanh số (E-BDB) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGTD trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Thời gian đào tạo ngành An toàn thông tin trường NEU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh giá năng lực ngành Luật thương mại quốc tế trường Đại học Ngoại thương
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy trường Đại học Ngoại thương
# ----------Question----------
# Trường FTU có mấy giảng đường
# ----------Question----------
# Chỉ tiêu thẳng ngành Khoa học Máy tính trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Số lượng giảng viên trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Trường NEU có phòng học đa phương tiện không ?
# ----------Question----------
# Trường Đại học Ngoại thương có xưởng thực tập không ?
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy ngành Cơ điện tử - ĐH Leibniz Hannover (Đức) trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Khóa luận tốt nghiệp Công nghệ thông tin - ĐH Victoria (New Zealand) trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT trường NEU
# ----------Question----------
# Vị trí nhà đa năng trường FTU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi HSA trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Đồ án tốt nghiệp Quan hệ công chúng ngành Marketing trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Số nhà đa năng trường UET
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi TSA trường Đại học Ngoại thương
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD trường FTU
# ----------Question----------
# Giới thiệu về ngành Công nghệ kỹ thuật xây dựng trường UET
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGNL ngành Quản trị khách sạn trường Đại học Kinh tế Quốc dân
# ----------Question----------
# phòng thực hành trường NEU
# ----------Question----------
# Đối tượng tuyển sinh ngành Chương trình tiên tiến Kỹ thuật Hóa dược trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi chuẩn hóa quốc tế trường Đại học Ngoại thương
# ----------Question----------
# Luận án tốt nghiệp Thương mại điện tử trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi HSA ngành Khoa học dữ liệu trong Kinh tế & Kinh doanh (DSEB) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD ngành Kỹ thuật y sinh (mới) trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Số sinh viên ngành Cử nhân công nghệ thông tin (định hướng ứng dụng) trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGNL ngành Quản trị nhân lực trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Trường UET có phòng thực hành không ?
# ----------Question----------
# Số phòng thực hành trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Danh sách giảng viên ngành Quản trị kinh doanh học bằng tiếng Anh (EBBA) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi TSA trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi TSA ngành Cơ khí - Chế tạo máy - Đh Griffith (Úc) trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh ngành Công nghệ Hàng không vũ trụ trường UET
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD ngành Công nghệ thông tin - ĐH Victoria (New Zealand) trường HUST
# ----------Question----------
# Chuẩn đầu ra ngoại ngữ của trường NEU
# ----------Question----------
# Trường FTU đào tạo những ngành gì ?
# ----------Question----------
# Chỉ tiêu thẳng ngành trường NEU
# ----------Question----------
# Đồ án tốt nghiệp Trí tuệ nhân tạo trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Số lượng phó giáo sư trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT ngành Công nghệ tài chính trường PTIT
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy trường NEU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi chuẩn hóa quốc tế trường UET
# ----------Question----------
# Số nghiên cứu sinh ngành Ngôn ngữ Anh trường Đại học Ngoại thương
# ----------Question----------
# Kiểm định cơ sở đào tạo trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGNL ngành Công nghệ kỹ thuật xây dựng trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Ngành Quản trị Kinh doanh trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Phương thức xét tuyển trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT ngành Kinh tế chính trị trường FTU
# ----------Question----------
# Vị trí thư viện trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Website trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Thời gian công bố Điểm chuẩn trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Số lượng giảng viên cơ hữu trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi HSA ngành Quản trị Kinh doanh trường NEU
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT ngành Ngôn ngữ Trung trường Đại học Ngoại thương
# ----------Question----------
# Phương thức thẳng ngành trường HUST
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi HSA ngành Công nghệ vi mạch bán dẫn (ngành Công nghệ kỹ thuật Điện, điện tử) trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh gia tư duy ngành Truyền thông đa phương tiện CLC trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Khả năng học tập và nâng cao trình độ sau khi ra trường ngành Chương trình tiên tiến Kỹ thuật Điều khiển - Tự động hóa và Hệ thống điện trường HUST
# ----------Question----------
# Điểm ưu tiên khi xét tuyển trường HUST
# ----------Question----------
# Điểm sàn ngành Ngôn ngữ Trung Quốc trường Đại học Ngoại thương
# ----------Question----------
# Đối tượng xét tuyển ngành Kinh tế đầu tư trường NEU
# ----------Question----------
# Học bổng trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Điểm cộng khi xét tuyển trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi chuẩn hóa quốc tế trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Phương thức tuyển thẳng trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Số phòng học trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Những trường nào đào tạo Kinh doanh thương mại
# ----------Question----------
# Trường Đại học Kinh tế Quốc dân có nhà đa năng không ?
# ----------Question----------
# Giáo trình môn Giải tích 1 ngành Kỹ thuật Y sinh trường Đại học Bách khoa Hà Nội
# Traceback (most recent call last):
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 820, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1088, in stream
#     yield from self.read_chunked(amt, decode_content=decode_content)
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1248, in read_chunked
#     self._update_chunk_length()
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1178, in _update_chunk_length
#     raise ProtocolError("Response ended prematurely") from None
# urllib3.exceptions.ProtocolError: Response ended prematurely
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Anh\AppData\Local\Temp\ipykernel_2964\1152279985.py", line 17, in <module>
#     result = get_result(result_url)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anh\AppData\Local\Temp\ipykernel_2964\2501976714.py", line 38, in get_result
#     response = requests.post(url)
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\api.py", line 115, in post
#     return request("post", url, data=data, json=json, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\sessions.py", line 746, in send
#     r.content
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 902, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 822, in generate
#     raise ChunkedEncodingError(e)
# requests.exceptions.ChunkedEncodingError: Response ended prematurely
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGNL ngành Công nghệ kỹ thuật cơ điện tử trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Các giảng đường trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Điểm trúng tuyển ngành Quản trị điều hành thông minh (E-SOM) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT trường UET
# ----------Question----------
# Số trung tâm học liệu trường UET
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT ngành Hệ thống thông tin trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Điểm trúng tuyển trường Đại học Kinh tế Quốc dân
# Traceback (most recent call last):
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 820, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1088, in stream
#     yield from self.read_chunked(amt, decode_content=decode_content)
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1248, in read_chunked
#     self._update_chunk_length()
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1178, in _update_chunk_length
#     raise ProtocolError("Response ended prematurely") from None
# urllib3.exceptions.ProtocolError: Response ended prematurely
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Anh\AppData\Local\Temp\ipykernel_2964\1152279985.py", line 17, in <module>
#     result = get_result(result_url)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anh\AppData\Local\Temp\ipykernel_2964\2501976714.py", line 38, in get_result
#     response = requests.post(url)
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\api.py", line 115, in post
#     return request("post", url, data=data, json=json, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\sessions.py", line 746, in send
#     r.content
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 902, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 822, in generate
#     raise ChunkedEncodingError(e)
# requests.exceptions.ChunkedEncodingError: Response ended prematurely
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT ngành Truyền thông đa phương tiện trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Với điểm thi đánh giá năng lực 51.75 nên chọn trường nào ?
# ----------Question----------
# Số lượng tiến sĩ trường HUST
# ----------Question----------
# Phương thức xét tuyển trường FTU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD ngành Kinh tế học tài chính (FE) trường NEU
# ----------Question----------
# Vị trí phòng học đa phương tiện trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Đối tượng xét tuyển ngành Đầu tư tài chính (BFI - tiếng Anh hệ số 2) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Đối tượng tuyển sinh trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Vị trí việc làm ngành Công nghệ thông tin Việt - Nhật trường PTIT
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi chuẩn hóa quốc tế ngành Toán kinh tế trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Điểm chuẩn trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Điểm trúng tuyển ngành Công nghệ thông tin trường PTIT
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh giá năng lực trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGNL trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Số sinh viên ngành Tiếng anh KHKT và Công nghệ trường HUST
# ----------Question----------
# Trường Đại học Kinh tế Quốc dân có các phòng chức năng khác không ?
# ----------Question----------
# Điểm sàn ngành Thương mại điện tử trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Khóa luận tốt nghiệp Cử nhân Công nghệ thông tin (định hướng ứng dụng) trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Hồ sơ xét tuyển trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGNL ngành Kế toán - Kiểm toán trường Đại học Ngoại thương
# ----------Question----------
# Học phí trường NEU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi TSA ngành An toàn không gian số - Cyber security (CT tiên tiến) trường HUST
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT ngành Công nghệ Thông tin trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh ngành Quan hệ công chúng ngành Marketing trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Tổng thu / chi trường UET
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi TSA ngành Công nghệ kỹ thuật điện tử - viễn thông trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Thông tin ngành Kỹ thuật Cơ điện tử trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGTD trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Số lượng phó giáo sư trường Đại học Ngoại thương
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGTD trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# trung tâm học liệu trường FTU
# ----------Question----------
# Nợ học phí trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh gia tư duy ngành Công nghệ Hàng không vũ trụ trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Điểm cộng khi xét tuyển trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Danh sách học phần ngành Công nghệ kỹ thuật cơ điện tử
# ----------Question----------
# Cơ sở vật chất trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD ngành Khoa học máy tính trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh giá năng lực ngành Kiểm toán tích hợp chứng chỉ quốc tế (AUD-ICAEW) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT trường NEU
# ----------Question----------
# Số thạc sĩ ngành Quản trị dịch vụ du lịch và lữ hành trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Trường Đại học Ngoại thương có đào tạo trình độ thạc sĩ không ?
# ----------Question----------
# Hoạt động liên kết đào tạo nước ngoài trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Số lượng giáo sư trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT ngành Tài chính – Ngân hàng trường NEU
# ----------Question----------
# Số lượng giảng viên cơ hữu trường Đại học Ngoại thương
# ----------Question----------
# Trường PTIT có xưởng thực tập không ?
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGTD ngành Kinh tế chính trị trường Đại học Ngoại thương
# ----------Question----------
# Học ngành Bất động sản nên chọn trường nào
# ----------Question----------
# Chỉ tiêu tuyển sinh trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Số sinh viên ngành Kế toán - Kiểm toán trường FTU
# ----------Question----------
# Chuẩn đầu ra ngành Báo chí của trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Địa chỉ trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Khả năng học tập và nâng cao trình độ sau khi ra trường ngành Kỹ thuật Dệt trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển thẳng ngành Công nghệ Thông tin trường UET
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi chuẩn hóa quốc tế ngành Ngành Kinh doanh quốc tế trường NEU
# ----------Question----------
# thư viện trường Đại học Ngoại thương
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh giá năng lực ngành Tiếng anh chuyên nghiệp quốc tế trường HUST
# ----------Question----------
# Phương thức xét tuyển ngành Marketing CLC trường Học viện Công nghệ Bưu chính Viễn thông
# Traceback (most recent call last):
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 820, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1088, in stream
#     yield from self.read_chunked(amt, decode_content=decode_content)
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1248, in read_chunked
#     self._update_chunk_length()
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\urllib3\response.py", line 1178, in _update_chunk_length
#     raise ProtocolError("Response ended prematurely") from None
# urllib3.exceptions.ProtocolError: Response ended prematurely
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Anh\AppData\Local\Temp\ipykernel_2964\1152279985.py", line 17, in <module>
#     result = get_result(result_url)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anh\AppData\Local\Temp\ipykernel_2964\2501976714.py", line 38, in get_result
#     response = requests.post(url)
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\api.py", line 115, in post
#     return request("post", url, data=data, json=json, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\sessions.py", line 746, in send
#     r.content
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 902, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anh\.conda\envs\ai\Lib\site-packages\requests\models.py", line 822, in generate
#     raise ChunkedEncodingError(e)
# requests.exceptions.ChunkedEncodingError: Response ended prematurely
# ----------Question----------
# trung tâm học liệu trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Học phí ngành Kinh tế chính trị trường Đại học Ngoại thương
# ----------Question----------
# Khóa luận tốt nghiệp Kinh doanh quốc tế trường FTU
# ----------Question----------
# Số phòng học đa phương tiện trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Luận văn tốt nghiệp Kinh doanh thương mại trường NEU
# ----------Question----------
# Giới thiệu về ngành Công nghệ kỹ thuật xây dựng trường UET
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGNL ngành Công nghệ kỹ thuật điện, điện tử trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT ngành Công nghệ Thông tin trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Với điểm thi HSA 52.3 nên chọn trường nào ?
# ----------Question----------
# Học phí trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# các phòng chức năng khác trường NEU
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh giá năng lực trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi HSA trường Đại học Ngoại thương
# ----------Question----------
# Số phòng thí nghiệm trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Thông tin ngành Kỹ thuật Vi điện tử và công nghệ nano trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Thời gian công bố Điểm trúng tuyển trường HUST
# ----------Question----------
# Trường Đại học Kinh tế Quốc dân có hội trường không ?
# ----------Question----------
# Chỉ tiêu thẳng ngành Kinh doanh quốc tế (tại Quảng Ninh) trường Đại học Ngoại thương
# ----------Question----------
# Điểm chuẩn trường Đại học Ngoại thương
# ----------Question----------
# Phương thức tuyển thẳng trường HUST
# ----------Question----------
# Số phòng học đa phương tiện trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Danh sách học phần ngành Tiếng Trung Khoa học và Công nghệ
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT trường PTIT
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh giá năng lực ngành Kế toán - Kiểm toán trường Đại học Ngoại thương
# ----------Question----------
# Đối tượng tuyển sinh ngành Máy tính và Robot trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT ngành Kế toán trường HUST
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGTD ngành Công nghệ Thông tin trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi HSA trường UET
# ----------Question----------
# hội trường trường NEU
# ----------Question----------
# Phương thức thẳng ngành Toán kinh tế trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD ngành Bất động sản trường NEU
# ----------Question----------
# xưởng thực tập trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Điểm trúng tuyển ngành Tiếng Anh KHKT và Công nghệ trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Số tín chỉ ngành Kỹ thuật Cơ khí trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi chuẩn hóa quốc tế trường Đại học Ngoại thương
# ----------Question----------
# Quy đổi điểm bằng chứng chỉ tiếng Anh khi xét tuyển trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi chuẩn hóa quốc tế ngành Luật kinh doanh trường NEU
# ----------Question----------
# Phương thức tuyển thẳng ngành Khoa học dữ liệu trong Kinh tế & Kinh doanh (DSEB) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi HSA trường Đại học Ngoại thương
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi chuẩn hóa quốc tế trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Giáo trình môn Tư tưởng Hoog Chí Minh ngành Kế toán chất lượng cao trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Chính sách học bổng trường FTU
# ----------Question----------
# phòng thực hành trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi TSA trường NEU
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGNL ngành Quản trị giải trí và sự kiện trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Vị trí các phòng chức năng khác trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# phòng thí nghiệm trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển ngành Quản lý dự án trường NEU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT ngành Cử nhân công nghệ thông tin (định hướng ứng dụng) trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Học phí ngành Ngôn ngữ Nhật trường Đại học Ngoại thương
# ----------Question----------
# Trường HUST có mấy cơ sở đào tạo ?
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT ngành Mạng máy tính và truyền thông dữ liệu trường UET
# ----------Question----------
# Vị trí trung tâm học liệu trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Đối tượng xét tuyển trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Trường HUST có thư viện không ?
# ----------Question----------
# Phương thức xét tuyển trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi TSA trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Những trường nào đào tạo Quản lí thị trường
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi chuẩn hóa quốc tế ngành Kỹ thuật Vi điện tử và công nghệ nano trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Điểm sàn trường Đại học Kinh tế Quốc dân
# ----------Question----------
# So sánh giữa trường Học viện Công nghệ Bưu chính Viễn thông và Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu thẳng ngành Ngôn ngữ Trung trường Đại học Ngoại thương
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi HSA ngành Kinh tế chính trị trường FTU
# ----------Question----------
# Điểm chuẩn ngành Công nghệ vật liệu và vi điện tử trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển ngành Quản lý dự án trường NEU
# ----------Question----------
# Tổ hợp xét tuyển trường NEU
# ----------Question----------
# Giáo trình môn Vật lý đại cương ngành Kỹ thuật Y sinh trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Số tín chỉ môn Đại số tuyến tính ngành Kỹ thuật Ô tô trường HUST
# ----------Question----------
# Điểm chuẩn ngành Kế toán trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Các giảng đường trường FTU
# ----------Question----------
# Vị trí việc làm ngành Ngôn ngữ Anh trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Số nhà đa năng trường Đại học Ngoại thương
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT ngành Kỹ thuật Robot trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi chuẩn hóa quốc tế ngành Công nghệ thông tin định hướng thị trường Nhật Bản trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Danh sách học phần ngành Ngôn ngữ Pháp
# ----------Question----------
# Vị trí phòng thí nghiệm trường Đại học Ngoại thương
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi chuẩn hóa quốc tế trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Trường Đại học công nghệ - Đại học quốc gia Hà Nội có nhà đa năng không ?
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy ngành Kinh tế học tài chính (FE) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Số thạc sĩ ngành Cử nhân Công nghệ thông tin (định hướng ứng dụng) trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Với điểm thi THPT 24.8 nên chọn trường nào ?
# ----------Question----------
# Luận văn tốt nghiệp Kỹ thuật y sinh (mới) trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT ngành Tài chính công trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi HSA ngành Ngôn ngữ Pháp trường Đại học Ngoại thương
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGNL trường HUST
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Số lượng tiến sĩ trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT ngành Công nghệ kỹ thuật xây dựng trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh gia tư duy trường Đại học Ngoại thương
# ----------Question----------
# hội trường trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT ngành Phân tích kinh doanh (BA) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Đối tượng tuyển sinh ngành Ngôn ngữ Trung trường Đại học Ngoại thương
# ----------Question----------
# Số trung tâm học liệu trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Trường UET có phòng thực hành không ?
# ----------Question----------
# Vị trí phòng thí nghiệm trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Số xưởng thực tập trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Tổ hợp xét tuyển ngành Quản trị khách sạn quốc tế (IHME - tiếng Anh hệ số 2) trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển thẳng trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Vị trí các phòng chức năng khác trường UET
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi THPT ngành Hệ thống thông tin trường UET
# ----------Question----------
# Luận văn tốt nghiệp Ngôn ngữ Trung Quốc trường Đại học Ngoại thương
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi TSA trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Trường Đại học công nghệ - Đại học quốc gia Hà Nội có đào tạo Hệ thống thông tin không ?
# ----------Question----------
# Học bổng trường FTU
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh giá năng lực ngành Truyền thông đa phương tiện CLC trường PTIT
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT ngành Khoa học máy tính trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# phòng học đa phương tiện trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Điểm chuẩn ngành Ngôn ngữ Anh trường FTU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh giá năng lực trường Đại học Ngoại thương
# ----------Question----------
# Website trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Số lượng thạc sĩ trường UET
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGTD trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Thời hạn nộp hồ sơ xét tuyển trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Trường Đại học Bách khoa Hà Nội có phòng học không ?
# ----------Question----------
# Thời gian công bố Điểm trúng tuyển trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Vị trí trung tâm học liệu trường UET
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGNL ngành Kỹ thuật Hóa Học trường HUST
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh giá năng lực ngành Định hướng nghề nghiệp Khoa học máy tính và dữ liệu trong kinh tế và kinh doanh trường Đại học Ngoại thương
# ----------Question----------
# Quy đổi điểm bằng chứng chỉ tiếng Anh khi xét tuyển trường Đại học Ngoại thương
# ----------Question----------
# Vị trí hội trường trường FTU
# ----------Question----------
# Trường UET có phòng thí nghiệm không ?
# ----------Question----------
# Diện tích trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi TSA ngành Khoa học máy tính trường NEU
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi HSA ngành Công nghệ kỹ thuật cơ điện tử trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Học phí ngành Chương trình tiên tiến Phân tích kinh doanh trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi ĐGNL trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Số lượng thạc sĩ trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy ngành Kế toán chất lượng cao trường PTIT
# ----------Question----------
# Vị trí việc làm ngành Chương trình tiên tiến Kỹ thuật Y sinh trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Trường Học viện Công nghệ Bưu chính Viễn thông có phòng thí nghiệm không ?
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT ngành Ngôn ngữ Pháp CLC trường Đại học Ngoại thương
# ----------Question----------
# Trợ cấp trường FTU
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT ngành Bất động sản trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Tỉ lệ sinh viên có việc làm sau 1 năm ra trường ngành Quản lý Tài nguyên và Môi trường trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Thông tin ngành Nhóm ngành Kinh tế; Kinh tế quốc tế trường FTU
# ----------Question----------
# Trường Học viện Công nghệ Bưu chính Viễn thông có các phòng chức năng khác không ?
# ----------Question----------
# Trường NEU có đào tạo Định phí Bảo hiểm & Quản trị rủi ro (Actuary) học bằng tiếng Anh không ?
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi đánh giá năng lực ngành Quản trị kinh doanh trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Số hội trường trường PTIT
# ----------Question----------
# Chỉ tiêu tuyển sinh trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh giá năng lực trường Đại học Ngoại thương
# ----------Question----------
# Số lượng giảng viên trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Số tín chỉ ngành Kỹ thuật Máy tính trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Các hội thảo trường Đại học Kinh tế Quốc dân
# ----------Question----------
# phòng học đa phương tiện trường NEU
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi HSA ngành Công nghệ Hàng không vũ trụ trường UET
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi TSA ngành Công nghệ đa phương tiện trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Trường Đại học công nghệ - Đại học quốc gia Hà Nội có thư viện không ?
# ----------Question----------
# Đối tượng xét tuyển ngành Ngôn ngữ Trung trường FTU
# ----------Question----------
# Điểm sàn trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi TSA ngành Ngành Kỹ thuật điều khiển & Tự động hóa trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Điểm trúng tuyển trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Số tín chỉ môn Tư tưởng Hoog Chí Minh ngành Kỹ thuật Ô tô trường HUST
# ----------Question----------
# Tổng thu / chi trường Đại học Ngoại thương
# ----------Question----------
# Giới thiệu về trường UET
# ----------Question----------
# Hoạt động liên kết đào tạo nước ngoài trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Số phòng thí nghiệm trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi SAT trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chuẩn đầu ra ngành Quản trị kinh doanh - ĐH Troy (Hoa Kỳ) của trường HUST
# ----------Question----------
# Danh sách giảng viên trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Trường Học viện Công nghệ Bưu chính Viễn thông có đào tạo trình độ thạc sĩ không ?
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi HSA ngành Chương trình tiên tiến Kỹ thuật Hóa dược trường Đại học Bách khoa Hà Nội
# ----------Question----------
# phòng thí nghiệm trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi SAT ngành Hóa học trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Phương thức tuyển thẳng ngành Công nghệ kỹ thuật sinh học trường Đại học công nghệ - Đại học quốc gia Hà Nội
# ----------Question----------
# Số lượng trợ giảng trường Đại học Ngoại thương
# ----------Question----------
# Phương thức xét tuyển theo kết quả thi THPT trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Số tín chỉ ngành Kỹ thuật hạt nhân trường Đại học Bách khoa Hà Nội
# ----------Question----------
# Tổ hợp xét tuyển ngành Ngôn ngữ Pháp trường FTU
# ----------Question----------
# Chính sách miễn giảm học phí trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Tỉ lệ sinh viên / giảng viên trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# nhà đa năng trường HUST
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi ĐGTD trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Chỉ tiêu tuyển thẳng trường FTU
# ----------Question----------
# Điểm ưu tiên khi xét tuyển trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Question----------
# Trường Đại học Ngoại thương có phòng học đa phương tiện không ?
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy trường PTIT
# ----------Question----------
# Đối tượng tuyển sinh trường Đại học Kinh tế Quốc dân
# ----------Question----------
# Với điểm thi HSA 69.5 nên chọn trường nào ?

# %%
DOMAIN = "http://127.0.0.1:8000"

import requests
def login(username: str, password: str) -> str:
    url = f"{DOMAIN}/login"
    payload = {
        "username": username,
        "password": password
    }
    response = requests.post(url, json=payload)
    token = response.headers.get("set-cookie")
    token = str(token).split("jwt=")[-1].split(";")[0]
    return token
def chat(token: str, model_id: str, message: str) -> dict:
    payload = {
        "text": message,
        "model_id": model_id,
        "session_id": None,
        "params": {
            "engine_type": "brave",
            "domain_restrict": False,
            "k_docs": 16,
            "k_pages": 10,
            "max_tokens": 4096,
            "temperature": 0.5,
            "top_p": 0.95,
            "top_k": 16,
            "max_history": 0
        }
    }
    url = f"{DOMAIN}/chat"
    headers = {
        "jwt": token
    }
    response = requests.post(url, json=payload, cookies=headers)
    return response.json()
def get_result(url: str) -> str:
    response = requests.post(url)
    return response.text

# %%
import traceback
with open("question_final.md", 'r', encoding='utf-8') as file:
    lines = file.readlines()
questions = []
for line in lines:
    line = line.strip()
    if len(line) > 0:
        questions.append(line.split(": ")[-1].strip())
for index in range(len(questions)):
    try:
        question = questions[index]
        print("-"*10 + "Question" + "-"*10)
        print(question)
        token = login("generate_1", "generate_1")
        data = chat(token, model_id, question)
        result_url = data["result_url"]
        result = get_result(result_url)
        # print("-"*10 + "Result" + "-"*10)
        # print(result)
    except:
        traceback.print_exc()
