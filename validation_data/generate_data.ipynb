# %%
DOMAIN = "http://127.0.0.1:8000"

import requests
def login(username: str, password: str) -> str:
    url = f"{DOMAIN}/login"
    payload = {
        "username": username,
        "password": password
    }
    response = requests.post(url, json=payload)
    token = response.headers.get("set-cookie")
    token = str(token).split("jwt=")[-1].split(";")[0]
    return token
def chat(token: str, model_id: str, message: str) -> dict:
    payload = {
        "text": message,
        "model_id": model_id,
        "session_id": None,
        "params": {
            "engine_type": "brave",
            "domain_restrict": False,
            "k_docs": 16,
            "k_pages": 10,
            "max_tokens": 4096,
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 16,
            "max_history": 0
        }
    }
    url = f"{DOMAIN}/chat"
    headers = {
        "jwt": token
    }
    response = requests.post(url, json=payload, cookies=headers)
    return response.json()
def get_result(url: str) -> str:
    response = requests.post(url)
    return response.text

# %%
model_id = "gpt-4o-miniCustom"

# %%
import traceback
with open("question_final.md", 'r', encoding='utf-8') as file:
    lines = file.readlines()
token = login("w", "w")
questions = []
for line in lines:
    line = line.strip()
    if len(line) > 0:
        questions.append(line.split(": ")[-1].strip())
for question in questions[:2]:
    try:
        print("-"*10 + "Question" + "-"*10)
        print(question)
        data = chat(token, model_id, question)
        result_url = data["result_url"]
        result = get_result(result_url)
        print("-"*10 + "Result" + "-"*10)
        print(result)
    except:
        traceback.print_exc()
        token = login("w", "w")
# Out:
# ----------Question----------
# Điểm trúng tuyển ngành Quản trị Kinh doanh trường Đại học Kinh tế Quốc dân
# ----------Result----------
# ### Điểm trúng tuyển 2025 — Ngành Quản trị Kinh doanh (Đại học Kinh tế Quốc dân)
# **Tóm tắt:**
# - Điểm trúng tuyển ngành Quản trị Kinh doanh năm 2025 là **27.10**.
# - So với năm 2024, điểm giảm nhẹ từ **27.15**.
# - Mã ngành: 7340101.
#
# | Ngành                     | Phương thức | Mã ngành  | Điểm chuẩn |
# |---------------------------|-------------|-----------|------------|
# | Quản trị Kinh doanh       | THPT        | 7340101   | 27.10      |
#
# **Nguồn:** [Tìm trường ĐH-CĐ - Cốc Cốc (NEU)](https://hoctap.coccoc.com/tim-truong-dh-cd)
# **Lưu ý:** Điểm chuẩn có thể thay đổi theo phương thức xét tuyển khác nhau.
#
# **Bạn có thể hỏi thêm:**
# - Điểm chuẩn các ngành khác tại NEU năm 2025?
# - Thông tin về học phí ngành Quản trị Kinh doanh?
# - Các tổ hợp xét tuyển cho ngành Quản trị Kinh doanh?
# ----------Question----------
# Chỉ tiêu tuyển sinh theo kết quả thi đánh gia tư duy ngành Công nghệ thông tin chất lượng cao trường Học viện Công nghệ Bưu chính Viễn thông
# ----------Result----------
# ### Chỉ tiêu tuyển sinh 2025 — Ngành Công nghệ thông tin (Học viện Công nghệ Bưu chính Viễn thông)
# **Tóm tắt:**
# - Chỉ tiêu tuyển sinh ngành Công nghệ thông tin (chất lượng cao) là **600** sinh viên.
# - Áp dụng cho phương thức xét tuyển dựa vào kết quả thi đánh giá tư duy.
# - Mã ngành: 7480201.
#
# | Ngành                        | Mã ngành  | Tổ hợp xét tuyển | Chỉ tiêu |
# |------------------------------|-----------|-------------------|----------|
# | Công nghệ thông tin (chất lượng cao) | 7480201   | A00, A01          | 600      |
#
# **Nguồn:** [Tìm trường ĐH-CĐ - Cốc Cốc](https://hoctap.coccoc.com/tim-truong-dh-cd)
# **Lưu ý:** Chỉ tiêu có thể thay đổi theo từng năm tuyển sinh và phương thức xét tuyển.
#
# **Bạn có thể hỏi thêm:**
# - Thông tin về các ngành khác tại Học viện Công nghệ Bưu chính Viễn thông.
# - Các phương thức xét tuyển chi tiết hơn.
# - Thời gian và địa điểm thi đánh giá tư duy.
